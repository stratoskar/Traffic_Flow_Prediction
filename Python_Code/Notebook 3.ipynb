# %% [markdown]
# In this section of the code, we train 4 discrete Machine and Deep learning models with the purpose of forecasting traffic flow along every path within the time series dataset. Consequently, we conduct a meticulous analysis of the vehicular flux within the city of San Francisco for each pathway, under the guidance and enforcement of the SQP rules.
#
# <b>The SPQ rules are fully described here:</b>https://dl.acm.org/doi/abs/10.1145/2666310.2666413

# %% [markdown]
# ### Phase 4: Preprocess the time series dataset and add weather data on it
# In this step, the following commands are executed:
# - Load time series dataset that created using SPQ function
# - Preprocess the time series dataset
# - Read weather data and preprocess them
# - Aggregate traffic flow data with weather data
# - Make visualizations of traffic flow per day and per 3-hour interval
# - Extract features that are helpful to our research

# %%
# !pip install ipython-autotime

# measure execution time
# %load_ext autotime
# Out:
# Requirement already satisfied: ipython-autotime in /usr/local/lib/python3.10/dist-packages (0.3.1)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from ipython-autotime) (7.34.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (67.7.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (0.19.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (3.0.39)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->ipython-autotime) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->ipython-autotime) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->ipython-autotime) (0.2.6)
# time: 352 µs (started: 2023-08-17 13:53:17 +00:00)

# %%
# disable warnings
import warnings
warnings.filterwarnings('ignore')

# standard library imports
import pandas as pd
import numpy as np

# visualization libraries
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
# Out:
# time: 466 ms (started: 2023-08-17 13:53:17 +00:00)

# %% [markdown]
# #### Step 1: Load the time series traffic flow dataset that created using SPQ function
# In this step we are doing the following operations:
# - Read the data
# - Change the name of columns

# %%
from google.colab import drive
drive.mount('/content/drive')

# define the path with the time series SPQ data
PATH = '/content/drive/MyDrive/Colab Notebooks/San Francisco TF Pred/Preprocessing_Forecasting/Data/time_series_SPQ.txt'
# Out:
# Mounted at /content/drive
# time: 23.3 s (started: 2023-08-17 13:53:17 +00:00)

# %%
# read dataset
time_series = pd.read_csv(PATH)

# this list contains the column names
columns = ["Taxi ID","Traj ID","Path","Length"]

# generate the columns of the dataset
i =4
while(True):
    if i == 4:
        columns.append(pd.to_datetime('2008-05-18 00:00:00'))
    else:
        columns.append(columns[i-1] + timedelta(seconds=1800))

    if (columns[i]>=pd.to_datetime('2008-05-24 23:59:59.000130')):
        break

    i+=1

# delete the last timestamp
columns.pop()

# assign new column names to our dataframe
time_series.columns = columns
# Out:
# time: 2.16 s (started: 2023-08-17 13:53:41 +00:00)

# %% [markdown]
# #### Step 2: Preprocess the time series dataset
# In this step we are doing the following operations:
# - Reshape it to long format using melt function
# - Encode categorical values
# - Preprocess the data types of each column

# %%
# reshape the data from wide format to long format
id_cols = ['Taxi ID','Traj ID', 'Path', 'Length']
time_cols = time_series.iloc[:,2:].columns
time_series = time_series.melt(id_vars=id_cols, value_vars=time_cols, var_name='Time Column', value_name='Traffic Flow')
time_series['Time Column'] = pd.to_datetime(time_series['Time Column'])

# sort rows by Path and Time
time_series.sort_values(by=['Path','Time Column'],inplace=True)
# Out:
# time: 460 ms (started: 2023-08-17 13:53:43 +00:00)

# %%
# convert path column from categorical to numerical
from sklearn.preprocessing import LabelEncoder

# create an instance of LabelEncoder
label_encoder = LabelEncoder()

# fit label encoder on the 'Path' column
time_series['Path'] = label_encoder.fit_transform(time_series['Path'])

# sort the data based in Path column
time_series = time_series.sort_values(by=['Path','Time Column'])

# print data
time_series.head()
# Out:
#       Taxi ID  Traj ID  Path  Length         Time Column  Traffic Flow
# 563       343      298     0       4 2008-05-18 00:00:00             4
# 1563      343      298     0       4 2008-05-18 00:30:00             4
# 2563      343      298     0       4 2008-05-18 01:00:00             6
# 3563      343      298     0       4 2008-05-18 01:30:00             3
# 4563      343      298     0       4 2008-05-18 02:00:00             9
# time: 1.01 s (started: 2023-08-17 13:53:43 +00:00)

# %% [markdown]
# #### Step 3: Read and preprocess the weather data
# In the weather dataset of San Francisco area, there are many columns that are useless for our research. We just drop them and preprocess the dataset.
#
# In this step we are doing the following operations:
# - Read the weather data
# - Drop uneccessary information
# - Encode categorical attributes
# - Fill Nan values

# %%
# define the path of weather data
path2 = '/content/drive/MyDrive/Colab Notebooks/San Francisco TF Pred/Preprocessing_Forecasting/Data/weather_data.csv'

# read weather data
weather_data = pd.read_csv(path2,sep=',')

# drop unecessary columns
# dropped columns can either have NaN values, or not be associated with traffic flow.
# columns kept: temperature, humidity, windspeed, sealevelpressure, visibility
weather_data = weather_data.drop(['name','feelslike','dew','precip','precipprob','preciptype',
                                  'snow','snowdepth','windgust','winddir','cloudcover',
                                  'solarradiation','solarenergy','uvindex','severerisk','stations','icon'],axis=1)
# Out:
# time: 364 ms (started: 2023-08-17 13:53:44 +00:00)

# %% [markdown]
# There is one column that contains categorical vales. Use one-hot encode it to represent it as numerical vector.

# %%
# view the values of "conditions" column
weather_data['conditions'].value_counts()
# Out:
# Partially cloudy    435
# Clear               166
# Overcast            142
# Rain, Overcast        1
# Name: conditions, dtype: int64
# time: 9.88 ms (started: 2023-08-17 13:53:45 +00:00)

# %%
# change the only 'Rain, Overcast' value to 'Overcast'
weather_data.loc[weather_data['conditions'] == 'Rain, Overcast', 'conditions'] = 'Overcast'
# Out:
# time: 1.23 ms (started: 2023-08-17 13:53:45 +00:00)

# %%
# view again the values of "conditions" column
weather_data['conditions'].value_counts()
# Out:
# Partially cloudy    435
# Clear               166
# Overcast            143
# Name: conditions, dtype: int64
# time: 10.1 ms (started: 2023-08-17 13:53:45 +00:00)

# %%
# one-hot encode the  "conditions" column
conditions = pd.get_dummies(weather_data['conditions'], prefix='conditions')
weather_data.drop('conditions',axis=1,inplace=True)

# concatenate the one-hot encoded columns to the original DataFrame
weather_data = pd.concat([weather_data, conditions], axis=1)
# Out:
# time: 3.37 ms (started: 2023-08-17 13:53:45 +00:00)

# %% [markdown]
# Now, there are not categorical values.

# %%
# view for null values
weather_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 744 entries, 0 to 743
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   datetime                     744 non-null    object
#  1   temp                         744 non-null    float64
#  2   humidity                     744 non-null    float64
#  3   windspeed                    744 non-null    float64
#  4   sealevelpressure             744 non-null    float64
#  5   visibility                   744 non-null    float64
#  6   conditions_Clear             744 non-null    uint8
#  7   conditions_Overcast          744 non-null    uint8
#  8   conditions_Partially cloudy  744 non-null    uint8
# dtypes: float64(5), object(1), uint8(3)
# memory usage: 37.2+ KB
# time: 19.1 ms (started: 2023-08-17 13:53:45 +00:00)

# %% [markdown]
# There are not null values in the weather dataset too!

# %%
# convert datetime column to appropriate format
weather_data['datetime'] = pd.to_datetime(weather_data['datetime'])

# drop rows that are not in within the interval [2008-05-18,2008-05-24]
start_date = pd.to_datetime('2008-05-18')
end_date = pd.to_datetime('2008-05-25')
weather_data = weather_data[(weather_data['datetime'] >= start_date) & (weather_data['datetime'] <= end_date)].reset_index(drop=True)
# Out:
# time: 5.73 ms (started: 2023-08-17 13:53:45 +00:00)

# %% [markdown]
# #### Step 4: Connect the two dataframes to one
# Use time information to correctly connect the weather data and traffic flow data together.

# %%
# connect two dataframes, time-series traffic flow and weather data
time_series.set_index('Time Column', inplace=True)
weather_data.set_index('datetime', inplace=True)

# resample the 'weather_data' dataset to 30-minute intervals and forward-fill the missing values
weather_data = weather_data.resample('30T').ffill()

# merge the time_series and weather_data_resampled datasets based on their indexes
time_series_weather = time_series.merge(weather_data, left_index=True, right_index=True)
# Out:
# time: 99.8 ms (started: 2023-08-17 13:53:45 +00:00)

# %% [markdown]
# #### Step 5: Feature Creation From Time Information
# In this step we define some features based on time series timestamps.
# - Day, day of week, hour and minute features derive directly from the timestamp column of the dataset.
# - Hour_sin and Hour_cos columns transform the hour values into a cyclic representation, where the values range from -1 to 1. This transformation is used in time series analysis to capture the periodic patterns or cyclical nature of time-related data.
# - Use also the 3_hour_interval to describe, in which interval of the day data refer to.

# %%
time_series_weather = time_series_weather.reset_index()
time_series_weather.rename(columns={'index': 'Time Column'}, inplace=True)
# Out:
# time: 21.9 ms (started: 2023-08-17 13:53:45 +00:00)

# %%
### extract timestamp information to different columns ###

time_series_weather['hour'] = time_series_weather['Time Column'].dt.hour
time_series_weather['dayofweek'] = time_series_weather['Time Column'].dt.dayofweek
time_series_weather['day'] = time_series_weather['Time Column'].dt.day
time_series_weather['minute'] = time_series_weather['Time Column'].dt.minute

### circular Encoding for cyclic time features ###

time_series_weather['hour_sin'] = np.sin(2 * np.pi * time_series_weather['hour'] / 24)
time_series_weather['hour_cos'] = np.cos(2 * np.pi * time_series_weather['hour'] / 24)

time_series_weather['day_of_week_sin'] = np.sin(2 * np.pi * time_series_weather['dayofweek'] / 7)
time_series_weather['day_of_week_cos'] = np.cos(2 * np.pi * time_series_weather['dayofweek'] / 7)

time_series_weather['day_sin'] = np.sin(2 * np.pi * time_series_weather['day'] / 31)
time_series_weather['day_cos'] = np.cos(2 * np.pi * time_series_weather['day'] / 31)

time_series_weather['minute_sin'] = np.sin(2 * np.pi * time_series_weather['minute'] / 60)
time_series_weather['minute_cos'] = np.cos(2 * np.pi * time_series_weather['minute'] / 60)
# Out:
# time: 137 ms (started: 2023-08-17 13:53:45 +00:00)

# %%
# define a custom function to determine the three-hour interval, based in timestamp hour information
def get_3hour_interval(hour):
    if hour in [0, 1, 2]:
        return 1
    elif hour in [3, 4, 5]:
        return 2
    elif hour in [6, 7, 8]:
        return 3
    elif hour in [9, 10, 11]:
        return 4
    elif hour in [12, 13, 14]:
        return 5
    elif hour in [15, 16, 17]:
        return 6
    elif hour in [18, 19, 20]:
        return 7
    elif hour in [21, 22, 23]:
        return 8
    else:
        return None
# Out:
# time: 861 µs (started: 2023-08-17 13:53:45 +00:00)

# %%
# apply the custom function on the data to create the '3hour_interval' column
time_series_weather['3hour_interval'] = time_series_weather['hour'].apply(get_3hour_interval)
# Out:
# time: 174 ms (started: 2023-08-17 13:53:45 +00:00)

# %%
# print dataset
time_series_weather
# Out:
#                Time Column  Taxi ID  Traj ID  Path  Length  Traffic Flow  \
# 0      2008-05-18 00:00:00      343      298     0       4             4
# 1      2008-05-18 00:00:00      370      177     1       4             2
# 2      2008-05-18 00:00:00      440      355     2       2             5
# 3      2008-05-18 00:00:00      459       48     3       9             4
# 4      2008-05-18 00:00:00      219      392     4      12             0
# ...                    ...      ...      ...   ...     ...           ...
# 335995 2008-05-24 23:30:00      127      127   995       3            18
# 335996 2008-05-24 23:30:00      200       73   996       9             1
# 335997 2008-05-24 23:30:00      240      242   997       5             0
# 335998 2008-05-24 23:30:00      117      380   998      12             0
# 335999 2008-05-24 23:30:00      248      615   999      11             0
#
#         temp  humidity  windspeed  sealevelpressure  ...  minute  hour_sin  \
# 0       12.4     87.29       16.1            1017.7  ...       0  0.000000
# 1       12.4     87.29       16.1            1017.7  ...       0  0.000000
# 2       12.4     87.29       16.1            1017.7  ...       0  0.000000
# 3       12.4     87.29       16.1            1017.7  ...       0  0.000000
# 4       12.4     87.29       16.1            1017.7  ...       0  0.000000
# ...      ...       ...        ...               ...  ...     ...       ...
# 335995  12.4     72.31       10.5            1015.0  ...      30 -0.258819
# 335996  12.4     72.31       10.5            1015.0  ...      30 -0.258819
# 335997  12.4     72.31       10.5            1015.0  ...      30 -0.258819
# 335998  12.4     72.31       10.5            1015.0  ...      30 -0.258819
# 335999  12.4     72.31       10.5            1015.0  ...      30 -0.258819
#
#         hour_cos  day_of_week_sin  day_of_week_cos   day_sin   day_cos  \
# 0       1.000000        -0.781831         0.623490 -0.485302 -0.874347
# 1       1.000000        -0.781831         0.623490 -0.485302 -0.874347
# 2       1.000000        -0.781831         0.623490 -0.485302 -0.874347
# 3       1.000000        -0.781831         0.623490 -0.485302 -0.874347
# 4       1.000000        -0.781831         0.623490 -0.485302 -0.874347
# ...          ...              ...              ...       ...       ...
# 335995  0.965926        -0.974928        -0.222521 -0.988468  0.151428
# 335996  0.965926        -0.974928        -0.222521 -0.988468  0.151428
# 335997  0.965926        -0.974928        -0.222521 -0.988468  0.151428
# 335998  0.965926        -0.974928        -0.222521 -0.988468  0.151428
# 335999  0.965926        -0.974928        -0.222521 -0.988468  0.151428
#
#           minute_sin  minute_cos  3hour_interval
# 0       0.000000e+00         1.0               1
# 1       0.000000e+00         1.0               1
# 2       0.000000e+00         1.0               1
# 3       0.000000e+00         1.0               1
# 4       0.000000e+00         1.0               1
# ...              ...         ...             ...
# 335995  5.665539e-16        -1.0               8
# 335996  5.665539e-16        -1.0               8
# 335997  5.665539e-16        -1.0               8
# 335998  5.665539e-16        -1.0               8
# 335999  5.665539e-16        -1.0               8
#
# [336000 rows x 27 columns]
# time: 143 ms (started: 2023-08-17 13:53:45 +00:00)

# %% [markdown]
# #### Step 6: Make Visualizations
#
# In this step, we are doing the following operations:
# - View total traffic flow (sum of traffic flow of every path in the dataset) per timestep. In this way, we can understand patterns that traffic flow has.
#
# - View total traffic flow per day and 3-hour interval of the same day, to understand in which time of each day Traffic Flow is on its peak.

# %%
import seaborn as sns
# Out:
# time: 148 ms (started: 2023-08-17 13:53:46 +00:00)

# %% [markdown]
# ##### Visualise the Traffic Flow in every path of the dataset per day
# Use the sum of traffic flow of every path at each timestep to generate a total overview about the data

# %%
# group by timestamp (index) and calculate the sum of the traffic flow
grouped_df = time_series_weather['Traffic Flow'].groupby(time_series_weather['Time Column']).sum()

# add results to dataframe
grouped_df = pd.DataFrame(grouped_df,index=grouped_df.index)
# Out:
# time: 11.6 ms (started: 2023-08-17 13:53:46 +00:00)

# %%
# add additional time information in the dataset
grouped_df['hour'] = grouped_df.index.hour
grouped_df['3hour_interval'] = grouped_df['hour'].apply(get_3hour_interval)
grouped_df['dayofweek'] = grouped_df.index.dayofweek
# Out:
# time: 5.97 ms (started: 2023-08-17 13:53:46 +00:00)

# %%
# create a custom dark color palette
dark_palette = sns.color_palette('dark', n_colors=8)

# create a plot to view the results
plt.figure(figsize=(15,5))
sns.lineplot(grouped_df,x=grouped_df.index,y='Traffic Flow',hue='dayofweek',marker='o', palette=dark_palette,linewidth=2.5)
plt.xlabel('Time')
plt.ylabel('Sum of Traffic Flow')
plt.title('Sum of Traffic Flow in Every Path of the Dataset Over Time')
plt.show()
# Out:
# time: 456 ms (started: 2023-08-17 13:53:46 +00:00)

# %% [markdown]
# Based on graph above, we see that for each day, there is a seasonality pattern. In the noon hours Traffic Flow is lower than in the mornnings or in the evenings.

# %% [markdown]
# ##### Visualize traffic flow per day and per 3hour time inteval

# %%
# traffic flow on 2008-05-18
pl = grouped_df[(grouped_df.index >= '2008-05-18 00:00:00') & (grouped_df.index < '2008-05-19 00:00:00')]

# create a custom dark color palette
dark_palette = sns.color_palette('dark', n_colors=8)

# plot the data
plt.figure(figsize=(15,5))
sns.lineplot(pl,x='Time Column',y='Traffic Flow',hue='3hour_interval',marker='o', palette=dark_palette,linewidth=2.5)
plt.title("Traffic Flow on 2008-05-18")
plt.xlabel("Time information every 30 minutes")
# Out:
# Text(0.5, 0, 'Time information every 30 minutes')
# time: 524 ms (started: 2023-08-17 13:53:46 +00:00)

# %%
# traffic flow on 2008-05-19
pl = grouped_df[(grouped_df.index >= '2008-05-19 00:00:00') & (grouped_df.index < '2008-05-20 00:00:00')]

# create a custom dark color palette
dark_palette = sns.color_palette('dark', n_colors=8)

# plot the data
plt.figure(figsize=(15,5))
sns.lineplot(pl,x='Time Column',y='Traffic Flow',hue='3hour_interval',marker='o', palette=dark_palette,linewidth=2.5)
plt.title("Traffic Flow on 2008-05-19")
plt.xlabel("Time information every 30 minutes")
# Out:
# Text(0.5, 0, 'Time information every 30 minutes')
# time: 458 ms (started: 2023-08-17 13:53:47 +00:00)

# %%
# traffic flow on 2008-05-20
pl = grouped_df[(grouped_df.index >= '2008-05-20 00:00:00') & (grouped_df.index < '2008-05-21 00:00:00')]

# create a custom dark color palette
dark_palette = sns.color_palette('dark', n_colors=8)

# plot the data
plt.figure(figsize=(15,5))
sns.lineplot(pl,x='Time Column',y='Traffic Flow',hue='3hour_interval',marker='o', palette=dark_palette,linewidth=2.5)
plt.title("Traffic Flow on 2008-05-20")
plt.xlabel("Time information every 30 minutes")
# Out:
# Text(0.5, 0, 'Time information every 30 minutes')
# time: 497 ms (started: 2023-08-17 13:53:47 +00:00)

# %%
# traffic flow on 2008-05-21
pl = grouped_df[(grouped_df.index >= '2008-05-21 00:00:00') & (grouped_df.index < '2008-05-22 00:00:00')]

# create a custom dark color palette
dark_palette = sns.color_palette('dark', n_colors=8)

# plot the data
plt.figure(figsize=(15,5))
sns.lineplot(pl,x='Time Column',y='Traffic Flow',hue='3hour_interval',marker='o', palette=dark_palette,linewidth=2.5)
plt.title("Traffic Flow on 2008-05-21")
plt.xlabel("Time information every 30 minutes")
# Out:
# Text(0.5, 0, 'Time information every 30 minutes')
# time: 466 ms (started: 2023-08-17 13:53:48 +00:00)

# %%
# traffic flow on 2008-05-22
pl = grouped_df[(grouped_df.index >= '2008-05-22 00:00:00') & (grouped_df.index < '2008-05-23 00:00:00')]

# create a custom dark color palette
dark_palette = sns.color_palette('dark', n_colors=8)

# plot the data
plt.figure(figsize=(15,5))
sns.lineplot(pl,x='Time Column',y='Traffic Flow',hue='3hour_interval',marker='o', palette=dark_palette,linewidth=2.5)
plt.title("Traffic Flow on 2008-05-22")
plt.xlabel("Time information every 30 minutes")
# Out:
# Text(0.5, 0, 'Time information every 30 minutes')
# time: 468 ms (started: 2023-08-17 13:53:48 +00:00)

# %%
# traffic flow on 2008-05-23
pl = grouped_df[(grouped_df.index >= '2008-05-23 00:00:00') & (grouped_df.index < '2008-05-24 00:00:00')]

# create a custom dark color palette
dark_palette = sns.color_palette('dark', n_colors=8)

# plot the data
plt.figure(figsize=(15,5))
sns.lineplot(pl,x='Time Column',y='Traffic Flow',hue='3hour_interval',marker='o', palette=dark_palette,linewidth=2.5)
plt.title("Traffic Flow on 2008-05-23")
plt.xlabel("Time information every 30 minutes")
# Out:
# Text(0.5, 0, 'Time information every 30 minutes')
# time: 579 ms (started: 2023-08-17 13:53:49 +00:00)

# %%
# traffic flow on 2008-05-24
pl = grouped_df[(grouped_df.index >= '2008-05-24 00:00:00') & (grouped_df.index < '2008-05-25 00:00:00')]

# create a custom dark color palette
dark_palette = sns.color_palette('dark', n_colors=8)

# plot the data
plt.figure(figsize=(15,5))
sns.lineplot(pl,x='Time Column',y='Traffic Flow',hue='3hour_interval',marker='o', palette=dark_palette,linewidth=2.5)
plt.title("Traffic Flow on 2008-05-24")
plt.xlabel("Time information every 30 minutes")
# Out:
# Text(0.5, 0, 'Time information every 30 minutes')
# time: 478 ms (started: 2023-08-17 13:53:49 +00:00)

# %% [markdown]
# ##### Find highly correlated data in the dataset

# %%
plt.figure(figsize=(20,10))
sns.heatmap(time_series_weather.corr(), annot=True, cmap='viridis')
# Out:
# <Axes: >
# time: 6.92 s (started: 2023-08-17 13:53:50 +00:00)

# %% [markdown]
# Based on the above heatmap, we see that there are some features that are highly correlated. For example,
# temperature is correlated wiith humidity, windspeed, the hour of day, 3hour_interval and circular encoding of hour feature. Based on this heatmap above, we can choose the features that will be used in the final model.

# %% [markdown]
# ### Phase 5: Build machine learning models for traffic flow forecasting
# In this step, the following commands are executed:
# - Train and Test split
# - Find the best lookback timesteps for our XGBoost model
# - Perform Grid Search CV to find the optimum parameters for the XGBoost model
# - Train XGboost model (1)
# - Train an LSTM model (2)
# - Train a random forest model (3)
# - Perform Grid Search CV to find the optimum parameters for the random forest model
# - Train Encodel-Decoder model (4)
# - Visualise the losses for each model
# - Test on testing set for each model
# - Add in the same dataframe the RMSE and MAE scores of each model, in order to compare them
# - Make visualizations on actual vs predicted traffic flow data

# %% [markdown]
# #### Step 1: Train - Test split
# In this step, we split the data into two datasets, train and test.
# The time inteval of all observations in this dataset are within [18-05-2008, 24-05-2008].
# - Train dataset contains all the data for each path till 2008-05-23 inclusive.
# - The rest of the data (the most resent ones) are in the test dataset

# %%
# sort the time series data
time_series_weather.sort_values(by=['Path','Time Column'], inplace=True)
# Out:
# time: 630 ms (started: 2023-08-17 13:53:57 +00:00)

# %%
# define train data
train = time_series_weather.loc[time_series_weather['Time Column'] < '2008-05-24']

# define test data
test = time_series_weather.loc[time_series_weather['Time Column'] >= '2008-05-24']

# print the results
print("Train set shape: ",train.shape)
print("Test set shape: ",test.shape)
# Out:
# Train set shape:  (288000, 27)
# Test set shape:  (48000, 27)
# time: 363 ms (started: 2023-08-17 13:53:57 +00:00)

# %%
# redefine train and test sets based on correlated features (drop highly correlated features)
train = train.drop(['Time Column','hour', 'hour_sin','day_of_week_cos', 'dayofweek', 'day', 'minute'],axis=1)
test = test.drop(['Time Column','hour', 'hour_sin','day_of_week_cos', 'dayofweek', 'day', 'minute'],axis=1)
# Out:
# time: 68.3 ms (started: 2023-08-17 13:53:58 +00:00)

# %% [markdown]
# #### Step 2: Find the best lookback timesteps for our XGBoost model
# In this step, we define the optimum lookback timestep number for our sliding window. This optimum number will be used by the model for forecasting.

# %% [markdown]
# ##### Step 2a: Create empty dataframe to store the scores per lookback timesteps

# %%
# find best lookback timesteps to perform analysis. Save those scores in a separate dataframe
lookback_scores = pd.DataFrame(columns=['#Timesteps','XGBoost Score'])
lookback_scores['#Timesteps'] = 0
lookback_scores['XGBoost Score'] = 0
# Out:
# time: 8.55 ms (started: 2023-08-17 13:53:58 +00:00)

# %% [markdown]
# ##### Step 2b: Create function that converts the data into a supervised problem
# Consider for each path n_in timesteps of traffic flow in the past, in order to predict the n_out traffic flow timesteps in the future.

# %%
from pandas import DataFrame
from pandas import concat

# create functio for generating (X, y) pairs
def series_to_supervised(data, n_in=1, n_out=1):
    """
    Frame a time series as a supervised learning dataset.
    Arguments:
        data: Sequence of observations as a list or NumPy array.
        n_in: Number of lag observations as input (X).
        n_out: Number of observations as output (y).
        dropnan: Boolean whether or not to drop rows with NaN values.
    Returns:
        Pandas DataFrame of series framed for supervised learning.
    """
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('Traffic Flow %d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('Traffic Flow %d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('Traffic Flow %d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    return agg
# Out:
# time: 1.47 ms (started: 2023-08-17 13:53:58 +00:00)

# %%
"""
Convert the training data into a supervised dataset. Create X,y pairs of the traffic column information.
Then, concatenate the rest of the culumns.
"""
def generate_X_y_pairs(data,n_in=1,n_out=1):
    new_data = pd.DataFrame()
    for item in data['Path'].unique():

        # call function only for traffic flow columns
        supervised_traffic_flow = series_to_supervised(pd.DataFrame(data[data['Path'] == item]['Traffic Flow']), n_in, n_out)

        # the rest of the columns are concatenated as they were
        supervised_traffic_flow = pd.concat([supervised_traffic_flow, time_series_weather[time_series_weather['Path'] == item]], axis=1)

        new_data = pd.concat([new_data,supervised_traffic_flow])

    new_data.dropna(inplace=True)
    return new_data
# Out:
# time: 9.21 ms (started: 2023-08-17 13:53:58 +00:00)

# %% [markdown]
# ##### Step 2c: Create a loop. In each loop, we are doing the following:
# - 0. Convert train and test sets into supervised problem with lookback timesteps.
# - 1. Define features and labels.
# - 2. Train the XGboost model with defult parameters
# - 3. Predict on the test set
# - 4. Save RMSE in a dataframe

# %%
# import libraries
import xgboost as xgb
from sklearn.metrics import mean_absolute_error, mean_squared_error
# Out:
# time: 553 ms (started: 2023-08-17 13:53:58 +00:00)

# %%
for lookback in [2,3,4,5,6]: # different lookback sizes

    # convert train and test data to supervised
    train_s = generate_X_y_pairs(train,lookback)
    test_s = generate_X_y_pairs(test,lookback)

    print("Lookback = "+str(lookback)+" - To supervised: Completed!")

    # add rolling mean information
    train_s['rolling_mean'] = 0
    test_s['rolling_mean'] = 0

    train_s['rolling_mean'] = train_s.iloc[:,0:lookback].mean(axis=1)
    test_s['rolling_mean'] = test_s.iloc[:,0:lookback].mean(axis=1)

    # define features
    features_s = train_s.drop(['Time Column','Traffic Flow','Traffic Flow 1(t)'],axis=1).columns

    # define label
    labels_s = ['Traffic Flow 1(t)']

    # create X_train and y_train datasets
    X_train_s = train_s[features_s]
    y_train_s = train_s[labels_s]

    # create X_test and y_test datasets
    X_test_s = test_s[features_s]
    y_test_s = test_s[labels_s]

    print("Lookback = "+str(lookback)+" - Train and Test sets: Completed!")

    # define XGBoost regression model
    reg = xgb.XGBRegressor(objective='reg:squarederror',n_estimators=1000,early_stopping_rounds = 5)

    # train the XGBoost model with feature weights (use validation set on test data)
    reg.fit(X_train_s, y_train_s, eval_set=[(X_train_s, y_train_s), (X_test_s,y_test_s)],verbose=False)

    print("Lookback = "+str(lookback)+" - Trainning: Completed!")

    # make predictions
    y_pred_s = reg.predict(X_test_s)

    # calculate RMSE score
    rmse = mean_squared_error(y_test_s, y_pred_s, squared=False)

    # create a new row as a dictionary
    new_row = {'#Timesteps': lookback, 'XGBoost Score': rmse}

    # append the new row to the DataFrame
    lookback_scores = lookback_scores.append(new_row, ignore_index=True)

    print("Lookback = "+str(lookback)+" - Saved Results: Completed!")
# Out:
# Lookback = 2 - To supervised: Completed!
# Lookback = 2 - Train and Test sets: Completed!
# Lookback = 2 - Trainning: Completed!
# Lookback = 2 - Saved Results: Completed!
# Lookback = 3 - To supervised: Completed!
# Lookback = 3 - Train and Test sets: Completed!
# Lookback = 3 - Trainning: Completed!
# Lookback = 3 - Saved Results: Completed!
# Lookback = 4 - To supervised: Completed!
# Lookback = 4 - Train and Test sets: Completed!
# Lookback = 4 - Trainning: Completed!
# Lookback = 4 - Saved Results: Completed!
# Lookback = 5 - To supervised: Completed!
# Lookback = 5 - Train and Test sets: Completed!
# Lookback = 5 - Trainning: Completed!
# Lookback = 5 - Saved Results: Completed!
# Lookback = 6 - To supervised: Completed!
# Lookback = 6 - Train and Test sets: Completed!
# Lookback = 6 - Trainning: Completed!
# Lookback = 6 - Saved Results: Completed!
# time: 3min 51s (started: 2023-08-17 13:53:59 +00:00)

# %% [markdown]
# #####  Step 2d: Print RMSE scores over lookback timesteps into a graph

# %%
# plot the data
plt.plot(lookback_scores['#Timesteps'], lookback_scores['XGBoost Score'], linestyle='-', marker='o', color='b')

# set plot title and axis labels
plt.title('Lookback timesteps over RMSE score')
plt.xlabel('Lookback Timesteps of column Traffic Flow')
plt.ylabel('RMSE score after XGBoost testing')

# add gridlines
plt.grid(True)

# show the plot
plt.show()
# Out:
# time: 225 ms (started: 2023-08-17 13:57:50 +00:00)

# %%
# find the timesteps corresponding to the minimum RMSE score
optimum_lookback = int(lookback_scores['#Timesteps'].loc[lookback_scores['XGBoost Score'].idxmin()])
# Out:
# time: 1.03 ms (started: 2023-08-17 13:57:50 +00:00)

# %% [markdown]
# #### Step 3: Perform Grid Search CV to find the optimum parameters for the XGBoost model
# This step is essential to tune correctly the XGboost model.

# %% [markdown]
# ##### Step 3a: Split train and test into supervised problem, based on optimum lookback timesteps that found above.

# %%
# convert train and test data to supervised problem based in the optimum lookback step we defined above.
train = generate_X_y_pairs(train,optimum_lookback)
test = generate_X_y_pairs(test,optimum_lookback)
# Out:
# time: 32.9 s (started: 2023-08-17 13:57:50 +00:00)

# %% [markdown]
# ##### Step 3b: Extract features about trend of time series
# In this step we define the rolling mean and rolling variance of a window. Since we are trying to forecast the last value of each window, only the first optimum_lookback values in the window are used to compute rolling features. The last value (that we are trying to forecast) is not included.

# %%
# add rolling mean information
train['rolling_mean'] = 0
test['rolling_mean'] = 0

train['rolling_var'] = 0
test['rolling_var'] = 0

# calculate rolling mean of window
train['rolling_mean'] = train.iloc[:,0:optimum_lookback].mean(axis=1)
test['rolling_mean'] = test.iloc[:,0:optimum_lookback].mean(axis=1)

# calculate rolling variance of window
train['rolling_var'] = train.iloc[:, 0:optimum_lookback].var(axis=1)
test['rolling_var'] = test.iloc[:, 0:optimum_lookback].var(axis=1)
# Out:
# time: 94.6 ms (started: 2023-08-17 13:58:23 +00:00)

# %% [markdown]
# #####  Step 3c: Define labels and features
# - Features will help the XGboost algorithm to predict the output value, the label. We will use all the traffic flow information at previous timesteps (t-n,t-n+1...,t-2,t-1), as well as the rest of the features (time and trend information) as features.
# - Label will be out target value, the Traffic Flow at timestep t.

# %%
# define features
features = train.drop(['Time Column','Traffic Flow 1(t)','Traffic Flow','hour', 'hour_sin','day_of_week_cos', 'dayofweek', 'day', 'minute'],axis=1).columns

# define labels
labels = ['Traffic Flow 1(t)']

# create X_train and y_train data sets
X_train = train[features]
y_train = train[labels]

# create X_test and y_test data sets
X_test = test[features]
y_test = test[labels]
# Out:
# time: 81 ms (started: 2023-08-17 13:58:23 +00:00)

# %%
# show shape information about X and y training and testing sets
print("Shape of X_train is: ",X_train.shape)
print("Shape of y_train is: ",y_train.shape)
print("Shape of X_test is: ",X_test.shape)
print("Shape of y_test is: ",y_test.shape)
# Out:
# Shape of X_train is:  (282000, 27)
# Shape of y_train is:  (282000, 1)
# Shape of X_test is:  (42000, 27)
# Shape of y_test is:  (42000, 1)
# time: 2.31 ms (started: 2023-08-17 13:58:23 +00:00)

# %% [markdown]
# ##### Step 3d: Apply GridSearchCV
# Use a 5-fold K-fold cross-validation was used for learning the optimum hyperparameters for the XGBoost algorithm.

# %%
from sklearn.model_selection import GridSearchCV
# Out:
# time: 436 µs (started: 2023-08-17 13:58:23 +00:00)

# %%
# tune hyperparameters using XGboost
xgb_params = {
    "n_estimators": [500],
    "learning_rate": [0.1],
    "max_depth": [3,9],
    "objective":['reg:squarederror'],
    "gamma": [0,1,2],
    "alpha": [0,0.1,1]
}

# define GridSearchCV object
xgb_grid = GridSearchCV(xgb.XGBRegressor(),
                        xgb_params,cv=3,
                        verbose=1,
                        scoring= "neg_mean_squared_error")

# train on train data using 3 fold Cross Validation
xgb_grid.fit(X_train,y_train,
             early_stopping_rounds=5,
             eval_set=[(X_train, y_train), (X_test,y_test)],
             eval_metric='rmse')

# print the best hyperparameters and corresponding score
print("Best Hyperparameters: 
# [36]	validation_0-rmse:2.64162	validation_1-rmse:2.85691
# [37]	validation_0-rmse:2.63528	validation_1-rmse:2.85541
# [38]	validation_0-rmse:2.63030	validation_1-rmse:2.85541
# [39]	validation_0-rmse:2.62458	validation_1-rmse:2.85344
# [40]	validation_0-rmse:2.61519	validation_1-rmse:2.85312
# [41]	validation_0-rmse:2.61046	validation_1-rmse:2.85264
# [42]	validation_0-rmse:2.60414	validation_1-rmse:2.84928
# [43]	validation_0-rmse:2.60380	validation_1-rmse:2.85204
# [44]	validation_0-rmse:2.60161	validation_1-rmse:2.85314
# [45]	validation_0-rmse:2.59527	validation_1-rmse:2.85126
# [46]	validation_0-rmse:2.59670	validation_1-rmse:2.85428
# [0]	validation_0-rmse:7.05356	validation_1-rmse:6.39196
# [1]	validation_0-rmse:6.47843	validation_1-rmse:5.89560
# [2]	validation_0-rmse:5.97015	validation_1-rmse:5.45473
# [3]	validation_0-rmse:5.52208	validation_1-rmse:5.06876
# [4]	validation_0-rmse:5.12823	validation_1-rmse:4.73552
# [5]	validation_0-rmse:4.78349	validation_1-rmse:4.44518
# [6]	validation_0-rmse:4.48384	validation_1-rmse:4.19875
# [7]	validation_0-rmse:4.22209	validation_1-rmse:3.98685
# [8]	validation_0-rmse:3.99482	validation_1-rmse:3.79990
# [9]	validation_0-rmse:3.79923	validation_1-rmse:3.64195
# [10]	validation_0-rmse:3.63140	validation_1-rmse:3.50962
# [11]	validation_0-rmse:3.48818	validation_1-rmse:3.40130
# [12]	validation_0-rmse:3.36545	validation_1-rmse:3.30658
# [13]	validation_0-rmse:3.26063	validation_1-rmse:3.22695
# [14]	validation_0-rmse:3.16975	validation_1-rmse:3.16229
# [15]	validation_0-rmse:3.09454	validation_1-rmse:3.10842
# [16]	validation_0-rmse:3.02758	validation_1-rmse:3.05979
# [17]	validation_0-rmse:2.97279	validation_1-rmse:3.02520
# [18]	validation_0-rmse:2.92421	validation_1-rmse:2.99514
# [19]	validation_0-rmse:2.88456	validation_1-rmse:2.96629
# [20]	validation_0-rmse:2.84845	validation_1-rmse:2.94101
# [21]	validation_0-rmse:2.81763	validation_1-rmse:2.92464
# [22]	validation_0-rmse:2.78898	validation_1-rmse:2.91193
# [23]	validation_0-rmse:2.76610	validation_1-rmse:2.89734
# [24]	validation_0-rmse:2.74482	validation_1-rmse:2.88557
# [25]	validation_0-rmse:2.72556	validation_1-rmse:2.87557
# [26]	validation_0-rmse:2.71082	validation_1-rmse:2.86942
# [27]	validation_0-rmse:2.69609	validation_1-rmse:2.86202
# [28]	validation_0-rmse:2.68149	validation_1-rmse:2.85194
# [29]	validation_0-rmse:2.67028	validation_1-rmse:2.84688
# [30]	validation_0-rmse:2.66038	validation_1-rmse:2.84534
# [31]	validation_0-rmse:2.64920	validation_1-rmse:2.84130
# [32]	validation_0-rmse:2.63957	validation_1-rmse:2.83720
# [33]	validation_0-rmse:2.63138	validation_1-rmse:2.83688
# [34]	validation_0-rmse:2.62252	validation_1-rmse:2.83427
# [35]	validation_0-rmse:2.61512	validation_1-rmse:2.83186
# [36]	validation_0-rmse:2.60787	validation_1-rmse:2.82978
# [37]	validation_0-rmse:2.60156	validation_1-rmse:2.82947
# [38]	validation_0-rmse:2.59446	validation_1-rmse:2.82883
# [39]	validation_0-rmse:2.58771	validation_1-rmse:2.82812
# [40]	validation_0-rmse:2.58169	validation_1-rmse:2.82847
# [41]	validation_0-rmse:2.57682	validation_1-rmse:2.82724
# [42]	validation_0-rmse:2.57104	validation_1-rmse:2.82656
# [43]	validation_0-rmse:2.56615	validation_1-rmse:2.82540
# [44]	validation_0-rmse:2.56124	validation_1-rmse:2.82529
# [45]	validation_0-rmse:2.55793	validation_1-rmse:2.82568
# [46]	validation_0-rmse:2.55366	validation_1-rmse:2.82509
# [47]	validation_0-rmse:2.54964	validation_1-rmse:2.82400
# [48]	validation_0-rmse:2.54686	validation_1-rmse:2.82292
# [49]	validation_0-rmse:2.54264	validation_1-rmse:2.82315
# [50]	validation_0-rmse:2.53905	validation_1-rmse:2.82278
# [51]	validation_0-rmse:2.53582	validation_1-rmse:2.82284
# [52]	validation_0-rmse:2.52964	validation_1-rmse:2.82027
# [53]	validation_0-rmse:2.52717	validation_1-rmse:2.81913
# [54]	validation_0-rmse:2.52526	validation_1-rmse:2.81871
# [55]	validation_0-rmse:2.52286	validation_1-rmse:2.81921
# [56]	validation_0-rmse:2.51834	validation_1-rmse:2.81838
# [57]	validation_0-rmse:2.51564	validation_1-rmse:2.81759
# [58]	validation_0-rmse:2.51277	validation_1-rmse:2.81726
# [59]	validation_0-rmse:2.50836	validation_1-rmse:2.81753
# [60]	validation_0-rmse:2.50782	validation_1-rmse:2.81743
# [61]	validation_0-rmse:2.50685	validation_1-rmse:2.81686
# [62]	validation_0-rmse:2.50520	validation_1-rmse:2.81697
# [63]	validation_0-rmse:2.50179	validation_1-rmse:2.81751
# [64]	validation_0-rmse:2.49728	validation_1-rmse:2.81732
# [65]	validation_0-rmse:2.49338	validation_1-rmse:2.81755
# [66]	validation_0-rmse:2.49171	validation_1-rmse:2.81679
# [67]	validation_0-rmse:2.48853	validation_1-rmse:2.81782
# [68]	validation_0-rmse:2.48561	validation_1-rmse:2.81824
# [69]	validation_0-rmse:2.48279	validation_1-rmse:2.81827
# [70]	validation_0-rmse:2.47955	validation_1-rmse:2.81839
# [0]	validation_0-rmse:7.06204	validation_1-rmse:6.39219
# [1]	validation_0-rmse:6.49510	validation_1-rmse:5.89539
# [2]	validation_0-rmse:5.99295	validation_1-rmse:5.45950
# [3]	validation_0-rmse:5.55051	validation_1-rmse:5.08139
# [4]	validation_0-rmse:5.16165	validation_1-rmse:4.75097
# [5]	validation_0-rmse:4.81984	validation_1-rmse:4.46355
# [6]	validation_0-rmse:4.52349	validation_1-rmse:4.21636
# [7]	validation_0-rmse:4.26314	validation_1-rmse:4.00578
# [8]	validation_0-rmse:4.03839	validation_1-rmse:3.82378
# [9]	validation_0-rmse:3.84237	validation_1-rmse:3.67376
# [10]	validation_0-rmse:3.67399	validation_1-rmse:3.54413
# [11]	validation_0-rmse:3.53056	validation_1-rmse:3.43445
# [12]	validation_0-rmse:3.40401	validation_1-rmse:3.33713
# [13]	validation_0-rmse:3.29669	validation_1-rmse:3.25902
# [14]	validation_0-rmse:3.20573	validation_1-rmse:3.19674
# [15]	validation_0-rmse:3.12818	validation_1-rmse:3.14382
# [16]	validation_0-rmse:3.06131	validation_1-rmse:3.09943
# [17]	validation_0-rmse:3.00467	validation_1-rmse:3.06231
# [18]	validation_0-rmse:2.95581	validation_1-rmse:3.03102
# [19]	validation_0-rmse:2.91470	validation_1-rmse:3.00826
# [20]	validation_0-rmse:2.88020	validation_1-rmse:2.98873
# [21]	validation_0-rmse:2.84996	validation_1-rmse:2.97089
# [22]	validation_0-rmse:2.82287	validation_1-rmse:2.95791
# [23]	validation_0-rmse:2.79882	validation_1-rmse:2.94229
# [24]	validation_0-rmse:2.78076	validation_1-rmse:2.93259
# [25]	validation_0-rmse:2.76397	validation_1-rmse:2.92610
# [26]	validation_0-rmse:2.74975	validation_1-rmse:2.91850
# [27]	validation_0-rmse:2.73396	validation_1-rmse:2.91395
# [28]	validation_0-rmse:2.72163	validation_1-rmse:2.91034
# [29]	validation_0-rmse:2.70973	validation_1-rmse:2.90660
# [30]	validation_0-rmse:2.69936	validation_1-rmse:2.90088
# [31]	validation_0-rmse:2.68973	validation_1-rmse:2.89450
# [32]	validation_0-rmse:2.68174	validation_1-rmse:2.89017
# [33]	validation_0-rmse:2.67351	validation_1-rmse:2.88868
# [34]	validation_0-rmse:2.66384	validation_1-rmse:2.88624
# [35]	validation_0-rmse:2.65623	validation_1-rmse:2.88373
# [36]	validation_0-rmse:2.65024	validation_1-rmse:2.88167
# [37]	validation_0-rmse:2.64241	validation_1-rmse:2.88172
# [38]	validation_0-rmse:2.63735	validation_1-rmse:2.87935
# [39]	validation_0-rmse:2.63087	validation_1-rmse:2.87848
# [40]	validation_0-rmse:2.62660	validation_1-rmse:2.87787
# [41]	validation_0-rmse:2.62114	validation_1-rmse:2.87646
# [42]	validation_0-rmse:2.61681	validation_1-rmse:2.87552
# [43]	validation_0-rmse:2.61044	validation_1-rmse:2.87620
# [44]	validation_0-rmse:2.60865	validation_1-rmse:2.87739
# [45]	validation_0-rmse:2.60481	validation_1-rmse:2.87603
# [46]	validation_0-rmse:2.60195	validation_1-rmse:2.87613
# [47]	validation_0-rmse:2.59721	validation_1-rmse:2.87813
# [0]	validation_0-rmse:7.08921	validation_1-rmse:6.39188
# [1]	validation_0-rmse:6.54564	validation_1-rmse:5.89362
# [2]	validation_0-rmse:6.06817	validation_1-rmse:5.45406
# [3]	validation_0-rmse:5.64946	validation_1-rmse:5.07290
# [4]	validation_0-rmse:5.28105	validation_1-rmse:4.73737
# [5]	validation_0-rmse:4.96085	validation_1-rmse:4.44733
# [6]	validation_0-rmse:4.68466	validation_1-rmse:4.19642
# [7]	validation_0-rmse:4.44571	validation_1-rmse:3.98471
# [8]	validation_0-rmse:4.23999	validation_1-rmse:3.80063
# [9]	validation_0-rmse:4.06409	validation_1-rmse:3.64562
# [10]	validation_0-rmse:3.91458	validation_1-rmse:3.51816
# [4]	validation_0-rmse:5.14926	validation_1-rmse:4.74651
# [5]	validation_0-rmse:4.80889	validation_1-rmse:4.45990
# [6]	validation_0-rmse:4.51187	validation_1-rmse:4.21463
# [7]	validation_0-rmse:4.25346	validation_1-rmse:4.00497
# [8]	validation_0-rmse:4.02780	validation_1-rmse:3.81775
# [9]	validation_0-rmse:3.83250	validation_1-rmse:3.66400
# [10]	validation_0-rmse:3.66554	validation_1-rmse:3.53107
# [11]	validation_0-rmse:3.52301	validation_1-rmse:3.41910
# [12]	validation_0-rmse:3.39873	validation_1-rmse:3.32378
# [13]	validation_0-rmse:3.29342	validation_1-rmse:3.24454
# [14]	validation_0-rmse:3.20434	validation_1-rmse:3.17796
# [15]	validation_0-rmse:3.12843	validation_1-rmse:3.12112
# [16]	validation_0-rmse:3.06021	validation_1-rmse:3.07811
# [17]	validation_0-rmse:3.00576	validation_1-rmse:3.04170
# [18]	validation_0-rmse:2.95675	validation_1-rmse:3.01295
# [19]	validation_0-rmse:2.91442	validation_1-rmse:2.98728
# [20]	validation_0-rmse:2.87864	validation_1-rmse:2.96485
# [21]	validation_0-rmse:2.84635	validation_1-rmse:2.94411
# [22]	validation_0-rmse:2.82039	validation_1-rmse:2.92498
# [23]	validation_0-rmse:2.79480	validation_1-rmse:2.91351
# [24]	validation_0-rmse:2.77435	validation_1-rmse:2.90528
# [25]	validation_0-rmse:2.75413	validation_1-rmse:2.89612
# [26]	validation_0-rmse:2.73727	validation_1-rmse:2.88994
# [27]	validation_0-rmse:2.72273	validation_1-rmse:2.88227
# [28]	validation_0-rmse:2.71214	validation_1-rmse:2.88105
# [29]	validation_0-rmse:2.69993	validation_1-rmse:2.87793
# [30]	validation_0-rmse:2.68775	validation_1-rmse:2.87242
# [31]	validation_0-rmse:2.67808	validation_1-rmse:2.87174
# [32]	validation_0-rmse:2.66940	validation_1-rmse:2.87038
# [33]	validation_0-rmse:2.66220	validation_1-rmse:2.87004
# [34]	validation_0-rmse:2.65182	validation_1-rmse:2.86862
# [35]	validation_0-rmse:2.64392	validation_1-rmse:2.86568
# [36]	validation_0-rmse:2.63560	validation_1-rmse:2.86430
# [37]	validation_0-rmse:2.62820	validation_1-rmse:2.86081
# [38]	validation_0-rmse:2.62285	validation_1-rmse:2.86098
# [39]	validation_0-rmse:2.61574	validation_1-rmse:2.86084
# [40]	validation_0-rmse:2.61094	validation_1-rmse:2.86039
# [41]	validation_0-rmse:2.60558	validation_1-rmse:2.86335
# [42]	validation_0-rmse:2.60159	validation_1-rmse:2.86259
# [43]	validation_0-rmse:2.59776	validation_1-rmse:2.86255
# [44]	validation_0-rmse:2.59822	validation_1-rmse:2.86546
# [45]	validation_0-rmse:2.59458	validation_1-rmse:2.86357
# [0]	validation_0-rmse:7.05356	validation_1-rmse:6.39196
# [1]	validation_0-rmse:6.47843	validation_1-rmse:5.89560
# [2]	validation_0-rmse:5.97015	validation_1-rmse:5.45473
# [3]	validation_0-rmse:5.52208	validation_1-rmse:5.06875
# [4]	validation_0-rmse:5.12825	validation_1-rmse:4.73554
# [5]	validation_0-rmse:4.78350	validation_1-rmse:4.44520
# [6]	validation_0-rmse:4.48386	validation_1-rmse:4.19876
# [7]	validation_0-rmse:4.22253	validation_1-rmse:3.98366
# [8]	validation_0-rmse:3.99492	validation_1-rmse:3.79608
# [9]	validation_0-rmse:3.79910	validation_1-rmse:3.63982
# [10]	validation_0-rmse:3.63119	validation_1-rmse:3.50663
# [11]	validation_0-rmse:3.48716	validation_1-rmse:3.39700
# [12]	validation_0-rmse:3.36306	validation_1-rmse:3.30201
# [13]	validation_0-rmse:3.25923	validation_1-rmse:3.22083
# [14]	validation_0-rmse:3.16941	validation_1-rmse:3.15164
# [15]	validation_0-rmse:3.09332	validation_1-rmse:3.09778
# [16]	validation_0-rmse:3.02759	validation_1-rmse:3.04956
# [17]	validation_0-rmse:2.97098	validation_1-rmse:3.01345
# [18]	validation_0-rmse:2.92540	validation_1-rmse:2.98229
# [19]	validation_0-rmse:2.88575	validation_1-rmse:2.96012
# [20]	validation_0-rmse:2.84985	validation_1-rmse:2.93789
# [21]	validation_0-rmse:2.81853	validation_1-rmse:2.91940
# [22]	validation_0-rmse:2.79349	validation_1-rmse:2.90759
# [23]	validation_0-rmse:2.77025	validation_1-rmse:2.89578
# [24]	validation_0-rmse:2.74857	validation_1-rmse:2.88857
# [25]	validation_0-rmse:2.73165	validation_1-rmse:2.87924
# [26]	validation_0-rmse:2.71394	validation_1-rmse:2.86945
# [27]	validation_0-rmse:2.69794	validation_1-rmse:2.86357
# [28]	validation_0-rmse:2.68198	validation_1-rmse:2.85785
# [29]	validation_0-rmse:2.66885	validation_1-rmse:2.85437
# [30]	validation_0-rmse:2.65786	validation_1-rmse:2.84779
# [31]	validation_0-rmse:2.64724	validation_1-rmse:2.84812
# [32]	validation_0-rmse:2.63718	validation_1-rmse:2.84566
# [33]	validation_0-rmse:2.62821	validation_1-rmse:2.84202
# [34]	validation_0-rmse:2.62174	validation_1-rmse:2.84048
# [35]	validation_0-rmse:2.61387	validation_1-rmse:2.84128
# [36]	validation_0-rmse:2.60686	validation_1-rmse:2.83942
# [37]	validation_0-rmse:2.59701	validation_1-rmse:2.83888
# [38]	validation_0-rmse:2.59082	validation_1-rmse:2.83827
# [39]	validation_0-rmse:2.58547	validation_1-rmse:2.83736
# [40]	validation_0-rmse:2.57911	validation_1-rmse:2.83538
# [41]	validation_0-rmse:2.57321	validation_1-rmse:2.83506
# [42]	validation_0-rmse:2.56851	validation_1-rmse:2.83325
# [43]	validation_0-rmse:2.56184	validation_1-rmse:2.83464
# [44]	validation_0-rmse:2.55669	validation_1-rmse:2.83463
# [45]	validation_0-rmse:2.55398	validation_1-rmse:2.83418
# [46]	validation_0-rmse:2.54873	validation_1-rmse:2.83332
# [47]	validation_0-rmse:2.54515	validation_1-rmse:2.83127
# [48]	validation_0-rmse:2.54288	validation_1-rmse:2.83066
# [49]	validation_0-rmse:2.53727	validation_1-rmse:2.83110
# [50]	validation_0-rmse:2.53458	validation_1-rmse:2.83093
# [51]	validation_0-rmse:2.53066	validation_1-rmse:2.82987
# [52]	validation_0-rmse:2.52825	validation_1-rmse:2.82939
# [53]	validation_0-rmse:2.52588	validation_1-rmse:2.82928
# [54]	validation_0-rmse:2.52015	validation_1-rmse:2.82887
# [55]	validation_0-rmse:2.51731	validation_1-rmse:2.82854
# [56]	validation_0-rmse:2.51524	validation_1-rmse:2.82808
# [57]	validation_0-rmse:2.51369	validation_1-rmse:2.82813
# [58]	validation_0-rmse:2.51066	validation_1-rmse:2.82876
# [59]	validation_0-rmse:2.50573	validation_1-rmse:2.83008
# [60]	validation_0-rmse:2.50319	validation_1-rmse:2.82986
# [61]	validation_0-rmse:2.49892	validation_1-rmse:2.82938
# [0]	validation_0-rmse:7.06204	validation_1-rmse:6.39219
# [1]	validation_0-rmse:6.49510	validation_1-rmse:5.89539
# [2]	validation_0-rmse:5.99295	validation_1-rmse:5.45950
# [3]	validation_0-rmse:5.55051	validation_1-rmse:5.08139
# [4]	validation_0-rmse:5.16165	validation_1-rmse:4.75097
# [5]	validation_0-rmse:4.81984	validation_1-rmse:4.46356
# [6]	validation_0-rmse:4.52348	validation_1-rmse:4.21636
# [7]	validation_0-rmse:4.26313	validation_1-rmse:4.00577
# [8]	validation_0-rmse:4.03838	validation_1-rmse:3.82377
# [9]	validation_0-rmse:3.84236	validation_1-rmse:3.67375
# [10]	validation_0-rmse:3.67398	validation_1-rmse:3.54412
# [11]	validation_0-rmse:3.53056	validation_1-rmse:3.43444
# [12]	validation_0-rmse:3.40402	validation_1-rmse:3.33713
# [13]	validation_0-rmse:3.29674	validation_1-rmse:3.25904
# [14]	validation_0-rmse:3.20448	validation_1-rmse:3.19641
# [15]	validation_0-rmse:3.12461	validation_1-rmse:3.14690
# [16]	validation_0-rmse:3.05953	validation_1-rmse:3.10095
# [17]	validation_0-rmse:3.00288	validation_1-rmse:3.06353
# [18]	validation_0-rmse:2.95626	validation_1-rmse:3.03496
# [19]	validation_0-rmse:2.91397	validation_1-rmse:3.00911
# [20]	validation_0-rmse:2.87970	validation_1-rmse:2.98723
# [21]	validation_0-rmse:2.85063	validation_1-rmse:2.96966
# [22]	validation_0-rmse:2.82626	validation_1-rmse:2.95531
# [23]	validation_0-rmse:2.80124	validation_1-rmse:2.93892
# [24]	validation_0-rmse:2.78153	validation_1-rmse:2.92746
# [25]	validation_0-rmse:2.76650	validation_1-rmse:2.92044
# [26]	validation_0-rmse:2.75016	validation_1-rmse:2.91802
# [27]	validation_0-rmse:2.73321	validation_1-rmse:2.91048
# [28]	validation_0-rmse:2.71957	validation_1-rmse:2.90146
# [29]	validation_0-rmse:2.70707	validation_1-rmse:2.89861
# [30]	validation_0-rmse:2.69665	validation_1-rmse:2.89256
# [31]	validation_0-rmse:2.68794	validation_1-rmse:2.89419
# [32]	validation_0-rmse:2.67789	validation_1-rmse:2.88978
# [33]	validation_0-rmse:2.67034	validation_1-rmse:2.88921
# [34]	validation_0-rmse:2.66197	validation_1-rmse:2.88620
# [35]	validation_0-rmse:2.65583	validation_1-rmse:2.88509
# [36]	validation_0-rmse:2.64926	validation_1-rmse:2.88396
# [37]	validation_0-rmse:2.64270	validation_1-rmse:2.88467
# [31]	validation_0-rmse:3.10727	validation_1-rmse:2.88111
# [32]	validation_0-rmse:3.10277	validation_1-rmse:2.87908
# [33]	validation_0-rmse:3.09837	validation_1-rmse:2.87630
# [34]	validation_0-rmse:3.09256	validation_1-rmse:2.87362
# [35]	validation_0-rmse:3.08849	validation_1-rmse:2.87001
# [36]	validation_0-rmse:3.08513	validation_1-rmse:2.86824
# [37]	validation_0-rmse:3.07995	validation_1-rmse:2.86605
# [38]	validation_0-rmse:3.07649	validation_1-rmse:2.86544
# [39]	validation_0-rmse:3.07369	validation_1-rmse:2.86387
# [40]	validation_0-rmse:3.07156	validation_1-rmse:2.86294
# [41]	validation_0-rmse:3.06838	validation_1-rmse:2.86244
# [42]	validation_0-rmse:3.06652	validation_1-rmse:2.86130
# [43]	validation_0-rmse:3.06386	validation_1-rmse:2.86018
# [44]	validation_0-rmse:3.06211	validation_1-rmse:2.86083
# [45]	validation_0-rmse:3.05948	validation_1-rmse:2.86024
# [46]	validation_0-rmse:3.05557	validation_1-rmse:2.85693
# [47]	validation_0-rmse:3.05414	validation_1-rmse:2.85635
# [48]	validation_0-rmse:3.05229	validation_1-rmse:2.85786
# [49]	validation_0-rmse:3.05007	validation_1-rmse:2.85798
# [50]	validation_0-rmse:3.04855	validation_1-rmse:2.85774
# [51]	validation_0-rmse:3.04571	validation_1-rmse:2.85682
# [52]	validation_0-rmse:3.04318	validation_1-rmse:2.85414
# [53]	validation_0-rmse:3.03974	validation_1-rmse:2.85452
# [54]	validation_0-rmse:3.03843	validation_1-rmse:2.85451
# [55]	validation_0-rmse:3.03733	validation_1-rmse:2.85497
# [56]	validation_0-rmse:3.03529	validation_1-rmse:2.85254
# [57]	validation_0-rmse:3.03264	validation_1-rmse:2.85304
# [58]	validation_0-rmse:3.03205	validation_1-rmse:2.85318
# [59]	validation_0-rmse:3.03062	validation_1-rmse:2.85283
# [60]	validation_0-rmse:3.02930	validation_1-rmse:2.85213
# [61]	validation_0-rmse:3.02839	validation_1-rmse:2.85184
# [62]	validation_0-rmse:3.02745	validation_1-rmse:2.85127
# [63]	validation_0-rmse:3.02679	validation_1-rmse:2.85131
# [64]	validation_0-rmse:3.02409	validation_1-rmse:2.85126
# [65]	validation_0-rmse:3.02321	validation_1-rmse:2.85025
# [66]	validation_0-rmse:3.02247	validation_1-rmse:2.84991
# [67]	validation_0-rmse:3.02171	validation_1-rmse:2.85129
# [68]	validation_0-rmse:3.02084	validation_1-rmse:2.85095
# [69]	validation_0-rmse:3.02046	validation_1-rmse:2.85101
# [70]	validation_0-rmse:3.01940	validation_1-rmse:2.85056
# [71]	validation_0-rmse:3.01853	validation_1-rmse:2.85116
# [0]	validation_0-rmse:7.08871	validation_1-rmse:6.38555
# [1]	validation_0-rmse:6.54533	validation_1-rmse:5.88963
# [2]	validation_0-rmse:6.06626	validation_1-rmse:5.45147
# [3]	validation_0-rmse:5.64792	validation_1-rmse:5.06989
# [4]	validation_0-rmse:5.27900	validation_1-rmse:4.73346
# [5]	validation_0-rmse:4.95764	validation_1-rmse:4.44249
# [24]	validation_0-rmse:2.77238	validation_1-rmse:2.91412
# [25]	validation_0-rmse:2.75225	validation_1-rmse:2.90606
# [26]	validation_0-rmse:2.73381	validation_1-rmse:2.89898
# [27]	validation_0-rmse:2.72178	validation_1-rmse:2.89605
# [28]	validation_0-rmse:2.71090	validation_1-rmse:2.89103
# [29]	validation_0-rmse:2.69790	validation_1-rmse:2.88722
# [30]	validation_0-rmse:2.68700	validation_1-rmse:2.88143
# [31]	validation_0-rmse:2.67260	validation_1-rmse:2.87896
# [32]	validation_0-rmse:2.66348	validation_1-rmse:2.87717
# [33]	validation_0-rmse:2.65253	validation_1-rmse:2.87419
# [34]	validation_0-rmse:2.64309	validation_1-rmse:2.87226
# [35]	validation_0-rmse:2.63437	validation_1-rmse:2.87041
# [36]	validation_0-rmse:2.62629	validation_1-rmse:2.86816
# [37]	validation_0-rmse:2.61902	validation_1-rmse:2.86607
# [38]	validation_0-rmse:2.61728	validation_1-rmse:2.86794
# [39]	validation_0-rmse:2.61288	validation_1-rmse:2.86627
# [40]	validation_0-rmse:2.60869	validation_1-rmse:2.86354
# [41]	validation_0-rmse:2.60338	validation_1-rmse:2.86516
# [42]	validation_0-rmse:2.59663	validation_1-rmse:2.86757
# [43]	validation_0-rmse:2.59376	validation_1-rmse:2.86647
# [44]	validation_0-rmse:2.58882	validation_1-rmse:2.86686
# [45]	validation_0-rmse:2.58403	validation_1-rmse:2.86787
# [0]	validation_0-rmse:7.05349	validation_1-rmse:6.39279
# [1]	validation_0-rmse:6.47856	validation_1-rmse:5.89809
# [2]	validation_0-rmse:5.96960	validation_1-rmse:5.45649
# [3]	validation_0-rmse:5.52143	validation_1-rmse:5.07045
# [4]	validation_0-rmse:5.12837	validation_1-rmse:4.73464
# [5]	validation_0-rmse:4.78337	validation_1-rmse:4.44388
# [6]	validation_0-rmse:4.48283	validation_1-rmse:4.19735
# [7]	validation_0-rmse:4.22120	validation_1-rmse:3.98166
# [8]	validation_0-rmse:3.99410	validation_1-rmse:3.79539
# [9]	validation_0-rmse:3.79915	validation_1-rmse:3.63472
# [10]	validation_0-rmse:3.63141	validation_1-rmse:3.50385
# [11]	validation_0-rmse:3.48780	validation_1-rmse:3.39260
# [12]	validation_0-rmse:3.36461	validation_1-rmse:3.29648
# [13]	validation_0-rmse:3.25927	validation_1-rmse:3.21400
# [14]	validation_0-rmse:3.16991	validation_1-rmse:3.14984
# [15]	validation_0-rmse:3.09548	validation_1-rmse:3.09620
# [16]	validation_0-rmse:3.03029	validation_1-rmse:3.05144
# [17]	validation_0-rmse:2.97402	validation_1-rmse:3.01197
# [18]	validation_0-rmse:2.92635	validation_1-rmse:2.98230
# [19]	validation_0-rmse:2.88659	validation_1-rmse:2.95780
# [20]	validation_0-rmse:2.85169	validation_1-rmse:2.93699
# [21]	validation_0-rmse:2.82203	validation_1-rmse:2.92088
# [22]	validation_0-rmse:2.79429	validation_1-rmse:2.90901
# [23]	validation_0-rmse:2.76949	validation_1-rmse:2.89498
# [24]	validation_0-rmse:2.75087	validation_1-rmse:2.88741
# [25]	validation_0-rmse:2.73197	validation_1-rmse:2.88067
# [26]	validation_0-rmse:2.71525	validation_1-rmse:2.86974
# [27]	validation_0-rmse:2.70243	validation_1-rmse:2.86295
# [28]	validation_0-rmse:2.68892	validation_1-rmse:2.85511
# [29]	validation_0-rmse:2.67496	validation_1-rmse:2.85185
# [30]	validation_0-rmse:2.66406	validation_1-rmse:2.84693
# [31]	validation_0-rmse:2.65245	validation_1-rmse:2.84410
# [32]	validation_0-rmse:2.64343	validation_1-rmse:2.84091
# [33]	validation_0-rmse:2.63283	validation_1-rmse:2.83766
# [34]	validation_0-rmse:2.62630	validation_1-rmse:2.83698
# [35]	validation_0-rmse:2.61654	validation_1-rmse:2.83438
# [36]	validation_0-rmse:2.61124	validation_1-rmse:2.83404
# [37]	validation_0-rmse:2.60333	validation_1-rmse:2.83251
# [38]	validation_0-rmse:2.59863	validation_1-rmse:2.83054
# [39]	validation_0-rmse:2.59383	validation_1-rmse:2.83036
# [40]	validation_0-rmse:2.58821	validation_1-rmse:2.82881
# [41]	validation_0-rmse:2.58266	validation_1-rmse:2.82831
# [42]	validation_0-rmse:2.57758	validation_1-rmse:2.82818
# [43]	validation_0-rmse:2.57129	validation_1-rmse:2.82854
# [44]	validation_0-rmse:2.56755	validation_1-rmse:2.82805
# [45]	validation_0-rmse:2.56276	validation_1-rmse:2.82802
# [46]	validation_0-rmse:2.55885	validation_1-rmse:2.82658
# [47]	validation_0-rmse:2.55180	validation_1-rmse:2.82541
# [48]	validation_0-rmse:2.54712	validation_1-rmse:2.82552
# [49]	validation_0-rmse:2.54096	validation_1-rmse:2.82531
# [50]	validation_0-rmse:2.53846	validation_1-rmse:2.82465
# [51]	validation_0-rmse:2.53387	validation_1-rmse:2.82353
# [52]	validation_0-rmse:2.53186	validation_1-rmse:2.82340
# [53]	validation_0-rmse:2.52700	validation_1-rmse:2.82159
# [54]	validation_0-rmse:2.52331	validation_1-rmse:2.82047
# [55]	validation_0-rmse:2.52105	validation_1-rmse:2.82026
# [56]	validation_0-rmse:2.51607	validation_1-rmse:2.82081
# [57]	validation_0-rmse:2.51192	validation_1-rmse:2.82036
# [58]	validation_0-rmse:2.50887	validation_1-rmse:2.82078
# [59]	validation_0-rmse:2.50676	validation_1-rmse:2.82128
# [60]	validation_0-rmse:2.50572	validation_1-rmse:2.82137
# [0]	validation_0-rmse:7.06229	validation_1-rmse:6.39232
# [1]	validation_0-rmse:6.49575	validation_1-rmse:5.89328
# [2]	validation_0-rmse:5.99347	validation_1-rmse:5.45595
# [3]	validation_0-rmse:5.55127	validation_1-rmse:5.07871
# [4]	validation_0-rmse:5.16189	validation_1-rmse:4.74779
# [5]	validation_0-rmse:4.82122	validation_1-rmse:4.46234
# [6]	validation_0-rmse:4.52439	validation_1-rmse:4.22121
# [7]	validation_0-rmse:4.26468	validation_1-rmse:4.00726
# [8]	validation_0-rmse:4.03967	validation_1-rmse:3.83098
# [9]	validation_0-rmse:3.84372	validation_1-rmse:3.67990
# [10]	validation_0-rmse:3.67503	validation_1-rmse:3.55251
# [11]	validation_0-rmse:3.53164	validation_1-rmse:3.44458
# [12]	validation_0-rmse:3.40601	validation_1-rmse:3.35488
# [13]	validation_0-rmse:3.29955	validation_1-rmse:3.27789
# [14]	validation_0-rmse:3.21164	validation_1-rmse:3.21407
# [15]	validation_0-rmse:3.13431	validation_1-rmse:3.15945
# [16]	validation_0-rmse:3.06860	validation_1-rmse:3.11368
# [17]	validation_0-rmse:3.01324	validation_1-rmse:3.07564
# [18]	validation_0-rmse:2.96573	validation_1-rmse:3.04891
# [19]	validation_0-rmse:2.92377	validation_1-rmse:3.02209
# [20]	validation_0-rmse:2.88639	validation_1-rmse:2.99653
# [21]	validation_0-rmse:2.85673	validation_1-rmse:2.97766
# [22]	validation_0-rmse:2.82731	validation_1-rmse:2.96225
# [23]	validation_0-rmse:2.80494	validation_1-rmse:2.94509
# [24]	validation_0-rmse:2.78516	validation_1-rmse:2.93356
# [25]	validation_0-rmse:2.76623	validation_1-rmse:2.92305
# [26]	validation_0-rmse:2.75172	validation_1-rmse:2.91767
# [27]	validation_0-rmse:2.73750	validation_1-rmse:2.91327
# [28]	validation_0-rmse:2.72181	validation_1-rmse:2.90533
# [29]	validation_0-rmse:2.71100	validation_1-rmse:2.90109
# [30]	validation_0-rmse:2.70192	validation_1-rmse:2.89927
# [31]	validation_0-rmse:2.69190	validation_1-rmse:2.89220
# [32]	validation_0-rmse:2.68169	validation_1-rmse:2.89015
# [33]	validation_0-rmse:2.67374	validation_1-rmse:2.88652
# [34]	validation_0-rmse:2.66583	validation_1-rmse:2.88453
# [35]	validation_0-rmse:2.65621	validation_1-rmse:2.88221
# [36]	validation_0-rmse:2.64957	validation_1-rmse:2.88101
# [37]	validation_0-rmse:2.64023	validation_1-rmse:2.88170
# [38]	validation_0-rmse:2.63323	validation_1-rmse:2.87963
# [39]	validation_0-rmse:2.62759	validation_1-rmse:2.87772
# [40]	validation_0-rmse:2.62208	validation_1-rmse:2.87548
# [41]	validation_0-rmse:2.61854	validation_1-rmse:2.87790
# [42]	validation_0-rmse:2.61214	validation_1-rmse:2.87706
# [43]	validation_0-rmse:2.60889	validation_1-rmse:2.87655
# [44]	validation_0-rmse:2.60369	validation_1-rmse:2.87629
# [45]	validation_0-rmse:2.59837	validation_1-rmse:2.87796
# [0]	validation_0-rmse:7.05606	validation_1-rmse:6.39375
# [1]	validation_0-rmse:6.48238	validation_1-rmse:5.89755
# [2]	validation_0-rmse:5.97464	validation_1-rmse:5.45828
# [3]	validation_0-rmse:5.52732	validation_1-rmse:5.07473
# [4]	validation_0-rmse:5.13288	validation_1-rmse:4.73843
# [5]	validation_0-rmse:4.78830	validation_1-rmse:4.44836
# [6]	validation_0-rmse:4.48701	validation_1-rmse:4.19957
# [7]	validation_0-rmse:4.22449	validation_1-rmse:3.98270
# [8]	validation_0-rmse:3.99742	validation_1-rmse:3.80197
# [9]	validation_0-rmse:3.80093	validation_1-rmse:3.64694
# [10]	validation_0-rmse:3.63066	validation_1-rmse:3.51632
# [11]	validation_0-rmse:3.48473	validation_1-rmse:3.40265
# [12]	validation_0-rmse:3.35979	validation_1-rmse:3.31400
# [13]	validation_0-rmse:3.25259	validation_1-rmse:3.23308
# [14]	validation_0-rmse:3.16027	validation_1-rmse:3.16737
# [15]	validation_0-rmse:3.08197	validation_1-rmse:3.11636
# [16]	validation_0-rmse:3.01557	validation_1-rmse:3.07425
# [17]	validation_0-rmse:2.95702	validation_1-rmse:3.03417
# [18]	validation_0-rmse:2.90759	validation_1-rmse:3.00579
# [19]	validation_0-rmse:2.86535	validation_1-rmse:2.97885
# [20]	validation_0-rmse:2.82788	validation_1-rmse:2.95532
# [21]	validation_0-rmse:2.79370	validation_1-rmse:2.94184
# [22]	validation_0-rmse:2.76528	validation_1-rmse:2.92249
# [23]	validation_0-rmse:2.74029	validation_1-rmse:2.90781
# [24]	validation_0-rmse:2.71930	validation_1-rmse:2.89559
# [25]	validation_0-rmse:2.69898	validation_1-rmse:2.88602
# [26]	validation_0-rmse:2.68119	validation_1-rmse:2.88018
# [27]	validation_0-rmse:2.66495	validation_1-rmse:2.87370
# [28]	validation_0-rmse:2.64914	validation_1-rmse:2.86780
# [29]	validation_0-rmse:2.63526	validation_1-rmse:2.86128
# [30]	validation_0-rmse:2.62303	validation_1-rmse:2.85808
# [31]	validation_0-rmse:2.61244	validation_1-rmse:2.85546
# [32]	validation_0-rmse:2.60063	validation_1-rmse:2.85321
# [33]	validation_0-rmse:2.58981	validation_1-rmse:2.84914
# [34]	validation_0-rmse:2.58034	validation_1-rmse:2.84565
# [35]	validation_0-rmse:2.56976	validation_1-rmse:2.84537
# [36]	validation_0-rmse:2.56142	validation_1-rmse:2.84373
# [37]	validation_0-rmse:2.55488	validation_1-rmse:2.84436
# [38]	validation_0-rmse:2.54646	validation_1-rmse:2.84343
# [39]	validation_0-rmse:2.53951	validation_1-rmse:2.84228
# [40]	validation_0-rmse:2.53442	validation_1-rmse:2.83995
# [41]	validation_0-rmse:2.52722	validation_1-rmse:2.84262
# [42]	validation_0-rmse:2.52281	validation_1-rmse:2.84057
# [43]	validation_0-rmse:2.51797	validation_1-rmse:2.83991
# [44]	validation_0-rmse:2.51068	validation_1-rmse:2.83869
# [45]	validation_0-rmse:2.50506	validation_1-rmse:2.83966
# [46]	validation_0-rmse:2.49906	validation_1-rmse:2.83921
# [47]	validation_0-rmse:2.49521	validation_1-rmse:2.83882
# [48]	validation_0-rmse:2.49006	validation_1-rmse:2.83834
# [49]	validation_0-rmse:2.48522	validation_1-rmse:2.83885
# [50]	validation_0-rmse:2.48074	validation_1-rmse:2.83924
# [51]	validation_0-rmse:2.47461	validation_1-rmse:2.83958
# [52]	validation_0-rmse:2.46945	validation_1-rmse:2.83921
# [53]	validation_0-rmse:2.46414	validation_1-rmse:2.83918
# Best Hyperparameters:  {'alpha': 1, 'gamma': 1, 'learning_rate': 0.1, 'max_depth': 9, 'n_estimators': 500, 'objective': 'reg:squarederror'}
# Best Score:  -8.124477233899839
# time: 18min 16s (started: 2023-08-17 13:58:23 +00:00)

# %% [markdown]
# #### Step 4: Create dataframe to save actual values and model predictions

# %%
total_predictions = pd.DataFrame(index=pd.to_datetime(test['Time Column']))
total_predictions['Actual'] = y_test['Traffic Flow 1(t)'].values
total_predictions['Path'] = X_test['Path'].values
# Out:
# time: 14.7 ms (started: 2023-08-17 14:16:40 +00:00)

# %% [markdown]
# #### Step 5: Train an XGboost model
# We will fit all the data in this model using the optimum parameters we found above.

# %% [markdown]
# Create XGBoost model and train it

# %%
# define XGBoost regressor
reg = xgb.XGBRegressor(
    objective='reg:squarederror',
    n_estimators=500,
    early_stopping_rounds=5,
    max_depth=9 ,
    learning_rate=0.1,
    gamma=1,
    alpha=0.1
)

# train the XGBoost model with feature weights (use validation set on test data)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test,y_test)],
        verbose=True)
# Out:
# [0]	validation_0-rmse:7.05587	validation_1-rmse:6.39348
# [1]	validation_0-rmse:6.48189	validation_1-rmse:5.89698
# [2]	validation_0-rmse:5.97405	validation_1-rmse:5.45904
# [3]	validation_0-rmse:5.52622	validation_1-rmse:5.07593
# [4]	validation_0-rmse:5.13153	validation_1-rmse:4.74001
# [5]	validation_0-rmse:4.78667	validation_1-rmse:4.45262
# [6]	validation_0-rmse:4.48513	validation_1-rmse:4.20581
# [7]	validation_0-rmse:4.22310	validation_1-rmse:3.98620
# [8]	validation_0-rmse:3.99641	validation_1-rmse:3.80620
# [9]	validation_0-rmse:3.79988	validation_1-rmse:3.64931
# [10]	validation_0-rmse:3.62866	validation_1-rmse:3.51586
# [11]	validation_0-rmse:3.48341	validation_1-rmse:3.40705
# [12]	validation_0-rmse:3.35842	validation_1-rmse:3.32006
# [13]	validation_0-rmse:3.25008	validation_1-rmse:3.24397
# [14]	validation_0-rmse:3.15826	validation_1-rmse:3.17856
# [15]	validation_0-rmse:3.08109	validation_1-rmse:3.12149
# [16]	validation_0-rmse:3.01450	validation_1-rmse:3.07642
# [17]	validation_0-rmse:2.95676	validation_1-rmse:3.03646
# [18]	validation_0-rmse:2.90586	validation_1-rmse:3.00224
# [19]	validation_0-rmse:2.86193	validation_1-rmse:2.97676
# [20]	validation_0-rmse:2.82515	validation_1-rmse:2.95383
# [21]	validation_0-rmse:2.79198	validation_1-rmse:2.93376
# [22]	validation_0-rmse:2.76557	validation_1-rmse:2.91856
# [23]	validation_0-rmse:2.73807	validation_1-rmse:2.90787
# [24]	validation_0-rmse:2.71601	validation_1-rmse:2.89803
# [25]	validation_0-rmse:2.69668	validation_1-rmse:2.88945
# [26]	validation_0-rmse:2.68029	validation_1-rmse:2.88253
# [27]	validation_0-rmse:2.66273	validation_1-rmse:2.87657
# [28]	validation_0-rmse:2.64774	validation_1-rmse:2.87126
# [29]	validation_0-rmse:2.63506	validation_1-rmse:2.86836
# [30]	validation_0-rmse:2.62308	validation_1-rmse:2.86350
# [31]	validation_0-rmse:2.61281	validation_1-rmse:2.85869
# [32]	validation_0-rmse:2.60142	validation_1-rmse:2.85622
# [33]	validation_0-rmse:2.59236	validation_1-rmse:2.85383
# [34]	validation_0-rmse:2.58284	validation_1-rmse:2.85100
# [35]	validation_0-rmse:2.57133	validation_1-rmse:2.85038
# [36]	validation_0-rmse:2.56251	validation_1-rmse:2.84820
# [37]	validation_0-rmse:2.55459	validation_1-rmse:2.84617
# [38]	validation_0-rmse:2.54688	validation_1-rmse:2.84458
# [39]	validation_0-rmse:2.54044	validation_1-rmse:2.84195
# [40]	validation_0-rmse:2.53235	validation_1-rmse:2.84241
# [41]	validation_0-rmse:2.52669	validation_1-rmse:2.84107
# [42]	validation_0-rmse:2.52007	validation_1-rmse:2.84117
# [43]	validation_0-rmse:2.51648	validation_1-rmse:2.83923
# [44]	validation_0-rmse:2.51202	validation_1-rmse:2.83893
# [45]	validation_0-rmse:2.50634	validation_1-rmse:2.83929
# [46]	validation_0-rmse:2.50281	validation_1-rmse:2.83998
# [47]	validation_0-rmse:2.49638	validation_1-rmse:2.83867
# [48]	validation_0-rmse:2.49057	validation_1-rmse:2.83713
# [49]	validation_0-rmse:2.48419	validation_1-rmse:2.83630
# [50]	validation_0-rmse:2.47805	validation_1-rmse:2.83735
# [51]	validation_0-rmse:2.47226	validation_1-rmse:2.83600
# [52]	validation_0-rmse:2.46751	validation_1-rmse:2.83607
# [53]	validation_0-rmse:2.46293	validation_1-rmse:2.83581
# [54]	validation_0-rmse:2.45841	validation_1-rmse:2.83445
# [55]	validation_0-rmse:2.45440	validation_1-rmse:2.83323
# [56]	validation_0-rmse:2.45174	validation_1-rmse:2.83272
# [57]	validation_0-rmse:2.44749	validation_1-rmse:2.83248
# [58]	validation_0-rmse:2.44279	validation_1-rmse:2.83227
# [59]	validation_0-rmse:2.44111	validation_1-rmse:2.83104
# [60]	validation_0-rmse:2.43563	validation_1-rmse:2.83104
# [61]	validation_0-rmse:2.43065	validation_1-rmse:2.83036
# [62]	validation_0-rmse:2.42829	validation_1-rmse:2.82981
# [63]	validation_0-rmse:2.42356	validation_1-rmse:2.82992
# [64]	validation_0-rmse:2.42074	validation_1-rmse:2.82886
# [65]	validation_0-rmse:2.41821	validation_1-rmse:2.82820
# [66]	validation_0-rmse:2.41439	validation_1-rmse:2.82833
# [67]	validation_0-rmse:2.41203	validation_1-rmse:2.82770
# [68]	validation_0-rmse:2.40977	validation_1-rmse:2.82730
# [69]	validation_0-rmse:2.40282	validation_1-rmse:2.82548
# [70]	validation_0-rmse:2.39953	validation_1-rmse:2.82569
# [71]	validation_0-rmse:2.39547	validation_1-rmse:2.82591
# [72]	validation_0-rmse:2.39138	validation_1-rmse:2.82618
# [73]	validation_0-rmse:2.39006	validation_1-rmse:2.82648
# [74]	validation_0-rmse:2.38563	validation_1-rmse:2.82579
# XGBRegressor(alpha=0.1, base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=5,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=1, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=9, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=500, n_jobs=None, num_parallel_tree=None,
#              predictor=None, ...)
# time: 57.9 s (started: 2023-08-17 14:16:40 +00:00)

# %% [markdown]
# Feature Importance of XGBoost model
# Show how our model used the feautres, in order to perform splits.

# %%
# show how much each of the features was used in our regression analysis
plt.figure(figsize=(15,5))
fi = pd.DataFrame(data=reg.feature_importances_,index=reg.feature_names_in_,columns=['importance'])
fi.sort_values('importance').plot(kind='barh', title='Feature Importance')
plt.xlabel('Feature Importance')
plt.ylabel('Feature Name')
plt.show()
# Out:
# time: 390 ms (started: 2023-08-17 14:17:38 +00:00)

# %% [markdown]
# Plot train and validation errors of XGBoost model in the same graph

# %%
# acquire the values of train and validation errors
results = reg.evals_result()
train_errors = results['validation_0']['rmse']
validation_errors = results['validation_1']['rmse']

# plot the validation and training errors
plt.figure(figsize=(10, 6))
plt.plot(train_errors, label='Train Error (Train Set)')
plt.plot(validation_errors, label='Validation Error (Test Set)')
plt.xlabel('Number of Iterations')
plt.ylabel('RMSE score of XGBoost')
plt.title('XGBoost Model Training and Validation Errors')
plt.legend()
plt.show()
# Out:
# time: 250 ms (started: 2023-08-17 14:17:38 +00:00)

# %% [markdown]
# Make predictions on the test set

# %%
y_pred_xgboost = reg.predict(X_test)
# Out:
# time: 116 ms (started: 2023-08-17 14:17:38 +00:00)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# calculate the MAE of XGBoost model
mae_xgboost = mean_absolute_error(y_test, y_pred_xgboost)
print("Mae is: ",mae_xgboost)

# calculate RMSE score of XGBoost model
rmse_xgboost = mean_squared_error(y_test, y_pred_xgboost, squared=False)
print("RMSE score:", rmse_xgboost)
# Out:
# Mae is:  1.7473074360425207
# RMSE score: 2.8254786229281033
# time: 6.03 ms (started: 2023-08-17 14:17:39 +00:00)

# %% [markdown]
# Show example of how well the model learned the trainning data.
#
#
# Use a random path to visualize the results

# %%
# predict on the trainning set
y_pred_train = reg.predict(X_train)

# add information in the trainning set
train_predictions = pd.DataFrame(index=pd.to_datetime(train['Time Column']))
train_predictions.insert(0,'Train Actual',y_train['Traffic Flow 1(t)'].values)
train_predictions.insert(1,'Train Predicted',y_pred_train)
train_predictions.insert(2,'Path',X_train['Path'].values)

# plot an example of the train-predictions at path 0 of the datase
plt.figure(figsize=(15,5))
plt.plot(train_predictions[train_predictions['Path']==0]['Train Actual'],".-",label='Actual Values')
plt.plot(train_predictions[train_predictions['Path']==0]['Train Predicted'],".-",label='Predictions on train set using XGboost')
plt.xlabel('Time')
plt.ylabel('Traffic Flow in current path')
plt.title('Forecast on train set using XGBoost model')
plt.legend()
plt.show()
# Out:
# time: 948 ms (started: 2023-08-17 14:17:39 +00:00)

# %% [markdown]
# As we can see, the model has learned the trend and (almost) the seasonality of the data.
#
# Despite the non-linearity of Traffic Flow, XGBoost performs quite well!

# %% [markdown]
# Show an example of actual values vs predicted on test set

# %%
test_predictions = pd.DataFrame(index=pd.to_datetime(test['Time Column']))
test_predictions.insert(0,'Test Actual',y_test['Traffic Flow 1(t)'].values)
test_predictions.insert(1,'Test Predicted',y_pred_xgboost)
test_predictions.insert(2,'Path',X_test['Path'].values)

# plot an example of the train-predictions
plt.figure(figsize=(15,5))
plt.plot(test_predictions[test_predictions['Path']==0]['Test Actual'],".-",label='Actual Values')
plt.plot(test_predictions[test_predictions['Path']==0]['Test Predicted'],".-",label='Predicted Values from XGBoost')
plt.xlabel('Time information')
plt.ylabel('Traffic Flow in current path')
plt.title('Actual Values vs. Predicted on random Path of test set (XGBoost model)')
plt.legend()
plt.show()
# Out:
# time: 366 ms (started: 2023-08-17 14:17:40 +00:00)

# %% [markdown]
# #### Step 6: Train LSTM for time series forecasting
# This is the second model that we will train on the same dataset. We use the optimum lookback score that we computed above, before training the XGboost algorithm. This ensures that the LSTM model will be trained on the same data as the XGboost algorithm.

# %% [markdown]
# ##### Step 6a: Create the train and test sets as before, then scale them
# Use the same train and test sets as in the XGBoost model. In order to create more accurate predictions, we scale those two sets before giving them as input to the LSTM Recurrent Neural Network model.

# %%
# import library for data scaling
from sklearn.preprocessing import MinMaxScaler
# Out:
# time: 392 µs (started: 2023-08-17 14:17:40 +00:00)

# %%
# scale the data
scaler = MinMaxScaler()
X_tr = scaler.fit_transform(X_train)
X_te = scaler.fit_transform(X_test)

y_tr = scaler.fit_transform(y_train)
y_te = scaler.fit_transform(y_test)
# Out:
# time: 112 ms (started: 2023-08-17 14:17:40 +00:00)

# %%
# create 3D train set for LSTM
trainX = []
trainY = []

for i in range(len(X_tr)):
    trainX.append(X_tr[i:i+1,:])

for i in range(len(y_tr)):
    trainY.append(y_tr[i:i+1,:])

trainX, trainY = np.array(trainX), np.array(trainY)
# Out:
# time: 512 ms (started: 2023-08-17 14:17:40 +00:00)

# %%
# create 3D test set FOR LSTM
testX = []
testY = []

for i in range(len(X_te)):
    testX.append(X_te[i:i+1,:])

for i in range(len(y_te)):
    testY.append(y_te[i:i+1,:])

testX, testY = np.array(testX), np.array(testY)
# Out:
# time: 83 ms (started: 2023-08-17 14:17:41 +00:00)

# %%
# print shapes of the created sets
trainX.shape, trainY.shape, testX.shape, testY.shape
# Out:
# ((282000, 1, 27), (282000, 1, 1), (42000, 1, 27), (42000, 1, 1))
# time: 4.02 ms (started: 2023-08-17 14:17:41 +00:00)

# %% [markdown]
# ##### Step 6b: Use the LSTM model for forecasting

# %% [markdown]
# Import libraries and define the LSTM structure

# %%
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dropout
import tensorflow as tf
# Out:
# time: 2.65 s (started: 2023-08-17 14:17:41 +00:00)

# %% [markdown]
# In the LSTM model, we include dense layers to capture more complex non linear patterns and dropout layers to prevent overfitting.

# %%
# define LSTM model
model = Sequential()
model.add(LSTM(200, activation='relu', return_sequences=True, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dropout(0.2))

model.add(LSTM(100, activation='relu', return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(50, activation='relu', return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(25, activation='relu', return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(12, activation='relu', return_sequences=True))
model.add(Dropout(0.2))

# additional Dense layers
model.add(Dense(6, activation='relu'))
model.add(Dense(3, activation='linear'))

# output layer
model.add(Dense(trainY.shape[1]))

# add early stopping mechanism
early_stopping = EarlyStopping(patience=10, monitor='val_loss', restore_best_weights=True)
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# time: 3.72 s (started: 2023-08-17 14:17:43 +00:00)

# %% [markdown]
# Compile the model

# %%
# compile LSTM model
model.compile(optimizer='adam', loss='mse')
# Out:
# time: 15.5 ms (started: 2023-08-17 14:17:47 +00:00)

# %% [markdown]
# Train the model

# %%
# fit model on training data
history = model.fit(trainX, trainY,
          epochs=50,
          batch_size=len(trainX)//100,
          validation_data=(testX,testY),
          verbose=1,
          callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 100/100 [==============================] - 14s 20ms/step - loss: 0.0105 - val_loss: 0.0133
# Epoch 2/50
# 100/100 [==============================] - 2s 21ms/step - loss: 0.0101 - val_loss: 0.0131
# Epoch 3/50
# 100/100 [==============================] - 2s 21ms/step - loss: 0.0055 - val_loss: 0.0039
# Epoch 4/50
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0031 - val_loss: 0.0035
# Epoch 5/50
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0027 - val_loss: 0.0039
# Epoch 6/50
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0026 - val_loss: 0.0035
# Epoch 7/50
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0025 - val_loss: 0.0036
# Epoch 8/50
# 100/100 [==============================] - 1s 13ms/step - loss: 0.0025 - val_loss: 0.0035
# Epoch 9/50
# 100/100 [==============================] - 1s 13ms/step - loss: 0.0024 - val_loss: 0.0038
# Epoch 10/50
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0024 - val_loss: 0.0035
# Epoch 11/50
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0024 - val_loss: 0.0036
# Epoch 12/50
# 100/100 [==============================] - 2s 20ms/step - loss: 0.0023 - val_loss: 0.0036
# Epoch 13/50
# 100/100 [==============================] - 2s 21ms/step - loss: 0.0023 - val_loss: 0.0035
# Epoch 14/50
# 100/100 [==============================] - 1s 13ms/step - loss: 0.0023 - val_loss: 0.0035
# Epoch 15/50
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0023 - val_loss: 0.0036
# Epoch 16/50
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0023 - val_loss: 0.0035
# Epoch 17/50
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0023 - val_loss: 0.0035
# Epoch 18/50
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0023 - val_loss: 0.0035
# Epoch 19/50
# 100/100 [==============================] - 1s 13ms/step - loss: 0.0022 - val_loss: 0.0037
# Epoch 20/50
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0022 - val_loss: 0.0035
# Epoch 21/50
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0022 - val_loss: 0.0037
# Epoch 22/50
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0022 - val_loss: 0.0035
# Epoch 23/50
# 100/100 [==============================] - 2s 22ms/step - loss: 0.0022 - val_loss: 0.0034
# Epoch 24/50
# 100/100 [==============================] - 1s 14ms/step - loss: 0.0022 - val_loss: 0.0038
# Epoch 25/50
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0022 - val_loss: 0.0036
# Epoch 26/50
# 100/100 [==============================] - 1s 13ms/step - loss: 0.0022 - val_loss: 0.0035
# Epoch 27/50
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0022 - val_loss: 0.0037
# Epoch 28/50
# 100/100 [==============================] - 1s 13ms/step - loss: 0.0022 - val_loss: 0.0037
# Epoch 29/50
# 100/100 [==============================] - 1s 12ms/step - loss: 0.0022 - val_loss: 0.0036
# Epoch 30/50
# 100/100 [==============================] - 1s 13ms/step - loss: 0.0022 - val_loss: 0.0039
# Epoch 31/50
# 100/100 [==============================] - 1s 13ms/step - loss: 0.0022 - val_loss: 0.0036
# Epoch 32/50
# 100/100 [==============================] - 2s 20ms/step - loss: 0.0022 - val_loss: 0.0040
# Epoch 33/50
# 100/100 [==============================] - 2s 22ms/step - loss: 0.0021 - val_loss: 0.0036
# time: 1min (started: 2023-08-17 14:17:47 +00:00)

# %%
# evaluate model on test data
loss_lstm = model.evaluate(testX, testY)
print("Test Loss:", loss_lstm)
# Out:
# 1313/1313 [==============================] - 6s 4ms/step - loss: 0.0034
# Test Loss: 0.0034227571450173855
# time: 36.8 s (started: 2023-08-17 14:18:48 +00:00)

# %%
### PLOT TRAIN VS. VALIDATION LOSS OF LSTM MODEL ###

# extract training and validation losses from the history object
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# plot the losses
plt.figure(figsize=(15,5))
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss Value')
plt.title('Training Loss vs Validation Loss of LSTM model')
plt.legend()

# show the plot
plt.show()
# Out:
# time: 249 ms (started: 2023-08-17 14:19:25 +00:00)

# %% [markdown]
# Make predictions on test set

# %%
# predict on test data
y_pred_lstm = model.predict(testX)
y_pred_lstm = scaler.inverse_transform(y_pred_lstm.reshape(-1,1))
# Out:
# 1313/1313 [==============================] - 6s 4ms/step
# time: 6.73 s (started: 2023-08-17 14:19:25 +00:00)

# %% [markdown]
# Evaluate the LSTM model

# %%
# calculate the MAE score of LSTM model
mae_lstm = mean_absolute_error(scaler.inverse_transform(testY.reshape(-1,1)),y_pred_lstm)
print("Mae LSTM is: ",mae_lstm)

# Calculate the RMSE score of LSTM model
rmse_lstm = mean_squared_error(scaler.inverse_transform(testY.reshape(-1,1)), y_pred_lstm, squared=False)
print("RMSE LSTM score:", rmse_lstm)
# Out:
# Mae LSTM is:  2.0822281118290764
# RMSE LSTM score: 3.0422256481554037
# time: 6.44 ms (started: 2023-08-17 14:19:32 +00:00)

# %% [markdown]
# Show example of how well the LSTM captured/learned the train data

# %%
# predict on the trainning set
y_pred_train_LSTM = model.predict(trainX)

# add information in the trainning set
train_predictions = pd.DataFrame(index=pd.to_datetime(train['Time Column']))
train_predictions.insert(0,'Train Actual',y_train['Traffic Flow 1(t)'].values)
train_predictions.insert(1,'Train Predicted',scaler.inverse_transform(y_pred_train_LSTM.reshape(-1,1)))
train_predictions.insert(2,'Path',X_train['Path'].values)

# plot an example of the train-predictions
plt.figure(figsize=(15,5))
plt.plot(train_predictions[train_predictions['Path']==0][['Train Actual','Train Predicted']],".-")
plt.xlabel('Time')
plt.ylabel('Traffic Flow in current path')
plt.title('Forecast on train set using LSTM model')
plt.show()
# Out:
# 8813/8813 [==============================] - 41s 5ms/step
# time: 1min 22s (started: 2023-08-17 14:19:32 +00:00)

# %% [markdown]
# #### Step 7: Create Random Forest model
# This is the third model that we train on the same data, in order to forecast the traffic flow prediction. This algorithm is (almost) the same with the XGBoost, because both of them use decision trees to make forecasts.

# %%
# import Random Forest algorithm
from sklearn.ensemble import RandomForestRegressor
# Out:
# time: 230 ms (started: 2023-08-17 14:20:54 +00:00)

# %% [markdown]
# ##### Step 7a: Find optimum parameters for random forest

# %%
# define the parameter grid for the grid search
param_grid = {
    'max_depth': [5, 7],
    'min_samples_split': [5, 10],
    'n_estimators': [50]
}

# create the Random Forest model
rf_model = RandomForestRegressor(n_jobs=-1)

# create the GridSearchCV object
grid_search = GridSearchCV(rf_model, param_grid, cv=3, scoring='neg_mean_squared_error',verbose=1)

# fit the GridSearchCV object on the training data
grid_search.fit(X_train, y_train)

# get the best parameters and the best score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

# print the best parameters and the best score
print("Best Parameters:", best_params)
print("Best Score:", best_score)
# Out:
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# Best Parameters: {'max_depth': 7, 'min_samples_split': 5, 'n_estimators': 50}
# Best Score: -9.324666005255214
# time: 5min 2s (started: 2023-08-17 14:20:54 +00:00)

# %% [markdown]
# ##### Step 7b: Create and train the best random forest model that occured after grid search.

# %%
# get the best model after Grid Search
best_model = RandomForestRegressor(n_estimators=150,
                                  min_samples_split=10,
                                  max_depth=7,
                                  verbose=1,
                                  n_jobs=-1)
# Out:
# time: 467 µs (started: 2023-08-17 14:25:57 +00:00)

# %%
# train the best Random Forest model
best_model.fit(X_train,y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:   34.3s
# [Parallel(n_jobs=-1)]: Done 150 out of 150 | elapsed:  1.9min finished
# RandomForestRegressor(max_depth=7, min_samples_split=10, n_estimators=150,
#                       n_jobs=-1, verbose=1)
# time: 1min 53s (started: 2023-08-17 14:25:57 +00:00)

# %% [markdown]
# ##### Step 7c: Make predictions on train set

# %%
# make predictions on the test set
y_pred_rf = best_model.predict(X_test)
# Out:
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done  46 tasks      | elapsed:    0.1s
# time: 244 ms (started: 2023-08-17 14:27:50 +00:00)
# [Parallel(n_jobs=2)]: Done 150 out of 150 | elapsed:    0.2s finished

# %%
# predict on the trainning set using random forest
y_pred_train_rf = best_model.predict(X_train)

# add information in the trainning set
train_predictions = pd.DataFrame(index=pd.to_datetime(train['Time Column']))
train_predictions.insert(0,'Train Actual',y_train['Traffic Flow 1(t)'].values)
train_predictions.insert(1,'Train Predicted',y_pred_train_rf)
train_predictions.insert(2,'Path',X_train['Path'].values)

# plot an example of the train-predictions
plt.figure(figsize=(15,5))
plt.plot(train_predictions[train_predictions['Path']==0][['Train Actual','Train Predicted']],".-")
plt.xlabel('Time')
plt.ylabel('Traffic Flow in current path')
plt.title('Forecast on train set using random forest model')
plt.show()
# Out:
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done  46 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=2)]: Done 150 out of 150 | elapsed:    1.3s finished
# time: 1.64 s (started: 2023-08-17 14:27:51 +00:00)

# %% [markdown]
# ##### Step 7d: Evalueate the random forest regressor

# %%
# calculate the MAE
mae_rf = mean_absolute_error(y_test, y_pred_rf)
print("MAE: ", mae_rf)

# calculate the RMSE
rmse_rf = mean_squared_error(y_test, y_pred_rf, squared=False)
print("RMSE: ", rmse_rf)
# Out:
# MAE:  1.7818511866160638
# RMSE:  2.8730843934540458
# time: 8.73 ms (started: 2023-08-17 14:27:52 +00:00)

# %% [markdown]
# #### Step 8: Train an Encoder-Decoder model
# This is the fourth model that we are using, in order to forecast the traffic flow.

# %% [markdown]
# ##### Step 8a: Initialize and compile the Encoder-Decoder model

# %%
# add necessary imports
from keras import layers
# Out:
# time: 360 µs (started: 2023-08-17 14:27:52 +00:00)

# %%
# convert train and test set to infinite datasets for faster training
BATCH_SIZE = 1
BUFFER_SIZE = 1000

train_univariate = tf.data.Dataset.from_tensor_slices((trainX, trainY))
train_univariate = train_univariate.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()
val_univariate = tf.data.Dataset.from_tensor_slices((testX, testY))
val_univariate = val_univariate.batch(BATCH_SIZE).repeat()
# Out:
# time: 132 ms (started: 2023-08-17 14:27:52 +00:00)

# %%
### DEFINE THE ENCODER DECODER MODEL ###

# encoder part
enco_deco = Sequential()
enco_deco.add(LSTM(100, input_shape=(1, trainX.shape[2]), return_sequences=True))
enco_deco.add(Dropout(0.2))  # Add dropout to the first LSTM layer
enco_deco.add(LSTM(units=50, return_sequences=True))
enco_deco.add(Dropout(0.2))  # Add dropout to the second LSTM layer
enco_deco.add(LSTM(units=15))

# feature vector
enco_deco.add(layers.RepeatVector(1))

# decoder part
enco_deco.add(LSTM(units=100, return_sequences=True))
enco_deco.add(LSTM(units=50, return_sequences=True))
enco_deco.add(TimeDistributed(layers.Dense(units=1)))
# Out:
# time: 1.23 s (started: 2023-08-17 14:27:53 +00:00)

# %% [markdown]
# Similar to the LSTM model, we include dense layers to capture more complex non linear patterns and dropout layers to prevent overfitting.

# %%
#compile the encoder decoder model using adam optiizer
enco_deco.compile(optimizer='adam', loss='mse')
# Out:
# time: 9.82 ms (started: 2023-08-17 14:27:54 +00:00)

# %% [markdown]
# ##### Step 8b: Train the model and make predictions

# %%
# train the enco-deco model
history = enco_deco.fit(train_univariate,
                        epochs=50,
                        steps_per_epoch=len(trainX)//100,
                        validation_data=val_univariate,
                        validation_steps=len(testX)//100,
                        verbose=1,
                        callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 2820/2820 [==============================] - 43s 12ms/step - loss: 0.0041 - val_loss: 0.0060
# Epoch 2/50
# 2820/2820 [==============================] - 32s 11ms/step - loss: 0.0040 - val_loss: 0.0082
# Epoch 3/50
# 2820/2820 [==============================] - 34s 12ms/step - loss: 0.0021 - val_loss: 0.0075
# Epoch 4/50
# 2820/2820 [==============================] - 37s 13ms/step - loss: 0.0025 - val_loss: 0.0056
# Epoch 5/50
# 2820/2820 [==============================] - 31s 11ms/step - loss: 0.0013 - val_loss: 0.0055
# Epoch 6/50
# 2820/2820 [==============================] - 31s 11ms/step - loss: 0.0023 - val_loss: 0.0073
# Epoch 7/50
# 2820/2820 [==============================] - 35s 12ms/step - loss: 0.0034 - val_loss: 0.0083
# Epoch 8/50
# 2820/2820 [==============================] - 33s 12ms/step - loss: 0.0024 - val_loss: 0.0061
# Epoch 9/50
# 2820/2820 [==============================] - 31s 11ms/step - loss: 0.0016 - val_loss: 0.0057
# Epoch 10/50
# 2820/2820 [==============================] - 31s 11ms/step - loss: 0.0030 - val_loss: 0.0062
# Epoch 11/50
# 2820/2820 [==============================] - 33s 12ms/step - loss: 0.0078 - val_loss: 0.0077
# Epoch 12/50
# 2820/2820 [==============================] - 33s 12ms/step - loss: 0.0074 - val_loss: 0.0113
# Epoch 13/50
# 2820/2820 [==============================] - 31s 11ms/step - loss: 0.0029 - val_loss: 0.0097
# Epoch 14/50
# 2820/2820 [==============================] - 31s 11ms/step - loss: 0.0020 - val_loss: 0.0092
# Epoch 15/50
# 2820/2820 [==============================] - 32s 11ms/step - loss: 0.0016 - val_loss: 0.0065
# time: 8min 15s (started: 2023-08-17 14:27:54 +00:00)

# %%
# make predictions using Encoder-Decoder model
predicted_enco_deco = enco_deco.predict(testX)
predicted_enco_deco = scaler.inverse_transform(predicted_enco_deco.reshape(-1, 1))
# Out:
# 1313/1313 [==============================] - 7s 4ms/step
# time: 12.3 s (started: 2023-08-17 14:36:10 +00:00)

# %% [markdown]
# ##### Step 8c: Evaluate the model

# %%
# calculate MAE of Encoder - Decoder model
mae_enco_deco = mean_absolute_error(y_test, predicted_enco_deco)

# calculate RMSE Encoder - Decoder model
rmse_enco_deco = mean_squared_error(y_test, predicted_enco_deco, squared=False)

print("MAE:", mae_enco_deco)
print("RMSE:", rmse_enco_deco)
# Out:
# MAE: 2.6078326024725325
# RMSE: 3.6053520042997786
# time: 7.18 ms (started: 2023-08-17 14:36:22 +00:00)

# %% [markdown]
# Plot train loss vs. validation loss

# %%
# get the train loss and validation loss values and plot them in the same graph
loss = history.history['loss']
val_loss = history.history['val_loss']

# plot the loss and validation loss
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'b', label='Training Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')
plt.title('Training and Validation Loss of Encoder-Decoder model')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# time: 329 ms (started: 2023-08-17 14:36:22 +00:00)

# %% [markdown]
# Forecast on train set using Encoder-Decoder model

# %%
# predict on the trainning set
y_pred_train_enco_deco = enco_deco.predict(trainX)
y_pred_train_enco_deco = scaler.inverse_transform(y_pred_train_enco_deco.reshape(-1, 1))

# add information in the trainning set
train_predictions = pd.DataFrame(index=pd.to_datetime(train['Time Column']))
train_predictions.insert(0,'Train Actual',y_train['Traffic Flow 1(t)'].values)
train_predictions.insert(1,'Train Predicted',y_pred_train_enco_deco)
train_predictions.insert(2,'Path',X_train['Path'].values)

# plot an example of the train-predictions
plt.figure(figsize=(15,5))
plt.plot(train_predictions[train_predictions['Path']==0][['Train Actual','Train Predicted']],".-")
plt.xlabel('Time')
plt.ylabel('Traffic Flow in current path')
plt.title('Forecast on train set using Encoder-Decoder model')
plt.show()
# Out:
# 8813/8813 [==============================] - 37s 4ms/step
# time: 41.4 s (started: 2023-08-17 14:36:22 +00:00)

# %% [markdown]
# #### Step 9: Add predictions of the four models to the same dataframe

# %%
# store predictions of XGBoost model to a dataframe
total_predictions['Predicted XGBoost'] = y_pred_xgboost
# Out:
# time: 1.36 ms (started: 2023-08-17 14:37:04 +00:00)

# %%
# store predictions of LSTM model to a dataframe
total_predictions['Predicted LSTM'] = scaler.inverse_transform(y_pred_lstm.reshape(-1,1))
# Out:
# time: 1.8 ms (started: 2023-08-17 14:37:04 +00:00)

# %%
# add predictions of Random Forest model
total_predictions['Predicted Random Forest'] = y_pred_rf
# Out:
# time: 1.13 ms (started: 2023-08-17 14:37:04 +00:00)

# %%
# add predictions of Encoder-Decoder model
total_predictions['Predicted Encoder Decoder Model'] = predicted_enco_deco
# Out:
# time: 1.03 ms (started: 2023-08-17 14:37:04 +00:00)

# %%
# print dataframe with predictions
total_predictions
# Out:
#                      Actual  Path  Predicted XGBoost  Predicted LSTM  \
# Time Column
# 2008-05-24 03:00:00     4.0     0           7.477365      525.717590
# 2008-05-24 03:30:00     7.0     0           6.383580      469.815277
# 2008-05-24 04:00:00     3.0     0           5.999142      502.284546
# 2008-05-24 04:30:00     9.0     0           5.208226      419.234924
# 2008-05-24 05:00:00     7.0     0           6.004172      484.841522
# ...                     ...   ...                ...             ...
# 2008-05-24 21:30:00     0.0   999           0.489037       49.258148
# 2008-05-24 22:00:00     0.0   999           0.350342       43.433781
# 2008-05-24 22:30:00     1.0   999           0.337248       43.021954
# 2008-05-24 23:00:00     0.0   999           0.586868       50.829525
# 2008-05-24 23:30:00     0.0   999           0.225714       45.743107
#
#                      Predicted Random Forest  Predicted Encoder Decoder Model
# Time Column
# 2008-05-24 03:00:00                 8.303270                         9.597902
# 2008-05-24 03:30:00                 6.467181                         8.704425
# 2008-05-24 04:00:00                 6.379876                         8.703668
# 2008-05-24 04:30:00                 5.750079                         7.797598
# 2008-05-24 05:00:00                 5.940032                         8.603433
# ...                                      ...                              ...
# 2008-05-24 21:30:00                 0.444828                         2.183869
# 2008-05-24 22:00:00                 0.444828                         2.258195
# 2008-05-24 22:30:00                 0.444828                         2.284442
# 2008-05-24 23:00:00                 0.717612                         2.293266
# 2008-05-24 23:30:00                 0.277462                         2.177485
#
# [42000 rows x 6 columns]
# time: 25.3 ms (started: 2023-08-17 14:37:04 +00:00)

# %% [markdown]
# #### Step 10: Add in the same dataframe the RMSE and MAE scores of each model, in order to compare them

# %%
# create dataframe with scores
scores = pd.DataFrame(columns=['Model','RMSE Score','MAE Score'])

# define rows for dataframe
new_row = {'Model': 'XGBoost', 'RMSE Score': rmse_xgboost, 'MAE Score': mae_xgboost}
new_row1 = {'Model': 'LSTM', 'RMSE Score': rmse_lstm, 'MAE Score': mae_lstm}
new_row2 = {'Model': 'Random Forest', 'RMSE Score': rmse_rf, 'MAE Score': mae_rf}
new_row3 = {'Model': 'Encoder Decoder', 'RMSE Score': rmse_enco_deco, 'MAE Score': mae_enco_deco}

# add rows to dataframe
scores = scores.append(new_row, ignore_index=True)
scores = scores.append(new_row1, ignore_index=True)
scores = scores.append(new_row2, ignore_index=True)
scores = scores.append(new_row3, ignore_index=True)
# Out:
# time: 15.1 ms (started: 2023-08-17 14:37:04 +00:00)

# %%
# print dataframe with all model scores
scores
# Out:
#              Model  RMSE Score  MAE Score
# 0          XGBoost    2.825479   1.747307
# 1             LSTM    3.042226   2.082228
# 2    Random Forest    2.873084   1.781851
# 3  Encoder Decoder    3.605352   2.607833
# time: 11.2 ms (started: 2023-08-17 14:37:04 +00:00)

# %% [markdown]
# #### Step 11: Plot examples of actual vs Predicted for each of the models
# In this part, we select a random path of the dataset and compare (for each model) the actual Traffic Flow values vs. the predicted ones

# %%
# plot results from XGBoost model
plt.figure(figsize=(15,5))
plt.plot(total_predictions[total_predictions['Path']==0]['Actual'],label='Actuals')
plt.plot(total_predictions[total_predictions['Path']==0]['Predicted XGBoost'],label='Predicted')
plt.xlabel("Time information")
plt.ylabel('Traffic Flow values')
plt.title('Actual vs Predicted traffic flow values of path 0 using XGBoost model')
plt.legend()
plt.plot()
# Out:
# []
# time: 555 ms (started: 2023-08-17 14:37:04 +00:00)

# %%
# plot results from LSTM model
plt.figure(figsize=(15,5))
plt.plot(total_predictions[total_predictions['Path']==0]['Actual'],label='Actuals')
plt.plot(total_predictions[total_predictions['Path']==0]['Predicted LSTM'],label='Predicted')
plt.xlabel("Time information")
plt.ylabel('Traffic Flow values')
plt.title('Actual vs Predicted traffic flow values of path 0 using LSTM model')
plt.legend()
plt.plot()
# Out:
# []
# time: 476 ms (started: 2023-08-17 14:37:05 +00:00)

# %%
# plot results from Random Forest model
plt.figure(figsize=(15,5))
plt.plot(total_predictions[total_predictions['Path']==0]['Actual'],label='Actuals')
plt.plot(total_predictions[total_predictions['Path']==0]['Predicted Random Forest'],label='Predicted')
plt.xlabel("Time information")
plt.ylabel('Traffic Flow values')
plt.title('Actual vs Predicted traffic flow values of path 0 using Random Forest model')
plt.legend()
plt.plot()
# Out:
# []
# time: 593 ms (started: 2023-08-17 14:37:05 +00:00)

# %%
# plot results from Encoder-Decoder model
plt.figure(figsize=(15,5))
plt.plot(total_predictions[total_predictions['Path']==0]['Actual'],label='Actuals')
plt.plot(total_predictions[total_predictions['Path']==0]['Predicted Encoder Decoder Model'],label='Predicted')
plt.xlabel("Time information")
plt.ylabel('Traffic Flow values')
plt.title('Actual vs Predicted traffic flow values of path 0 using Encoder-Decoder model model')
plt.legend()
plt.plot()
# Out:
# []
# time: 595 ms (started: 2023-08-17 14:37:06 +00:00)

# %% [markdown]
# #### Step 12: Make visualizations on actual vs predicted traffic flow data
# Use best model's predictions from total_predictions dataframe and plot the residuals between the actual traffic flow values and predicted ones.
#
# The graph to be created will contain the sum of traffic flow per timestamp, as done before in the visualization step.

# %%
# groupe dataframe by timestamp
grouped = total_predictions.groupby(total_predictions.index).sum()

# add results to dataframe
grouped = pd.DataFrame(grouped,index=grouped.index)

# drop path column, as it is useless in this step
grouped.drop('Path', axis=1, inplace=True)
# Out:
# time: 14.4 ms (started: 2023-08-17 14:37:06 +00:00)

# %% [markdown]
# ##### Decide which model's predicted values will be used, based on the best RMSE score

# %%
# find the model with the best RMSE score (has the lowest RMSE value)
index = scores[['RMSE Score']].idxmin()
# Out:
# time: 2.43 ms (started: 2023-08-17 14:37:06 +00:00)

# %%
if (scores.iloc[index]['Model'][0] == 'XGBoost'):
    # create a plot to view the results
    plt.figure(figsize=(15,5))
    sns.lineplot(grouped,x=grouped.index,y='Actual',marker='o',linewidth=2.5,label='Actual')
    sns.lineplot(grouped,x=grouped.index,y='Predicted XGBoost',marker='o',linewidth=2.5, color='orange',label='XGboost')
    plt.xlabel('Time')
    plt.ylabel('Sum of Traffic Flow')
    plt.title('Sum of Traffic Flow in Every Path of the Dataset Over Time vs Predicted')
    plt.show()

    # save the model to a file
    reg.save_model('/content/drive/MyDrive/Colab Notebooks/San Francisco TF Pred/Preprocessing_Forecasting/Data/xgboost_model.model')

elif (scores.iloc[index]['Model'][0] == 'LSTM'):
      # create a plot to view the results
      plt.figure(figsize=(15,5))
      sns.lineplot(grouped,x=grouped.index,y='Actual',marker='o',linewidth=2.5,label='Actual')
      sns.lineplot(grouped,x=grouped.index,y='Predicted XGBoost',marker='o',linewidth=2.5, color='orange',label='XGboost')
      plt.xlabel('Time')
      plt.ylabel('Sum of Traffic Flow')
      plt.title('Sum of Traffic Flow in Every Path of the Dataset Over Time vs Predicted')
      plt.show()

      # Save the model to a file
      model.save('lstm_model.h5')

elif (scores.iloc[index]['Model'][0] == 'Random Forest'):
    # create a plot to view the results
      plt.figure(figsize=(15,5))
      sns.lineplot(grouped,x=grouped.index,y='Actual',marker='o',linewidth=2.5,label='Actual')
      sns.lineplot(grouped,x=grouped.index,y='Predicted XGBoost',marker='o',linewidth=2.5, color='orange',label='XGboost')
      plt.xlabel('Time')
      plt.ylabel('Sum of Traffic Flow')
      plt.title('Sum of Traffic Flow in Every Path of the Dataset Over Time vs Predicted')
      plt.show()

      # save model
      import joblib
      joblib.dump(best_model, 'random_forest_model.pkl')

elif (scores.iloc[index]['Model'][0] == 'Encoder Decoder'):
    # create a plot to view the results
      plt.figure(figsize=(15,5))
      sns.lineplot(grouped,x=grouped.index,y='Actual',marker='o',linewidth=2.5,label='Actual')
      sns.lineplot(grouped,x=grouped.index,y='Predicted XGBoost',marker='o',linewidth=2.5, color='orange',label='XGboost')
      plt.xlabel('Time')
      plt.ylabel('Sum of Traffic Flow')
      plt.title('Sum of Traffic Flow in Every Path of the Dataset Over Time vs Predicted')
      plt.show()

      # save the model to a file
      enco_deco.save('encoder_decoder_model.h5')
# Out:
# time: 1.44 s (started: 2023-08-17 14:54:09 +00:00)
