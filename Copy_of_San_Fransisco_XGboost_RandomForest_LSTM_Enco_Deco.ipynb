# %% [markdown]
# <a href="https://colab.research.google.com/github/stratoskar/Diploma_Thesis/blob/main/Copy_of_San_Fransisco_XGboost_RandomForest_LSTM_Enco_Deco.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Phase 4: Build XGboost machine learning model for traffic flow forecast

# %%
# measure execution time
#%load_ext autotime

# disable warnings
import warnings
warnings.filterwarnings('ignore')

# standard library imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

# %% [markdown]
# ### Load the time series traffic flow dataset
# In this step we are doing the following operations:
# - Read the data
# - Change the name of columns

# %%
# Access Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Google Drive path with the time series data
time_series_file_path = '/content/drive/MyDrive/Colab Notebooks/San Francisco TF Pred/Data/time_series.txt'

# %%
# read dataset
time_series = pd.read_csv(time_series_file_path)

# this list contains the column names
columns = ["Taxi ID","Traj ID","Path","Length"]

# generate the columns of the dataset
i =4
while(True):
    if i == 4:
        columns.append(pd.to_datetime('2008-05-18 00:00:00'))
    else:
        columns.append(columns[i-1] + timedelta(seconds=1800))

    if (columns[i]>=pd.to_datetime('2008-05-24 23:59:59.000130')):
        break

    i+=1

# delete the last timestamp
columns.pop()

# assign new column names to our dataframe
time_series.columns = columns

# %% [markdown]
# ### Transform the time series dataset
# In this step we are doing the following operations:
# - Reshape it to long format using melt function
# - Encode categorical values
# - Preprocess the data types of each column

# %%
# reshape the data from wide format to long format
id_cols = ['Taxi ID','Traj ID', 'Path', 'Length']
time_cols = time_series.iloc[:,2:].columns
time_series = time_series.melt(id_vars=id_cols, value_vars=time_cols, var_name='Time Column', value_name='Traffic Flow')
time_series['Time Column'] = pd.to_datetime(time_series['Time Column'])

# sort rows by Path and Time
time_series.sort_values(by=['Path','Time Column'],inplace=True)

# %%
# convert path column from categorical to numerical
from sklearn.preprocessing import LabelEncoder

# create an instance of LabelEncoder
label_encoder = LabelEncoder()

# fit label encoder on the 'Path' column
time_series['Path'] = label_encoder.fit_transform(time_series['Path'])

# sort the data based in Path column
time_series = time_series.sort_values(by=['Path','Time Column'])

# print data
time_series.head()
# Out:
#       Taxi ID  Traj ID  Path  Length         Time Column  Traffic Flow
# 593        97      297     0       8 2008-05-18 00:00:00             4
# 1593       97      297     0       8 2008-05-18 00:30:00             4
# 2593       97      297     0       8 2008-05-18 01:00:00             4
# 3593       97      297     0       8 2008-05-18 01:30:00             2
# 4593       97      297     0       8 2008-05-18 02:00:00             9

# %% [markdown]
# ### Weather data
# In the weather dataset of San Francisco area, there are many columns that are useless for our research. We just drop them and preprocess the dataset.
#
# In this step we are doing the following operations:
# - Read the weather data
# - Drop uneccessary informatio n
# - Encode categorical attributes
# - Fill Nan values

# %%
# Google Drive path with the weather data
file_path_weather_data = '/content/drive/MyDrive/Colab Notebooks/San Francisco TF Pred/Data/weather_data.csv'

# %%
# read weather data
weather_data = pd.read_csv(file_path_weather_data,sep=',')

# drop unecessary columns.
# dropped columns can either have NaN values, or not be associated with traffic flow.
# columns kept: temperature, humidity, windspeed, sealevelpressure, visibility
weather_data = weather_data.drop(['name','feelslike','dew','precip','precipprob','preciptype',
                                  'snow','snowdepth','windgust','winddir','cloudcover',
                                  'solarradiation','solarenergy','uvindex','severerisk','stations','icon'],axis=1)

# %% [markdown]
# There is one column that contains categorical vales. Use one-hot encoding to represent them as numerical vectors.

# %%
# view the values of "conditions" column
weather_data['conditions'].value_counts()
# Out:
# Partially cloudy    435
# Clear               166
# Overcast            142
# Rain, Overcast        1
# Name: conditions, dtype: int64

# %%
# change the only 'Rain, Overcast' value to 'Overcast'
weather_data.loc[weather_data['conditions'] == 'Rain, Overcast', 'conditions'] = 'Overcast'

# %%
# view again the values of "conditions" column
weather_data['conditions'].value_counts()
# Out:
# Partially cloudy    435
# Clear               166
# Overcast            143
# Name: conditions, dtype: int64

# %%
# one-hot encode the  "conditions" column
conditions = pd.get_dummies(weather_data['conditions'], prefix='conditions')
weather_data.drop('conditions',axis=1,inplace=True)

# concatenate the one-hot encoded columns to the original DataFrame
weather_data = pd.concat([weather_data, conditions], axis=1)

# %% [markdown]
# Now, there are not categorical values.

# %%
# view for null values
weather_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 744 entries, 0 to 743
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   datetime                     744 non-null    object
#  1   temp                         744 non-null    float64
#  2   humidity                     744 non-null    float64
#  3   windspeed                    744 non-null    float64
#  4   sealevelpressure             744 non-null    float64
#  5   visibility                   744 non-null    float64
#  6   conditions_Clear             744 non-null    uint8
#  7   conditions_Overcast          744 non-null    uint8
#  8   conditions_Partially cloudy  744 non-null    uint8
# dtypes: float64(5), object(1), uint8(3)
# memory usage: 37.2+ KB

# %% [markdown]
# There are not null values in the weather dataset too!

# %%
# covnert datetime column to appropriate format
weather_data['datetime'] = pd.to_datetime(weather_data['datetime'])

# drop rows that are not in within the interval [2008-05-18,2008-05-24]
start_date = pd.to_datetime('2008-05-18')
end_date = pd.to_datetime('2008-05-25')

weather_data = weather_data[(weather_data['datetime'] >= start_date) & (weather_data['datetime'] <= end_date)].reset_index(drop=True)

# %% [markdown]
# ### Connect the two dataframes to one
# Use time information to correctly connect the weather data and traffic flow data together.

# %%
# connect two dataframes, time-series traffic flow and weather data
time_series.set_index('Time Column', inplace=True)
weather_data.set_index('datetime', inplace=True)

# resample the 'weather_data' dataset to 30-minute intervals and forward-fill the missing values
weather_data = weather_data.resample('30T').ffill()

# merge the time_series and weather_data_resampled datasets based on their indexes
time_series_weather = time_series.merge(weather_data, left_index=True, right_index=True)

# %% [markdown]
# ### Feature Creation From Time Information
# In this step we define some features based on time series timestamps.
# - Day, dayfweek, hour and minute features derive directly from the timestamp column of the dataset.
# - Hour_sin and Hour_cos columns transform the hour values into a cyclic representation, where the values range from -1 to 1. This transformation is used in time series analysis to capture the periodic patterns or cyclical nature of time-related data.
# - Use also the 3_hour_interval to describe, in which interval of the day data refer to.

# %%
time_series_weather = time_series_weather.reset_index()
time_series_weather.rename(columns={'index': 'Time Column'}, inplace=True)

# %%
### extract timestamp information to different columns ###

time_series_weather['hour'] = time_series_weather['Time Column'].dt.hour
time_series_weather['dayofweek'] = time_series_weather['Time Column'].dt.dayofweek
time_series_weather['day'] = time_series_weather['Time Column'].dt.day
time_series_weather['minute'] = time_series_weather['Time Column'].dt.minute

### circular Encoding for cyclic time features ###

time_series_weather['hour_sin'] = np.sin(2 * np.pi * time_series_weather['hour'] / 24)
time_series_weather['hour_cos'] = np.cos(2 * np.pi * time_series_weather['hour'] / 24)

time_series_weather['day_of_week_sin'] = np.sin(2 * np.pi * time_series_weather['dayofweek'] / 7)
time_series_weather['day_of_week_cos'] = np.cos(2 * np.pi * time_series_weather['dayofweek'] / 7)

time_series_weather['day_sin'] = np.sin(2 * np.pi * time_series_weather['day'] / 31)
time_series_weather['day_cos'] = np.cos(2 * np.pi * time_series_weather['day'] / 31)

time_series_weather['minute_sin'] = np.sin(2 * np.pi * time_series_weather['minute'] / 60)
time_series_weather['minute_cos'] = np.cos(2 * np.pi * time_series_weather['minute'] / 60)

# %%
# define a custom function to determine the three-hour interval, based in timestamp hour information
def get_3hour_interval(hour):
    if hour in [0, 1, 2]:
        return 1
    elif hour in [3, 4, 5]:
        return 2
    elif hour in [6, 7, 8]:
        return 3
    elif hour in [9, 10, 11]:
        return 4
    elif hour in [12, 13, 14]:
        return 5
    elif hour in [15, 16, 17]:
        return 6
    elif hour in [18, 19, 20]:
        return 7
    elif hour in [21, 22, 23]:
        return 8
    else:
        return None

# %%
# apply the custom function on the data to create the '3hour_interval' column
time_series_weather['3hour_interval'] = time_series_weather['hour'].apply(get_3hour_interval)

# %%
# print dataset
time_series_weather
# Out:
#                Time Column  Taxi ID  Traj ID  Path  Length  Traffic Flow  \
# 0      2008-05-18 00:00:00       97      297     0       8             4
# 1      2008-05-18 00:00:00        2       83     1       3             4
# 2      2008-05-18 00:00:00      247      370     2      10             7
# 3      2008-05-18 00:00:00      327       78     3       2             5
# 4      2008-05-18 00:00:00      363       56     4      11             0
# ...                    ...      ...      ...   ...     ...           ...
# 335995 2008-05-24 23:30:00      403      113   995       6             2
# 335996 2008-05-24 23:30:00      477       44   996       9             0
# 335997 2008-05-24 23:30:00      135      125   997       2             3
# 335998 2008-05-24 23:30:00      192      164   998      12             0
# 335999 2008-05-24 23:30:00      468      131   999       4             1
#
#         temp  humidity  windspeed  sealevelpressure  ...  minute  hour_sin  \
# 0       12.4     87.29       16.1            1017.7  ...       0  0.000000
# 1       12.4     87.29       16.1            1017.7  ...       0  0.000000
# 2       12.4     87.29       16.1            1017.7  ...       0  0.000000
# 3       12.4     87.29       16.1            1017.7  ...       0  0.000000
# 4       12.4     87.29       16.1            1017.7  ...       0  0.000000
# ...      ...       ...        ...               ...  ...     ...       ...
# 335995  12.4     72.31       10.5            1015.0  ...      30 -0.258819
# 335996  12.4     72.31       10.5            1015.0  ...      30 -0.258819
# 335997  12.4     72.31       10.5            1015.0  ...      30 -0.258819
# 335998  12.4     72.31       10.5            1015.0  ...      30 -0.258819
# 335999  12.4     72.31       10.5            1015.0  ...      30 -0.258819
#
#         hour_cos  day_of_week_sin  day_of_week_cos   day_sin   day_cos  \
# 0       1.000000        -0.781831         0.623490 -0.485302 -0.874347
# 1       1.000000        -0.781831         0.623490 -0.485302 -0.874347
# 2       1.000000        -0.781831         0.623490 -0.485302 -0.874347
# 3       1.000000        -0.781831         0.623490 -0.485302 -0.874347
# 4       1.000000        -0.781831         0.623490 -0.485302 -0.874347
# ...          ...              ...              ...       ...       ...
# 335995  0.965926        -0.974928        -0.222521 -0.988468  0.151428
# 335996  0.965926        -0.974928        -0.222521 -0.988468  0.151428
# 335997  0.965926        -0.974928        -0.222521 -0.988468  0.151428
# 335998  0.965926        -0.974928        -0.222521 -0.988468  0.151428
# 335999  0.965926        -0.974928        -0.222521 -0.988468  0.151428
#
#           minute_sin  minute_cos  3hour_interval
# 0       0.000000e+00         1.0               1
# 1       0.000000e+00         1.0               1
# 2       0.000000e+00         1.0               1
# 3       0.000000e+00         1.0               1
# 4       0.000000e+00         1.0               1
# ...              ...         ...             ...
# 335995  5.665539e-16        -1.0               8
# 335996  5.665539e-16        -1.0               8
# 335997  5.665539e-16        -1.0               8
# 335998  5.665539e-16        -1.0               8
# 335999  5.665539e-16        -1.0               8
#
# [336000 rows x 27 columns]

# %% [markdown]
# ### Make Visualizations
#
# In this step, we are doing the following operations:
# - View total traffic flow (sum of traffic flow of every path in the dataset) per day. In this way we understand patterns that traffic flow has.
#
# - View total traffic flow per day and 3-hour interval of the same day, to understand in which time of each day Traffic Flow is on peak.

# %%
import seaborn as sns

# %% [markdown]
# #### Visualise the Traffic Flow in every path of the dataset per day
# Use the sum of traffic flow of every path at each timestep to generate a total overview about the data

# %%
# group by timestamp (index) and calculate the sum of the traffic flow
grouped_df = time_series_weather['Traffic Flow'].groupby(time_series_weather['Time Column']).sum()

# add results to dataframe
grouped_df = pd.DataFrame(grouped_df,index=grouped_df.index)

# %%
# add additional time information in the dataset
grouped_df['hour'] = grouped_df.index.hour
grouped_df['3hour_interval'] = grouped_df['hour'].apply(get_3hour_interval)
grouped_df['dayofweek'] = grouped_df.index.dayofweek

# %%
# create a custom dark color palette
dark_palette = sns.color_palette('dark', n_colors=8)

# create a plot to view the results
plt.figure(figsize=(15,5))
sns.lineplot(grouped_df,x=grouped_df.index,y='Traffic Flow',hue='dayofweek',marker='o', palette=dark_palette,linewidth=2.5)
plt.xlabel('Time')
plt.ylabel('Sum of Traffic Flow')
plt.title('Sum of Traffic Flow in Every Path of the Dataset Over Time')
plt.show()

# %% [markdown]
# Based on graph above, we see that for each day, there is a seasonality pattern. In the noon hours Traffic Flow is lower than in the mornnings or in the evenings.

# %% [markdown]
# #### Visualize traffic flow per day and per 3hour time inteval

# %%
# traffic flow on 2008-05-18
pl = grouped_df[(grouped_df.index >= '2008-05-18 00:00:00') & (grouped_df.index < '2008-05-19 00:00:00')]

# Create a custom dark color palette
dark_palette = sns.color_palette('dark', n_colors=8)

# plot the data
plt.figure(figsize=(15,5))
sns.lineplot(pl,x='Time Column',y='Traffic Flow',hue='3hour_interval',marker='o', palette=dark_palette,linewidth=2.5)
plt.title("Traffic Flow on 2008-05-18")
plt.xlabel("Time information every 30 minutes")
# Out:
# Text(0.5, 0, 'Time information every 30 minutes')

# %%
# traffic flow on 2008-05-19
pl = grouped_df[(grouped_df.index >= '2008-05-19 00:00:00') & (grouped_df.index < '2008-05-20 00:00:00')]

# Create a custom dark color palette
dark_palette = sns.color_palette('dark', n_colors=8)

# plot the data
plt.figure(figsize=(15,5))
sns.lineplot(pl,x='Time Column',y='Traffic Flow',hue='3hour_interval',marker='o', palette=dark_palette,linewidth=2.5)
plt.title("Traffic Flow on 2008-05-19")
plt.xlabel("Time information every 30 minutes")
# Out:
# Text(0.5, 0, 'Time information every 30 minutes')

# %%
# traffic flow on 2008-05-20
pl = grouped_df[(grouped_df.index >= '2008-05-20 00:00:00') & (grouped_df.index < '2008-05-21 00:00:00')]

# Create a custom dark color palette
dark_palette = sns.color_palette('dark', n_colors=8)

# plot the data
plt.figure(figsize=(15,5))
sns.lineplot(pl,x='Time Column',y='Traffic Flow',hue='3hour_interval',marker='o', palette=dark_palette,linewidth=2.5)
plt.title("Traffic Flow on 2008-05-20")
plt.xlabel("Time information every 30 minutes")
# Out:
# Text(0.5, 0, 'Time information every 30 minutes')

# %%
# traffic flow on 2008-05-21
pl = grouped_df[(grouped_df.index >= '2008-05-21 00:00:00') & (grouped_df.index < '2008-05-22 00:00:00')]

# Create a custom dark color palette
dark_palette = sns.color_palette('dark', n_colors=8)

# plot the data
plt.figure(figsize=(15,5))
sns.lineplot(pl,x='Time Column',y='Traffic Flow',hue='3hour_interval',marker='o', palette=dark_palette,linewidth=2.5)
plt.title("Traffic Flow on 2008-05-21")
plt.xlabel("Time information every 30 minutes")
# Out:
# Text(0.5, 0, 'Time information every 30 minutes')

# %%
# traffic flow on 2008-05-22
pl = grouped_df[(grouped_df.index >= '2008-05-22 00:00:00') & (grouped_df.index < '2008-05-23 00:00:00')]

# Create a custom dark color palette
dark_palette = sns.color_palette('dark', n_colors=8)

# plot the data
plt.figure(figsize=(15,5))
sns.lineplot(pl,x='Time Column',y='Traffic Flow',hue='3hour_interval',marker='o', palette=dark_palette,linewidth=2.5)
plt.title("Traffic Flow on 2008-05-22")
plt.xlabel("Time information every 30 minutes")
# Out:
# Text(0.5, 0, 'Time information every 30 minutes')

# %%
# traffic flow on 2008-05-23
pl = grouped_df[(grouped_df.index >= '2008-05-23 00:00:00') & (grouped_df.index < '2008-05-24 00:00:00')]

# Create a custom dark color palette
dark_palette = sns.color_palette('dark', n_colors=8)

# plot the data
plt.figure(figsize=(15,5))
sns.lineplot(pl,x='Time Column',y='Traffic Flow',hue='3hour_interval',marker='o', palette=dark_palette,linewidth=2.5)
plt.title("Traffic Flow on 2008-05-23")
plt.xlabel("Time information every 30 minutes")
# Out:
# Text(0.5, 0, 'Time information every 30 minutes')

# %%
# traffic flow on 2008-05-24
pl = grouped_df[(grouped_df.index >= '2008-05-24 00:00:00') & (grouped_df.index < '2008-05-25 00:00:00')]

# Create a custom dark color palette
dark_palette = sns.color_palette('dark', n_colors=8)

# plot the data
plt.figure(figsize=(15,5))
sns.lineplot(pl,x='Time Column',y='Traffic Flow',hue='3hour_interval',marker='o', palette=dark_palette,linewidth=2.5)
plt.title("Traffic Flow on 2008-05-24")
plt.xlabel("Time information every 30 minutes")
# Out:
# Text(0.5, 0, 'Time information every 30 minutes')

# %% [markdown]
# #### Find highly correlated data in the dataset

# %%
plt.figure(figsize=(20,10))
sns.heatmap(time_series_weather.corr(), annot=True, cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# Based on the above heatmap, we see that there are some features that are highly correlated. For example,
# temperature is correlated wiith humidity, windspeed, the hour of day, 3hour_interval and circular encoding of hour feature. Based on this heatmap above, we can choose the features that will be used in the final model.

# %% [markdown]
# ### Train - Test split
# In this step, we split the data into two datasets train and test.
# The time inteval of all observations in this dataset are within [18-05-2008, 24-05-2008].
# - Train dataset contains all the data for each path till 2008-05-23 inclusive.
# - The rest of the data (the most resent ones) are in the test dataset

# %%
# sort the time series data
time_series_weather.sort_values(by=['Path','Time Column'], inplace=True)

# %%
# define train data
train = time_series_weather.loc[time_series_weather['Time Column'] < '2008-05-24']

# define test data
test = time_series_weather.loc[time_series_weather['Time Column'] >= '2008-05-24']

# print the results
print("Train set shape: ",train.shape)
print("Test set shape: ",test.shape)
# Out:
# Train set shape:  (288000, 27)
# Test set shape:  (48000, 27)

# %%
# redefine train and test sets based on correlated features (drop highly correlated features)
train = train.drop(['Time Column','hour', 'hour_sin','day_of_week_cos', 'dayofweek', 'day', 'minute'],axis=1)
test = test.drop(['Time Column','hour', 'hour_sin','day_of_week_cos', 'dayofweek', 'day', 'minute'],axis=1)

# %% [markdown]
# ### Find the best lookback timesteps for our XGBoost model
# In this step, we define the optimum lookback timestep number for our sliding window. This optimum number will be used by the model for forecasting. Also, since XGBoost is the best model based in RMSE score, we perform this operation only for this model.

# %% [markdown]
# #### Step 0: Create empty dataframe to store the scores per lookback timesteps

# %%
# find best lookback timesteps to perform analysis. Save those scores in a separate dataframe
lookback_scores = pd.DataFrame(columns=['#Timesteps','XGBoost Score'])
lookback_scores['#Timesteps'] = 0
lookback_scores['XGBoost Score'] = 0

# %% [markdown]
# #### Step 1: Create function that converts the data into a supervised problem
# Consider for each path n_in timesteps of traffic flow in the past, in order to predict the n_out traffic flow timesteps in the future.

# %%
from pandas import DataFrame
from pandas import concat

# create functio for generating (X, y) pairs
def series_to_supervised(data, n_in=1, n_out=1):
    """
    Frame a time series as a supervised learning dataset.
    Arguments:
        data: Sequence of observations as a list or NumPy array.
        n_in: Number of lag observations as input (X).
        n_out: Number of observations as output (y).
        dropnan: Boolean whether or not to drop rows with NaN values.
    Returns:
        Pandas DataFrame of series framed for supervised learning.
    """
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('Traffic Flow %d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('Traffic Flow %d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('Traffic Flow %d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    return agg

# %%
"""
Convert the training data into a supervised dataset. Create X,y pairs of the traffic column information.
Then, concatenate the rest of the culumns.
"""
def generate_X_y_pairs(data,n_in=1,n_out=1):
    new_data = pd.DataFrame()
    for item in data['Path'].unique():

        # call function only for traffic flow columns
        supervised_traffic_flow = series_to_supervised(pd.DataFrame(data[data['Path'] == item]['Traffic Flow']), n_in, n_out)

        # the rest of the columns are concatenated as they were
        supervised_traffic_flow = pd.concat([supervised_traffic_flow, time_series_weather[time_series_weather['Path'] == item]], axis=1)

        new_data = pd.concat([new_data,supervised_traffic_flow])

    new_data.dropna(inplace=True)
    return new_data

# %% [markdown]
# #### Step 2: Create a loop. In each loop, we are doing the following:
# - 0. Convert train and test sets into supervised problem with lookback timesteps.
# - 1. Define features and labels.
# - 2. Train the XGboost model with defult parameters
# - 3. Predict on the test set
# - 4. Save RMSE in a dataframe

# %%
# import libraries
import xgboost as xgb
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
for lookback in [2,3,4,5,6]: # different lookback sizes

    # convert train and test data to supervised
    train_s = generate_X_y_pairs(train,lookback)
    test_s = generate_X_y_pairs(test,lookback)

    print("Lookback = "+str(lookback)+" - To supervised: Completed!")

    # add rolling mean information
    train_s['rolling_mean'] = 0
    test_s['rolling_mean'] = 0

    train_s['rolling_mean'] = train_s.iloc[:,0:lookback].mean(axis=1)
    test_s['rolling_mean'] = test_s.iloc[:,0:lookback].mean(axis=1)

    # define features
    features_s = train_s.drop(['Time Column','Traffic Flow','Traffic Flow 1(t)'],axis=1).columns

    # define label
    labels_s = ['Traffic Flow 1(t)']

    # create X_train and y_train datasets
    X_train_s = train_s[features_s]
    y_train_s = train_s[labels_s]

    # create X_test and y_test datasets
    X_test_s = test_s[features_s]
    y_test_s = test_s[labels_s]

    print("Lookback = "+str(lookback)+" - Train and Test sets: Completed!")

    # define XGBoost regression model
    reg = xgb.XGBRegressor(objective='reg:squarederror',n_estimators=1000,early_stopping_rounds = 5)

    # train the XGBoost model with feature weights, use validation set on test data)
    reg.fit(X_train_s, y_train_s, eval_set=[(X_train_s, y_train_s), (X_test_s,y_test_s)],verbose=False)

    print("Lookback = "+str(lookback)+" - Trainning: Completed!")

    # make predictions
    y_pred_s = reg.predict(X_test_s)

    # calculate RMSE score
    rmse = mean_squared_error(y_test_s, y_pred_s, squared=False)

    # create a new row as a dictionary
    new_row = {'#Timesteps': lookback, 'XGBoost Score': rmse}

    # append the new row to the DataFrame
    lookback_scores = lookback_scores.append(new_row, ignore_index=True)

    print("Lookback = "+str(lookback)+" - Saved Results: Completed!")
# Out:
# Lookback = 2 - To supervised: Completed!
# Lookback = 2 - Train and Test sets: Completed!
# Lookback = 2 - Trainning: Completed!
# Lookback = 2 - Saved Results: Completed!
# Lookback = 3 - To supervised: Completed!
# Lookback = 3 - Train and Test sets: Completed!
# Lookback = 3 - Trainning: Completed!
# Lookback = 3 - Saved Results: Completed!
# Lookback = 4 - To supervised: Completed!
# Lookback = 4 - Train and Test sets: Completed!
# Lookback = 4 - Trainning: Completed!
# Lookback = 4 - Saved Results: Completed!
# Lookback = 5 - To supervised: Completed!
# Lookback = 5 - Train and Test sets: Completed!
# Lookback = 5 - Trainning: Completed!
# Lookback = 5 - Saved Results: Completed!
# Lookback = 6 - To supervised: Completed!
# Lookback = 6 - Train and Test sets: Completed!
# Lookback = 6 - Trainning: Completed!
# Lookback = 6 - Saved Results: Completed!

# %% [markdown]
# ####  Step 3: Print RMSE scores over lookback timesteps into a graph

# %%
# plot the data
plt.plot(lookback_scores['#Timesteps'], lookback_scores['XGBoost Score'], linestyle='-', marker='o', color='b')

# set plot title and axis labels
plt.title('Lookback timesteps over RMSE score')
plt.xlabel('Lookback Timesteps of column Traffic Flow')
plt.ylabel('RMSE score after XGBoost testing')

# add gridlines
plt.grid(True)

# show the plot
plt.show()

# %%
# find the timesteps corresponding to the minimum RMSE score
optimum_lookback = int(lookback_scores['#Timesteps'].loc[lookback_scores['XGBoost Score'].idxmin()])

# %% [markdown]
# ### Perform Grid Search CV to find the optimum parameters for the XGBoost model
# This step is essential to tune correctly the XGboost model.

# %% [markdown]
# #### Step 0: Split train and test into supervised problem, based on optimum lookback timesteps that found above.

# %%
# convert train and test data to supervised problem based in the optimum lookback step we defined above.
train = generate_X_y_pairs(train,optimum_lookback)
test = generate_X_y_pairs(test,optimum_lookback)

# %% [markdown]
# #### Step 1: Extract features about trend of time series
# In this step we define the rolling mean and rolling variance of a window. Since we are trying to forecast the last value of each window, only the first optimum_lookback values in the window are used to compute rolling features. The last value (that we are trying to forecast) is not included.

# %%
# add rolling mean information
train['rolling_mean'] = 0
test['rolling_mean'] = 0

train['rolling_var'] = 0
test['rolling_var'] = 0

# calculate rolling mean of window
train['rolling_mean'] = train.iloc[:,0:optimum_lookback].mean(axis=1)
test['rolling_mean'] = test.iloc[:,0:optimum_lookback].mean(axis=1)

# calculate rolling variance of window
train['rolling_var'] = train.iloc[:, 0:optimum_lookback].var(axis=1)
test['rolling_var'] = test.iloc[:, 0:optimum_lookback].var(axis=1)

# %% [markdown]
# ####  Step 2: Define labels and features
# - Features will help the XGboost algorithm to predict the output value, the label. We will use all the traffic flow information at previous timesteps (t-n,t-n+1...,t-2,t-1), as well as the rest of the features (time and trend information) as features.
# - Label will be out target value, the Traffic Flow at timestep t.

# %%
# define features
features = train.drop(['Time Column','Traffic Flow 1(t)','Traffic Flow','hour', 'hour_sin','day_of_week_cos', 'dayofweek', 'day', 'minute'],axis=1).columns

# define labels
labels = ['Traffic Flow 1(t)']

# create X_train and y_train data sets
X_train = train[features]
y_train = train[labels]

# create X_test and y_test data sets
X_test = test[features]
y_test = test[labels]

# %%
# show shape information about X and y training and testing sets
print("Shape of X_train is: ",X_train.shape)
print("Shape of y_train is: ",y_train.shape)
print("Shape of X_test is: ",X_test.shape)
print("Shape of y_test is: ",y_test.shape)
# Out:
# Shape of X_train is:  (282000, 27)
# Shape of y_train is:  (282000, 1)
# Shape of X_test is:  (42000, 27)
# Shape of y_test is:  (42000, 1)

# %% [markdown]
# #### Step 3: Apply GridSearchCV
# Use a 5-fold K-fold cross-validation was used for learning the optimum hyperparameters for the XGBoost algorithm.

# %%
from sklearn.model_selection import GridSearchCV

# %%
# tune hyperparameters using XGboost
xgb_params = {
    "n_estimators": [300],
    "learning_rate": [0.1],
    "max_depth": [5,9],
    "objective":['reg:squarederror'],
    "gamma": [0,1],
    "alpha": [0,0.1,1]
}

# define GridSearchCV object
xgb_grid = GridSearchCV(xgb.XGBRegressor(),
                        xgb_params,cv=3,
                        verbose=1,
                        scoring= "neg_mean_squared_error")

# train on train data using 5 fold CV
xgb_grid.fit(X_train,y_train,
             early_stopping_rounds=5,
             eval_set=[(X_train, y_train), (X_test,y_test)],
             eval_metric='rmse')

# print the best hyperparameters and corresponding score
print("Best Hyperparameters: ", xgb_grid.best_params_)
print("Best Score: ", xgb_grid.best_score_)
# Out:
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [0]	validation_0-rmse:6.81478	validation_1-rmse:6.02864
# [1]	validation_0-rmse:6.28512	validation_1-rmse:5.55442
# [2]	validation_0-rmse:5.81913	validation_1-rmse:5.13861
# [3]	validation_0-rmse:5.41013	validation_1-rmse:4.77957
# [4]	validation_0-rmse:5.05309	validation_1-rmse:4.46840
# [5]	validation_0-rmse:4.74040	validation_1-rmse:4.19633
# [6]	validation_0-rmse:4.46852	validation_1-rmse:3.96142
# [7]	validation_0-rmse:4.23496	validation_1-rmse:3.75950
# [8]	validation_0-rmse:4.03520	validation_1-rmse:3.59078
# [9]	validation_0-rmse:3.86454	validation_1-rmse:3.45142
# [10]	validation_0-rmse:3.71757	validation_1-rmse:3.33896
# [11]	validation_0-rmse:3.59355	validation_1-rmse:3.23669
# [12]	validation_0-rmse:3.48426	validation_1-rmse:3.14742
# [13]	validation_0-rmse:3.39576	validation_1-rmse:3.08167
# [14]	validation_0-rmse:3.31831	validation_1-rmse:3.01956
# [15]	validation_0-rmse:3.25615	validation_1-rmse:2.97346
# [16]	validation_0-rmse:3.20432	validation_1-rmse:2.93574
# [17]	validation_0-rmse:3.16003	validation_1-rmse:2.90588
# [18]	validation_0-rmse:3.12031	validation_1-rmse:2.87715
# [19]	validation_0-rmse:3.08652	validation_1-rmse:2.85311
# [20]	validation_0-rmse:3.05954	validation_1-rmse:2.83481
# [21]	validation_0-rmse:3.03598	validation_1-rmse:2.82044
# [22]	validation_0-rmse:3.01480	validation_1-rmse:2.80784
# [23]	validation_0-rmse:2.99955	validation_1-rmse:2.80084
# [24]	validation_0-rmse:2.98318	validation_1-rmse:2.79136
# [25]	validation_0-rmse:2.97053	validation_1-rmse:2.78312
# [26]	validation_0-rmse:2.95972	validation_1-rmse:2.77605
# [27]	validation_0-rmse:2.94892	validation_1-rmse:2.77430
# [28]	validation_0-rmse:2.97185	validation_1-rmse:2.80305
# [29]	validation_0-rmse:2.96647	validation_1-rmse:2.79982
# [30]	validation_0-rmse:2.96024	validation_1-rmse:2.79664
# [31]	validation_0-rmse:2.96036	validation_1-rmse:2.80423
# [32]	validation_0-rmse:2.95474	validation_1-rmse:2.80370
# [0]	validation_0-rmse:6.81443	validation_1-rmse:6.02767
# [1]	validation_0-rmse:6.28392	validation_1-rmse:5.55175
# [2]	validation_0-rmse:5.81701	validation_1-rmse:5.13711
# [3]	validation_0-rmse:5.40693	validation_1-rmse:4.77561
# [4]	validation_0-rmse:5.04965	validation_1-rmse:4.46073
# [5]	validation_0-rmse:4.73759	validation_1-rmse:4.19181
# [6]	validation_0-rmse:4.46790	validation_1-rmse:3.95945
# [7]	validation_0-rmse:4.23570	validation_1-rmse:3.76196
# [8]	validation_0-rmse:4.03664	validation_1-rmse:3.59307
# [9]	validation_0-rmse:3.86430	validation_1-rmse:3.44601
# [10]	validation_0-rmse:3.71957	validation_1-rmse:3.32601
# [11]	validation_0-rmse:3.59442	validation_1-rmse:3.21337
# [12]	validation_0-rmse:3.48971	validation_1-rmse:3.12786
# [13]	validation_0-rmse:3.39971	validation_1-rmse:3.06036
# [14]	validation_0-rmse:3.32575	validation_1-rmse:3.00372
# [15]	validation_0-rmse:3.26363	validation_1-rmse:2.96145
# [16]	validation_0-rmse:3.21079	validation_1-rmse:2.92388
# [17]	validation_0-rmse:3.16348	validation_1-rmse:2.88966
# [18]	validation_0-rmse:3.12463	validation_1-rmse:2.87226
# [19]	validation_0-rmse:3.09215	validation_1-rmse:2.85149
# [20]	validation_0-rmse:3.06562	validation_1-rmse:2.83135
# [21]	validation_0-rmse:3.04185	validation_1-rmse:2.82337
# [22]	validation_0-rmse:3.02131	validation_1-rmse:2.80760
# [23]	validation_0-rmse:3.00427	validation_1-rmse:2.79723
# [24]	validation_0-rmse:2.99040	validation_1-rmse:2.78896
# [25]	validation_0-rmse:2.97586	validation_1-rmse:2.78252
# [26]	validation_0-rmse:2.96061	validation_1-rmse:2.77768
# [27]	validation_0-rmse:2.94825	validation_1-rmse:2.77211
# [28]	validation_0-rmse:2.94104	validation_1-rmse:2.76943
# [29]	validation_0-rmse:2.93117	validation_1-rmse:2.76561
# [30]	validation_0-rmse:2.92392	validation_1-rmse:2.76252
# [31]	validation_0-rmse:2.91831	validation_1-rmse:2.76070
# [32]	validation_0-rmse:2.91437	validation_1-rmse:2.75994
# [33]	validation_0-rmse:2.90804	validation_1-rmse:2.75839
# [34]	validation_0-rmse:2.90170	validation_1-rmse:2.75549
# [35]	validation_0-rmse:2.89790	validation_1-rmse:2.75558
# [36]	validation_0-rmse:2.89181	validation_1-rmse:2.75481
# [37]	validation_0-rmse:2.88572	validation_1-rmse:2.75389
# [38]	validation_0-rmse:2.88060	validation_1-rmse:2.75378
# [39]	validation_0-rmse:2.87657	validation_1-rmse:2.75539
# [40]	validation_0-rmse:2.87244	validation_1-rmse:2.75455
# [41]	validation_0-rmse:2.86896	validation_1-rmse:2.75694
# [42]	validation_0-rmse:2.86607	validation_1-rmse:2.75600
# [43]	validation_0-rmse:2.86162	validation_1-rmse:2.75658
# [0]	validation_0-rmse:6.80957	validation_1-rmse:6.02454
# [1]	validation_0-rmse:6.27556	validation_1-rmse:5.54755
# [2]	validation_0-rmse:5.80548	validation_1-rmse:5.12979
# [3]	validation_0-rmse:5.39405	validation_1-rmse:4.76902
# [4]	validation_0-rmse:5.03551	validation_1-rmse:4.45351
# [5]	validation_0-rmse:4.72327	validation_1-rmse:4.17930
# [6]	validation_0-rmse:4.45431	validation_1-rmse:3.95044
# [7]	validation_0-rmse:4.22028	validation_1-rmse:3.75426
# [8]	validation_0-rmse:4.02059	validation_1-rmse:3.58914
# [9]	validation_0-rmse:3.85081	validation_1-rmse:3.44900
# [10]	validation_0-rmse:3.70590	validation_1-rmse:3.33324
# [11]	validation_0-rmse:3.58309	validation_1-rmse:3.23052
# [12]	validation_0-rmse:3.47563	validation_1-rmse:3.14659
# [13]	validation_0-rmse:3.38842	validation_1-rmse:3.07904
# [14]	validation_0-rmse:3.31517	validation_1-rmse:3.02422
# [15]	validation_0-rmse:3.25091	validation_1-rmse:2.97975
# [16]	validation_0-rmse:3.19781	validation_1-rmse:2.95077
# [17]	validation_0-rmse:3.15447	validation_1-rmse:2.91235
# [18]	validation_0-rmse:3.11380	validation_1-rmse:2.88606
# [19]	validation_0-rmse:3.08265	validation_1-rmse:2.86381
# [20]	validation_0-rmse:3.05224	validation_1-rmse:2.84165
# [21]	validation_0-rmse:3.02740	validation_1-rmse:2.82788
# [22]	validation_0-rmse:3.00914	validation_1-rmse:2.81799
# [23]	validation_0-rmse:2.99063	validation_1-rmse:2.80927
# [24]	validation_0-rmse:2.97639	validation_1-rmse:2.80187
# [25]	validation_0-rmse:2.96170	validation_1-rmse:2.79330
# [26]	validation_0-rmse:2.94972	validation_1-rmse:2.78578
# [27]	validation_0-rmse:2.94016	validation_1-rmse:2.78301
# [28]	validation_0-rmse:2.93013	validation_1-rmse:2.77727
# [29]	validation_0-rmse:2.92278	validation_1-rmse:2.77348
# [30]	validation_0-rmse:2.91605	validation_1-rmse:2.76913
# [31]	validation_0-rmse:2.91094	validation_1-rmse:2.76930
# [32]	validation_0-rmse:2.90453	validation_1-rmse:2.76878
# [33]	validation_0-rmse:2.89827	validation_1-rmse:2.77085
# [34]	validation_0-rmse:2.89320	validation_1-rmse:2.76884
# [35]	validation_0-rmse:2.88753	validation_1-rmse:2.76765
# [36]	validation_0-rmse:2.88276	validation_1-rmse:2.76663
# [37]	validation_0-rmse:2.87777	validation_1-rmse:2.76553
# [38]	validation_0-rmse:2.87286	validation_1-rmse:2.76588
# [39]	validation_0-rmse:2.86904	validation_1-rmse:2.76808
# [40]	validation_0-rmse:2.86584	validation_1-rmse:2.76738
# [41]	validation_0-rmse:2.86266	validation_1-rmse:2.76637
# [42]	validation_0-rmse:2.85735	validation_1-rmse:2.76631
# [0]	validation_0-rmse:6.80318	validation_1-rmse:6.04063
# [1]	validation_0-rmse:6.26484	validation_1-rmse:5.58312
# [2]	validation_0-rmse:5.78651	validation_1-rmse:5.17035
# [3]	validation_0-rmse:5.36335	validation_1-rmse:4.80985
# [4]	validation_0-rmse:4.99380	validation_1-rmse:4.50302
# [5]	validation_0-rmse:4.66765	validation_1-rmse:4.23797
# [6]	validation_0-rmse:4.38044	validation_1-rmse:4.01125
# [7]	validation_0-rmse:4.13423	validation_1-rmse:3.81763
# [8]	validation_0-rmse:3.91984	validation_1-rmse:3.65186
# [9]	validation_0-rmse:3.73426	validation_1-rmse:3.50828
# [10]	validation_0-rmse:3.57455	validation_1-rmse:3.39261
# [11]	validation_0-rmse:3.43499	validation_1-rmse:3.29012
# [12]	validation_0-rmse:3.31645	validation_1-rmse:3.20624
# [13]	validation_0-rmse:3.21613	validation_1-rmse:3.13970
# [14]	validation_0-rmse:3.12922	validation_1-rmse:3.08321
# [15]	validation_0-rmse:3.05640	validation_1-rmse:3.03387
# [16]	validation_0-rmse:2.99449	validation_1-rmse:2.99305
# [17]	validation_0-rmse:2.94376	validation_1-rmse:2.96176
# [18]	validation_0-rmse:2.90006	validation_1-rmse:2.93599
# [19]	validation_0-rmse:2.86299	validation_1-rmse:2.91150
# [20]	validation_0-rmse:2.83415	validation_1-rmse:2.89399
# [21]	validation_0-rmse:2.80597	validation_1-rmse:2.87844
# [22]	validation_0-rmse:2.78948	validation_1-rmse:2.87238
# [23]	validation_0-rmse:2.76611	validation_1-rmse:2.86197
# [24]	validation_0-rmse:2.74852	validation_1-rmse:2.85403
# [25]	validation_0-rmse:2.73132	validation_1-rmse:2.84757
# [26]	validation_0-rmse:2.72156	validation_1-rmse:2.84483
# [27]	validation_0-rmse:2.70687	validation_1-rmse:2.84052
# [28]	validation_0-rmse:2.69661	validation_1-rmse:2.83631
# [29]	validation_0-rmse:2.69655	validation_1-rmse:2.83935
# [30]	validation_0-rmse:2.68601	validation_1-rmse:2.83563
# [31]	validation_0-rmse:2.68483	validation_1-rmse:2.83635
# [32]	validation_0-rmse:2.68172	validation_1-rmse:2.83738
# [33]	validation_0-rmse:2.68379	validation_1-rmse:2.84515
# [34]	validation_0-rmse:2.68870	validation_1-rmse:2.85757
# [0]	validation_0-rmse:6.79798	validation_1-rmse:6.02988
# [1]	validation_0-rmse:6.25215	validation_1-rmse:5.56343
# [2]	validation_0-rmse:5.77051	validation_1-rmse:5.15512
# [3]	validation_0-rmse:5.34470	validation_1-rmse:4.80033
# [4]	validation_0-rmse:4.97058	validation_1-rmse:4.48648
# [5]	validation_0-rmse:4.64294	validation_1-rmse:4.22175
# [6]	validation_0-rmse:4.35712	validation_1-rmse:3.99327
# [7]	validation_0-rmse:4.10875	validation_1-rmse:3.78733
# [8]	validation_0-rmse:3.89313	validation_1-rmse:3.61811
# [9]	validation_0-rmse:3.70572	validation_1-rmse:3.47593
# [10]	validation_0-rmse:3.54629	validation_1-rmse:3.35331
# [11]	validation_0-rmse:3.40863	validation_1-rmse:3.25275
# [12]	validation_0-rmse:3.29105	validation_1-rmse:3.16912
# [13]	validation_0-rmse:3.19095	validation_1-rmse:3.09816
# [14]	validation_0-rmse:3.10445	validation_1-rmse:3.03948
# [15]	validation_0-rmse:3.03097	validation_1-rmse:2.99062
# [16]	validation_0-rmse:2.96840	validation_1-rmse:2.95187
# [17]	validation_0-rmse:2.91637	validation_1-rmse:2.91974
# [18]	validation_0-rmse:2.87076	validation_1-rmse:2.89027
# [19]	validation_0-rmse:2.82963	validation_1-rmse:2.86767
# [20]	validation_0-rmse:2.79489	validation_1-rmse:2.84833
# [21]	validation_0-rmse:2.76647	validation_1-rmse:2.83431
# [22]	validation_0-rmse:2.74190	validation_1-rmse:2.82147
# [23]	validation_0-rmse:2.72208	validation_1-rmse:2.81233
# [24]	validation_0-rmse:2.70409	validation_1-rmse:2.80204
# [25]	validation_0-rmse:2.68470	validation_1-rmse:2.79581
# [26]	validation_0-rmse:2.66619	validation_1-rmse:2.78833
# [27]	validation_0-rmse:2.65184	validation_1-rmse:2.78358
# [28]	validation_0-rmse:2.63768	validation_1-rmse:2.77886
# [29]	validation_0-rmse:2.62477	validation_1-rmse:2.77466
# [30]	validation_0-rmse:2.61626	validation_1-rmse:2.77145
# [31]	validation_0-rmse:2.60725	validation_1-rmse:2.76891
# [32]	validation_0-rmse:2.59721	validation_1-rmse:2.76741
# [33]	validation_0-rmse:2.58719	validation_1-rmse:2.76563
# [34]	validation_0-rmse:2.57993	validation_1-rmse:2.76784
# [35]	validation_0-rmse:2.57221	validation_1-rmse:2.76538
# [36]	validation_0-rmse:2.56781	validation_1-rmse:2.76400
# [37]	validation_0-rmse:2.56053	validation_1-rmse:2.76263
# [38]	validation_0-rmse:2.55212	validation_1-rmse:2.76190
# [39]	validation_0-rmse:2.54552	validation_1-rmse:2.76224
# [40]	validation_0-rmse:2.53874	validation_1-rmse:2.76180
# [41]	validation_0-rmse:2.53119	validation_1-rmse:2.76150
# [42]	validation_0-rmse:2.52709	validation_1-rmse:2.75791
# [43]	validation_0-rmse:2.52037	validation_1-rmse:2.75813
# [44]	validation_0-rmse:2.51473	validation_1-rmse:2.75771
# [45]	validation_0-rmse:2.51211	validation_1-rmse:2.75804
# [46]	validation_0-rmse:2.50863	validation_1-rmse:2.75663
# [47]	validation_0-rmse:2.50509	validation_1-rmse:2.75627
# [48]	validation_0-rmse:2.50072	validation_1-rmse:2.75662
# [49]	validation_0-rmse:2.49781	validation_1-rmse:2.75649
# [50]	validation_0-rmse:2.49287	validation_1-rmse:2.75585
# [51]	validation_0-rmse:2.48908	validation_1-rmse:2.75583
# [52]	validation_0-rmse:2.48443	validation_1-rmse:2.75488
# [53]	validation_0-rmse:2.48013	validation_1-rmse:2.75574
# [54]	validation_0-rmse:2.47664	validation_1-rmse:2.75203
# [55]	validation_0-rmse:2.47145	validation_1-rmse:2.75210
# [56]	validation_0-rmse:2.46779	validation_1-rmse:2.75244
# [57]	validation_0-rmse:2.46436	validation_1-rmse:2.75236
# [58]	validation_0-rmse:2.46167	validation_1-rmse:2.75204
# [59]	validation_0-rmse:2.45953	validation_1-rmse:2.75125
# [60]	validation_0-rmse:2.45544	validation_1-rmse:2.75272
# [61]	validation_0-rmse:2.45429	validation_1-rmse:2.75281
# [62]	validation_0-rmse:2.45238	validation_1-rmse:2.75030
# [63]	validation_0-rmse:2.45090	validation_1-rmse:2.75045
# [64]	validation_0-rmse:2.44943	validation_1-rmse:2.75060
# [65]	validation_0-rmse:2.44768	validation_1-rmse:2.75007
# [66]	validation_0-rmse:2.44395	validation_1-rmse:2.75020
# [67]	validation_0-rmse:2.44171	validation_1-rmse:2.75002
# [68]	validation_0-rmse:2.44095	validation_1-rmse:2.74984
# [69]	validation_0-rmse:2.43941	validation_1-rmse:2.74978
# [70]	validation_0-rmse:2.43691	validation_1-rmse:2.74872
# [71]	validation_0-rmse:2.43358	validation_1-rmse:2.74895
# [72]	validation_0-rmse:2.43161	validation_1-rmse:2.74908
# [73]	validation_0-rmse:2.42819	validation_1-rmse:2.74813
# [74]	validation_0-rmse:2.42635	validation_1-rmse:2.74783
# [75]	validation_0-rmse:2.42400	validation_1-rmse:2.74779
# [76]	validation_0-rmse:2.42346	validation_1-rmse:2.74782
# [77]	validation_0-rmse:2.42031	validation_1-rmse:2.74839
# [78]	validation_0-rmse:2.41659	validation_1-rmse:2.74765
# [79]	validation_0-rmse:2.41512	validation_1-rmse:2.74758
# [80]	validation_0-rmse:2.41237	validation_1-rmse:2.74789
# [81]	validation_0-rmse:2.41068	validation_1-rmse:2.74792
# [82]	validation_0-rmse:2.40888	validation_1-rmse:2.74766
# [83]	validation_0-rmse:2.40421	validation_1-rmse:2.74906
# [84]	validation_0-rmse:2.40300	validation_1-rmse:2.74859
# [0]	validation_0-rmse:6.79600	validation_1-rmse:6.03027
# [1]	validation_0-rmse:6.24643	validation_1-rmse:5.57133
# [2]	validation_0-rmse:5.76076	validation_1-rmse:5.15718
# [3]	validation_0-rmse:5.33195	validation_1-rmse:4.79957
# [4]	validation_0-rmse:4.95692	validation_1-rmse:4.49048
# [5]	validation_0-rmse:4.62737	validation_1-rmse:4.22449
# [6]	validation_0-rmse:4.33881	validation_1-rmse:3.98935
# [7]	validation_0-rmse:4.08999	validation_1-rmse:3.79404
# [8]	validation_0-rmse:3.87576	validation_1-rmse:3.62611
# [9]	validation_0-rmse:3.68885	validation_1-rmse:3.48152
# [10]	validation_0-rmse:3.52696	validation_1-rmse:3.35963
# [11]	validation_0-rmse:3.38678	validation_1-rmse:3.25709
# [12]	validation_0-rmse:3.26664	validation_1-rmse:3.17299
# [13]	validation_0-rmse:3.16632	validation_1-rmse:3.10025
# [14]	validation_0-rmse:3.08073	validation_1-rmse:3.03751
# [15]	validation_0-rmse:3.00885	validation_1-rmse:2.99042
# [16]	validation_0-rmse:2.94542	validation_1-rmse:2.95324
# [17]	validation_0-rmse:2.89220	validation_1-rmse:2.91876
# [18]	validation_0-rmse:2.84593	validation_1-rmse:2.89315
# [19]	validation_0-rmse:2.80705	validation_1-rmse:2.87156
# [20]	validation_0-rmse:2.77255	validation_1-rmse:2.85334
# [21]	validation_0-rmse:2.74225	validation_1-rmse:2.83846
# [22]	validation_0-rmse:2.71590	validation_1-rmse:2.82492
# [23]	validation_0-rmse:2.69313	validation_1-rmse:2.81728
# [24]	validation_0-rmse:2.67482	validation_1-rmse:2.80896
# [25]	validation_0-rmse:2.65725	validation_1-rmse:2.80364
# [26]	validation_0-rmse:2.64243	validation_1-rmse:2.79974
# [27]	validation_0-rmse:2.62922	validation_1-rmse:2.79399
# [28]	validation_0-rmse:2.61721	validation_1-rmse:2.78941
# [29]	validation_0-rmse:2.60657	validation_1-rmse:2.78343
# [30]	validation_0-rmse:2.59446	validation_1-rmse:2.78069
# [31]	validation_0-rmse:2.58493	validation_1-rmse:2.77711
# [32]	validation_0-rmse:2.57466	validation_1-rmse:2.77463
# [33]	validation_0-rmse:2.56321	validation_1-rmse:2.77496
# [34]	validation_0-rmse:2.55535	validation_1-rmse:2.77281
# [35]	validation_0-rmse:2.54703	validation_1-rmse:2.77340
# [36]	validation_0-rmse:2.54000	validation_1-rmse:2.77080
# [37]	validation_0-rmse:2.53305	validation_1-rmse:2.76996
# [38]	validation_0-rmse:2.52787	validation_1-rmse:2.76961
# [39]	validation_0-rmse:2.52189	validation_1-rmse:2.77187
# [40]	validation_0-rmse:2.51733	validation_1-rmse:2.77186
# [41]	validation_0-rmse:2.51200	validation_1-rmse:2.77120
# [42]	validation_0-rmse:2.50801	validation_1-rmse:2.77083
# [43]	validation_0-rmse:2.50365	validation_1-rmse:2.77009
# [0]	validation_0-rmse:6.81478	validation_1-rmse:6.02864
# [1]	validation_0-rmse:6.28512	validation_1-rmse:5.55442
# [2]	validation_0-rmse:5.81913	validation_1-rmse:5.13861
# [3]	validation_0-rmse:5.41013	validation_1-rmse:4.77957
# [4]	validation_0-rmse:5.05309	validation_1-rmse:4.46840
# [5]	validation_0-rmse:4.74040	validation_1-rmse:4.19633
# [6]	validation_0-rmse:4.46852	validation_1-rmse:3.96142
# [7]	validation_0-rmse:4.23496	validation_1-rmse:3.75950
# [8]	validation_0-rmse:4.03520	validation_1-rmse:3.59078
# [9]	validation_0-rmse:3.86454	validation_1-rmse:3.45142
# [10]	validation_0-rmse:3.71757	validation_1-rmse:3.33896
# [11]	validation_0-rmse:3.59355	validation_1-rmse:3.23669
# [12]	validation_0-rmse:3.48426	validation_1-rmse:3.14742
# [13]	validation_0-rmse:3.39576	validation_1-rmse:3.08167
# [14]	validation_0-rmse:3.31831	validation_1-rmse:3.01956
# [15]	validation_0-rmse:3.25615	validation_1-rmse:2.97346
# [16]	validation_0-rmse:3.20432	validation_1-rmse:2.93574
# [17]	validation_0-rmse:3.16003	validation_1-rmse:2.90588
# [18]	validation_0-rmse:3.12031	validation_1-rmse:2.87715
# [19]	validation_0-rmse:3.08652	validation_1-rmse:2.85311
# [20]	validation_0-rmse:3.05954	validation_1-rmse:2.83481
# [21]	validation_0-rmse:3.03598	validation_1-rmse:2.82044
# [22]	validation_0-rmse:3.01480	validation_1-rmse:2.80784
# [23]	validation_0-rmse:2.99955	validation_1-rmse:2.80084
# [24]	validation_0-rmse:2.98318	validation_1-rmse:2.79136
# [25]	validation_0-rmse:2.97053	validation_1-rmse:2.78312
# [26]	validation_0-rmse:2.95972	validation_1-rmse:2.77605
# [27]	validation_0-rmse:2.94892	validation_1-rmse:2.77430
# [28]	validation_0-rmse:2.97185	validation_1-rmse:2.80305
# [29]	validation_0-rmse:2.96647	validation_1-rmse:2.79982
# [30]	validation_0-rmse:2.96024	validation_1-rmse:2.79664
# [31]	validation_0-rmse:2.96036	validation_1-rmse:2.80423
# [0]	validation_0-rmse:6.81443	validation_1-rmse:6.02767
# [1]	validation_0-rmse:6.28392	validation_1-rmse:5.55175
# [2]	validation_0-rmse:5.81701	validation_1-rmse:5.13711
# [3]	validation_0-rmse:5.40693	validation_1-rmse:4.77561
# [4]	validation_0-rmse:5.04965	validation_1-rmse:4.46073
# [5]	validation_0-rmse:4.73759	validation_1-rmse:4.19181
# [6]	validation_0-rmse:4.46790	validation_1-rmse:3.95945
# [7]	validation_0-rmse:4.23570	validation_1-rmse:3.76196
# [8]	validation_0-rmse:4.03664	validation_1-rmse:3.59307
# [9]	validation_0-rmse:3.86430	validation_1-rmse:3.44601
# [10]	validation_0-rmse:3.71957	validation_1-rmse:3.32601
# [11]	validation_0-rmse:3.59442	validation_1-rmse:3.21337
# [12]	validation_0-rmse:3.48971	validation_1-rmse:3.12786
# [13]	validation_0-rmse:3.39971	validation_1-rmse:3.06036
# [14]	validation_0-rmse:3.32575	validation_1-rmse:3.00372
# [15]	validation_0-rmse:3.26363	validation_1-rmse:2.96145
# [16]	validation_0-rmse:3.21079	validation_1-rmse:2.92388
# [17]	validation_0-rmse:3.16348	validation_1-rmse:2.88966
# [18]	validation_0-rmse:3.12463	validation_1-rmse:2.87226
# [19]	validation_0-rmse:3.09215	validation_1-rmse:2.85149
# [20]	validation_0-rmse:3.06562	validation_1-rmse:2.83135
# [21]	validation_0-rmse:3.04185	validation_1-rmse:2.82337
# [22]	validation_0-rmse:3.02131	validation_1-rmse:2.80760
# [23]	validation_0-rmse:3.00427	validation_1-rmse:2.79723
# [24]	validation_0-rmse:2.99040	validation_1-rmse:2.78896
# [25]	validation_0-rmse:2.97586	validation_1-rmse:2.78252
# [26]	validation_0-rmse:2.96061	validation_1-rmse:2.77768
# [27]	validation_0-rmse:2.94825	validation_1-rmse:2.77211
# [28]	validation_0-rmse:2.94104	validation_1-rmse:2.76943
# [29]	validation_0-rmse:2.93117	validation_1-rmse:2.76561
# [30]	validation_0-rmse:2.92392	validation_1-rmse:2.76252
# [31]	validation_0-rmse:2.91831	validation_1-rmse:2.76070
# [32]	validation_0-rmse:2.91438	validation_1-rmse:2.75994
# [33]	validation_0-rmse:2.90805	validation_1-rmse:2.75839
# [34]	validation_0-rmse:2.90170	validation_1-rmse:2.75549
# [35]	validation_0-rmse:2.89791	validation_1-rmse:2.75558
# [36]	validation_0-rmse:2.89181	validation_1-rmse:2.75481
# [37]	validation_0-rmse:2.88573	validation_1-rmse:2.75389
# [38]	validation_0-rmse:2.88060	validation_1-rmse:2.75378
# [39]	validation_0-rmse:2.87657	validation_1-rmse:2.75539
# [40]	validation_0-rmse:2.87244	validation_1-rmse:2.75455
# [41]	validation_0-rmse:2.86896	validation_1-rmse:2.75694
# [42]	validation_0-rmse:2.86607	validation_1-rmse:2.75600
# [0]	validation_0-rmse:6.80957	validation_1-rmse:6.02454
# [1]	validation_0-rmse:6.27556	validation_1-rmse:5.54755
# [2]	validation_0-rmse:5.80548	validation_1-rmse:5.12979
# [3]	validation_0-rmse:5.39405	validation_1-rmse:4.76902
# [4]	validation_0-rmse:5.03551	validation_1-rmse:4.45351
# [5]	validation_0-rmse:4.72327	validation_1-rmse:4.17930
# [6]	validation_0-rmse:4.45431	validation_1-rmse:3.95044
# [7]	validation_0-rmse:4.22028	validation_1-rmse:3.75426
# [8]	validation_0-rmse:4.02059	validation_1-rmse:3.58914
# [9]	validation_0-rmse:3.85081	validation_1-rmse:3.44900
# [10]	validation_0-rmse:3.70590	validation_1-rmse:3.33324
# [11]	validation_0-rmse:3.58309	validation_1-rmse:3.23052
# [12]	validation_0-rmse:3.47563	validation_1-rmse:3.14659
# [13]	validation_0-rmse:3.38842	validation_1-rmse:3.07904
# [14]	validation_0-rmse:3.31517	validation_1-rmse:3.02422
# [15]	validation_0-rmse:3.25091	validation_1-rmse:2.97975
# [16]	validation_0-rmse:3.19781	validation_1-rmse:2.95077
# [17]	validation_0-rmse:3.15447	validation_1-rmse:2.91235
# [18]	validation_0-rmse:3.11380	validation_1-rmse:2.88606
# [19]	validation_0-rmse:3.08265	validation_1-rmse:2.86381
# [20]	validation_0-rmse:3.05224	validation_1-rmse:2.84165
# [21]	validation_0-rmse:3.02740	validation_1-rmse:2.82788
# [22]	validation_0-rmse:3.00914	validation_1-rmse:2.81799
# [23]	validation_0-rmse:2.99063	validation_1-rmse:2.80927
# [24]	validation_0-rmse:2.97639	validation_1-rmse:2.80187
# [25]	validation_0-rmse:2.96170	validation_1-rmse:2.79330
# [26]	validation_0-rmse:2.94972	validation_1-rmse:2.78578
# [27]	validation_0-rmse:2.94016	validation_1-rmse:2.78301
# [28]	validation_0-rmse:2.93013	validation_1-rmse:2.77727
# [29]	validation_0-rmse:2.92278	validation_1-rmse:2.77348
# [30]	validation_0-rmse:2.91605	validation_1-rmse:2.76913
# [31]	validation_0-rmse:2.91094	validation_1-rmse:2.76930
# [32]	validation_0-rmse:2.90453	validation_1-rmse:2.76878
# [33]	validation_0-rmse:2.89827	validation_1-rmse:2.77085
# [34]	validation_0-rmse:2.89320	validation_1-rmse:2.76884
# [35]	validation_0-rmse:2.88753	validation_1-rmse:2.76765
# [36]	validation_0-rmse:2.88276	validation_1-rmse:2.76663
# [37]	validation_0-rmse:2.87777	validation_1-rmse:2.76553
# [38]	validation_0-rmse:2.87286	validation_1-rmse:2.76588
# [39]	validation_0-rmse:2.86904	validation_1-rmse:2.76808
# [40]	validation_0-rmse:2.86584	validation_1-rmse:2.76738
# [41]	validation_0-rmse:2.86266	validation_1-rmse:2.76637
# [42]	validation_0-rmse:2.85736	validation_1-rmse:2.76635
# [0]	validation_0-rmse:6.80318	validation_1-rmse:6.04063
# [1]	validation_0-rmse:6.26484	validation_1-rmse:5.58312
# [2]	validation_0-rmse:5.78656	validation_1-rmse:5.17042
# [3]	validation_0-rmse:5.36344	validation_1-rmse:4.80994
# [4]	validation_0-rmse:4.99425	validation_1-rmse:4.50365
# [5]	validation_0-rmse:4.66583	validation_1-rmse:4.23935
# [6]	validation_0-rmse:4.38297	validation_1-rmse:4.01098
# [7]	validation_0-rmse:4.13764	validation_1-rmse:3.81819
# [8]	validation_0-rmse:3.91900	validation_1-rmse:3.65376
# [9]	validation_0-rmse:3.73418	validation_1-rmse:3.51285
# [10]	validation_0-rmse:3.57683	validation_1-rmse:3.39419
# [11]	validation_0-rmse:3.43976	validation_1-rmse:3.29523
# [12]	validation_0-rmse:3.32034	validation_1-rmse:3.21071
# [13]	validation_0-rmse:3.21894	validation_1-rmse:3.13981
# [14]	validation_0-rmse:3.13458	validation_1-rmse:3.08424
# [15]	validation_0-rmse:3.06187	validation_1-rmse:3.03706
# [16]	validation_0-rmse:2.99905	validation_1-rmse:2.99921
# [17]	validation_0-rmse:2.94666	validation_1-rmse:2.96621
# [18]	validation_0-rmse:2.90189	validation_1-rmse:2.93960
# [19]	validation_0-rmse:2.86428	validation_1-rmse:2.91648
# [20]	validation_0-rmse:2.83345	validation_1-rmse:2.89813
# [21]	validation_0-rmse:2.80677	validation_1-rmse:2.88347
# [22]	validation_0-rmse:2.78718	validation_1-rmse:2.87739
# [23]	validation_0-rmse:2.76729	validation_1-rmse:2.86390
# [24]	validation_0-rmse:2.74818	validation_1-rmse:2.85535
# [25]	validation_0-rmse:2.72989	validation_1-rmse:2.84481
# [26]	validation_0-rmse:2.71675	validation_1-rmse:2.83802
# [27]	validation_0-rmse:2.70825	validation_1-rmse:2.83556
# [28]	validation_0-rmse:2.69653	validation_1-rmse:2.83184
# [29]	validation_0-rmse:2.68639	validation_1-rmse:2.82687
# [30]	validation_0-rmse:2.67579	validation_1-rmse:2.82423
# [31]	validation_0-rmse:2.66965	validation_1-rmse:2.81843
# [32]	validation_0-rmse:2.66073	validation_1-rmse:2.81675
# [33]	validation_0-rmse:2.65182	validation_1-rmse:2.81474
# [34]	validation_0-rmse:2.64659	validation_1-rmse:2.81534
# [35]	validation_0-rmse:2.64602	validation_1-rmse:2.81598
# [36]	validation_0-rmse:2.63924	validation_1-rmse:2.81629
# [37]	validation_0-rmse:2.63273	validation_1-rmse:2.81429
# [38]	validation_0-rmse:2.62635	validation_1-rmse:2.81223
# [39]	validation_0-rmse:2.62125	validation_1-rmse:2.81353
# [40]	validation_0-rmse:2.61976	validation_1-rmse:2.81447
# [41]	validation_0-rmse:2.61416	validation_1-rmse:2.81421
# [42]	validation_0-rmse:2.61167	validation_1-rmse:2.81711
# [0]	validation_0-rmse:6.79798	validation_1-rmse:6.02988
# [1]	validation_0-rmse:6.25215	validation_1-rmse:5.56343
# [2]	validation_0-rmse:5.77051	validation_1-rmse:5.15512
# [3]	validation_0-rmse:5.34470	validation_1-rmse:4.80001
# [4]	validation_0-rmse:4.97057	validation_1-rmse:4.48617
# [5]	validation_0-rmse:4.64327	validation_1-rmse:4.22252
# [6]	validation_0-rmse:4.35801	validation_1-rmse:3.99586
# [7]	validation_0-rmse:4.10905	validation_1-rmse:3.79050
# [8]	validation_0-rmse:3.89342	validation_1-rmse:3.62058
# [9]	validation_0-rmse:3.70731	validation_1-rmse:3.47686
# [10]	validation_0-rmse:3.54674	validation_1-rmse:3.35831
# [11]	validation_0-rmse:3.40764	validation_1-rmse:3.25770
# [12]	validation_0-rmse:3.28992	validation_1-rmse:3.17599
# [13]	validation_0-rmse:3.19021	validation_1-rmse:3.10378
# [14]	validation_0-rmse:3.10327	validation_1-rmse:3.04822
# [15]	validation_0-rmse:3.02985	validation_1-rmse:2.99701
# [16]	validation_0-rmse:2.96915	validation_1-rmse:2.95792
# [17]	validation_0-rmse:2.91447	validation_1-rmse:2.92377
# [18]	validation_0-rmse:2.86828	validation_1-rmse:2.89295
# [19]	validation_0-rmse:2.83138	validation_1-rmse:2.87356
# [20]	validation_0-rmse:2.79654	validation_1-rmse:2.85405
# [21]	validation_0-rmse:2.76712	validation_1-rmse:2.83812
# [22]	validation_0-rmse:2.74113	validation_1-rmse:2.82246
# [23]	validation_0-rmse:2.71720	validation_1-rmse:2.80967
# [24]	validation_0-rmse:2.69756	validation_1-rmse:2.80035
# [25]	validation_0-rmse:2.68108	validation_1-rmse:2.79393
# [26]	validation_0-rmse:2.66240	validation_1-rmse:2.78832
# [27]	validation_0-rmse:2.64714	validation_1-rmse:2.78326
# [28]	validation_0-rmse:2.63363	validation_1-rmse:2.77951
# [29]	validation_0-rmse:2.62105	validation_1-rmse:2.77338
# [30]	validation_0-rmse:2.60993	validation_1-rmse:2.77063
# [31]	validation_0-rmse:2.60040	validation_1-rmse:2.76969
# [32]	validation_0-rmse:2.59180	validation_1-rmse:2.76659
# [33]	validation_0-rmse:2.58496	validation_1-rmse:2.76411
# [34]	validation_0-rmse:2.57742	validation_1-rmse:2.76323
# [35]	validation_0-rmse:2.56845	validation_1-rmse:2.76026
# [36]	validation_0-rmse:2.56154	validation_1-rmse:2.75903
# [37]	validation_0-rmse:2.55583	validation_1-rmse:2.75878
# [38]	validation_0-rmse:2.54917	validation_1-rmse:2.75833
# [39]	validation_0-rmse:2.54354	validation_1-rmse:2.75803
# [40]	validation_0-rmse:2.53760	validation_1-rmse:2.75713
# [41]	validation_0-rmse:2.53209	validation_1-rmse:2.75517
# [42]	validation_0-rmse:2.52436	validation_1-rmse:2.75550
# [43]	validation_0-rmse:2.51767	validation_1-rmse:2.75538
# [44]	validation_0-rmse:2.51236	validation_1-rmse:2.75429
# [45]	validation_0-rmse:2.50754	validation_1-rmse:2.75412
# [46]	validation_0-rmse:2.50461	validation_1-rmse:2.75429
# [47]	validation_0-rmse:2.50156	validation_1-rmse:2.75426
# [48]	validation_0-rmse:2.49740	validation_1-rmse:2.75419
# [49]	validation_0-rmse:2.49473	validation_1-rmse:2.75318
# [50]	validation_0-rmse:2.49091	validation_1-rmse:2.75315
# [51]	validation_0-rmse:2.48746	validation_1-rmse:2.75263
# [52]	validation_0-rmse:2.48389	validation_1-rmse:2.75279
# [53]	validation_0-rmse:2.48150	validation_1-rmse:2.75260
# [54]	validation_0-rmse:2.47788	validation_1-rmse:2.75337
# [55]	validation_0-rmse:2.47526	validation_1-rmse:2.75295
# [56]	validation_0-rmse:2.47162	validation_1-rmse:2.75290
# [57]	validation_0-rmse:2.46604	validation_1-rmse:2.75134
# [58]	validation_0-rmse:2.46318	validation_1-rmse:2.75022
# [59]	validation_0-rmse:2.45900	validation_1-rmse:2.74625
# [60]	validation_0-rmse:2.45647	validation_1-rmse:2.74568
# [61]	validation_0-rmse:2.45177	validation_1-rmse:2.74595
# [62]	validation_0-rmse:2.44814	validation_1-rmse:2.74628
# [63]	validation_0-rmse:2.44530	validation_1-rmse:2.74591
# [64]	validation_0-rmse:2.44361	validation_1-rmse:2.74554
# [65]	validation_0-rmse:2.44037	validation_1-rmse:2.74582
# [66]	validation_0-rmse:2.43812	validation_1-rmse:2.74554
# [67]	validation_0-rmse:2.43535	validation_1-rmse:2.74546
# [68]	validation_0-rmse:2.43180	validation_1-rmse:2.74836
# [69]	validation_0-rmse:2.43045	validation_1-rmse:2.74811
# [70]	validation_0-rmse:2.42936	validation_1-rmse:2.74758
# [71]	validation_0-rmse:2.42692	validation_1-rmse:2.74748
# [0]	validation_0-rmse:6.79601	validation_1-rmse:6.03027
# [1]	validation_0-rmse:6.24644	validation_1-rmse:5.57133
# [2]	validation_0-rmse:5.76076	validation_1-rmse:5.15718
# [3]	validation_0-rmse:5.33195	validation_1-rmse:4.79957
# [4]	validation_0-rmse:4.95697	validation_1-rmse:4.49053
# [5]	validation_0-rmse:4.62767	validation_1-rmse:4.22503
# [6]	validation_0-rmse:4.33911	validation_1-rmse:3.98960
# [7]	validation_0-rmse:4.09026	validation_1-rmse:3.79439
# [8]	validation_0-rmse:3.87600	validation_1-rmse:3.62673
# [9]	validation_0-rmse:3.68914	validation_1-rmse:3.48231
# [10]	validation_0-rmse:3.52728	validation_1-rmse:3.36000
# [11]	validation_0-rmse:3.38682	validation_1-rmse:3.25630
# [12]	validation_0-rmse:3.26680	validation_1-rmse:3.17528
# [13]	validation_0-rmse:3.16610	validation_1-rmse:3.09864
# [14]	validation_0-rmse:3.08076	validation_1-rmse:3.04135
# [15]	validation_0-rmse:3.00603	validation_1-rmse:2.99492
# [16]	validation_0-rmse:2.94503	validation_1-rmse:2.95354
# [17]	validation_0-rmse:2.88971	validation_1-rmse:2.92232
# [18]	validation_0-rmse:2.84336	validation_1-rmse:2.89607
# [19]	validation_0-rmse:2.80351	validation_1-rmse:2.87589
# [20]	validation_0-rmse:2.76994	validation_1-rmse:2.85784
# [21]	validation_0-rmse:2.74134	validation_1-rmse:2.84352
# [22]	validation_0-rmse:2.71581	validation_1-rmse:2.83118
# [23]	validation_0-rmse:2.69277	validation_1-rmse:2.82032
# [24]	validation_0-rmse:2.67317	validation_1-rmse:2.81277
# [25]	validation_0-rmse:2.65602	validation_1-rmse:2.80688
# [26]	validation_0-rmse:2.64200	validation_1-rmse:2.80026
# [27]	validation_0-rmse:2.62688	validation_1-rmse:2.79490
# [28]	validation_0-rmse:2.61344	validation_1-rmse:2.79088
# [29]	validation_0-rmse:2.60184	validation_1-rmse:2.78816
# [30]	validation_0-rmse:2.59037	validation_1-rmse:2.78739
# [31]	validation_0-rmse:2.58166	validation_1-rmse:2.78579
# [32]	validation_0-rmse:2.57012	validation_1-rmse:2.78349
# [33]	validation_0-rmse:2.56107	validation_1-rmse:2.78216
# [34]	validation_0-rmse:2.55202	validation_1-rmse:2.78080
# [35]	validation_0-rmse:2.54284	validation_1-rmse:2.78108
# [36]	validation_0-rmse:2.53674	validation_1-rmse:2.77886
# [37]	validation_0-rmse:2.53206	validation_1-rmse:2.77775
# [38]	validation_0-rmse:2.52478	validation_1-rmse:2.77734
# [39]	validation_0-rmse:2.51826	validation_1-rmse:2.77675
# [40]	validation_0-rmse:2.51101	validation_1-rmse:2.77403
# [41]	validation_0-rmse:2.50724	validation_1-rmse:2.77166
# [42]	validation_0-rmse:2.50236	validation_1-rmse:2.77116
# [43]	validation_0-rmse:2.49575	validation_1-rmse:2.77100
# [44]	validation_0-rmse:2.49218	validation_1-rmse:2.77040
# [45]	validation_0-rmse:2.48839	validation_1-rmse:2.77000
# [46]	validation_0-rmse:2.48430	validation_1-rmse:2.77012
# [47]	validation_0-rmse:2.48115	validation_1-rmse:2.76957
# [48]	validation_0-rmse:2.47743	validation_1-rmse:2.76954
# [49]	validation_0-rmse:2.47453	validation_1-rmse:2.76982
# [50]	validation_0-rmse:2.47057	validation_1-rmse:2.76968
# [51]	validation_0-rmse:2.46863	validation_1-rmse:2.77002
# [52]	validation_0-rmse:2.46507	validation_1-rmse:2.77045
# [53]	validation_0-rmse:2.46147	validation_1-rmse:2.77019
# [0]	validation_0-rmse:6.81479	validation_1-rmse:6.02864
# [1]	validation_0-rmse:6.28513	validation_1-rmse:5.55442
# [2]	validation_0-rmse:5.81914	validation_1-rmse:5.13862
# [3]	validation_0-rmse:5.41015	validation_1-rmse:4.77959
# [4]	validation_0-rmse:5.05311	validation_1-rmse:4.46842
# [5]	validation_0-rmse:4.74042	validation_1-rmse:4.19635
# [6]	validation_0-rmse:4.46854	validation_1-rmse:3.96144
# [7]	validation_0-rmse:4.23498	validation_1-rmse:3.75952
# [8]	validation_0-rmse:4.03522	validation_1-rmse:3.59080
# [9]	validation_0-rmse:3.86457	validation_1-rmse:3.45144
# [10]	validation_0-rmse:3.71759	validation_1-rmse:3.33898
# [11]	validation_0-rmse:3.59357	validation_1-rmse:3.23671
# [12]	validation_0-rmse:3.48426	validation_1-rmse:3.14743
# [13]	validation_0-rmse:3.39576	validation_1-rmse:3.08168
# [14]	validation_0-rmse:3.31831	validation_1-rmse:3.01957
# [15]	validation_0-rmse:3.25615	validation_1-rmse:2.97346
# [16]	validation_0-rmse:3.20432	validation_1-rmse:2.93575
# [17]	validation_0-rmse:3.16003	validation_1-rmse:2.90588
# [18]	validation_0-rmse:3.12031	validation_1-rmse:2.87716
# [19]	validation_0-rmse:3.08653	validation_1-rmse:2.85311
# [20]	validation_0-rmse:3.05955	validation_1-rmse:2.83482
# [21]	validation_0-rmse:3.03599	validation_1-rmse:2.82044
# [22]	validation_0-rmse:3.01482	validation_1-rmse:2.80784
# [23]	validation_0-rmse:2.99957	validation_1-rmse:2.80084
# [24]	validation_0-rmse:2.98319	validation_1-rmse:2.79136
# [25]	validation_0-rmse:2.97055	validation_1-rmse:2.78312
# [26]	validation_0-rmse:2.95974	validation_1-rmse:2.77605
# [27]	validation_0-rmse:2.94893	validation_1-rmse:2.77428
# [28]	validation_0-rmse:2.97178	validation_1-rmse:2.80295
# [29]	validation_0-rmse:2.96639	validation_1-rmse:2.79971
# [30]	validation_0-rmse:2.96017	validation_1-rmse:2.79654
# [31]	validation_0-rmse:2.96025	validation_1-rmse:2.80408
# [32]	validation_0-rmse:2.95463	validation_1-rmse:2.80355
# [0]	validation_0-rmse:6.81443	validation_1-rmse:6.02767
# [1]	validation_0-rmse:6.28392	validation_1-rmse:5.55175
# [2]	validation_0-rmse:5.81702	validation_1-rmse:5.13712
# [3]	validation_0-rmse:5.40694	validation_1-rmse:4.77562
# [4]	validation_0-rmse:5.04966	validation_1-rmse:4.46073
# [5]	validation_0-rmse:4.73760	validation_1-rmse:4.19182
# [6]	validation_0-rmse:4.46792	validation_1-rmse:3.95945
# [7]	validation_0-rmse:4.23572	validation_1-rmse:3.76197
# [8]	validation_0-rmse:4.03665	validation_1-rmse:3.59308
# [9]	validation_0-rmse:3.86432	validation_1-rmse:3.44602
# [10]	validation_0-rmse:3.71958	validation_1-rmse:3.32602
# [11]	validation_0-rmse:3.59443	validation_1-rmse:3.21338
# [12]	validation_0-rmse:3.48972	validation_1-rmse:3.12787
# [13]	validation_0-rmse:3.39973	validation_1-rmse:3.06037
# [14]	validation_0-rmse:3.32576	validation_1-rmse:3.00373
# [15]	validation_0-rmse:3.26364	validation_1-rmse:2.96145
# [16]	validation_0-rmse:3.21080	validation_1-rmse:2.92388
# [17]	validation_0-rmse:3.16349	validation_1-rmse:2.88967
# [18]	validation_0-rmse:3.12464	validation_1-rmse:2.87227
# [19]	validation_0-rmse:3.09216	validation_1-rmse:2.85149
# [20]	validation_0-rmse:3.06564	validation_1-rmse:2.83135
# [21]	validation_0-rmse:3.04186	validation_1-rmse:2.82337
# [22]	validation_0-rmse:3.02132	validation_1-rmse:2.80760
# [23]	validation_0-rmse:3.00428	validation_1-rmse:2.79723
# [24]	validation_0-rmse:2.99041	validation_1-rmse:2.78896
# [25]	validation_0-rmse:2.97587	validation_1-rmse:2.78252
# [26]	validation_0-rmse:2.96062	validation_1-rmse:2.77768
# [27]	validation_0-rmse:2.94826	validation_1-rmse:2.77211
# [28]	validation_0-rmse:2.94105	validation_1-rmse:2.76943
# [29]	validation_0-rmse:2.93118	validation_1-rmse:2.76561
# [30]	validation_0-rmse:2.92393	validation_1-rmse:2.76251
# [31]	validation_0-rmse:2.91832	validation_1-rmse:2.76070
# [32]	validation_0-rmse:2.91439	validation_1-rmse:2.75994
# [33]	validation_0-rmse:2.90806	validation_1-rmse:2.75838
# [34]	validation_0-rmse:2.90171	validation_1-rmse:2.75549
# [35]	validation_0-rmse:2.89792	validation_1-rmse:2.75558
# [36]	validation_0-rmse:2.89182	validation_1-rmse:2.75480
# [37]	validation_0-rmse:2.88574	validation_1-rmse:2.75389
# [38]	validation_0-rmse:2.88061	validation_1-rmse:2.75377
# [39]	validation_0-rmse:2.87658	validation_1-rmse:2.75539
# [40]	validation_0-rmse:2.87245	validation_1-rmse:2.75483
# [41]	validation_0-rmse:2.86896	validation_1-rmse:2.75723
# [42]	validation_0-rmse:2.86607	validation_1-rmse:2.75628
# [0]	validation_0-rmse:6.80957	validation_1-rmse:6.02454
# [1]	validation_0-rmse:6.27557	validation_1-rmse:5.54756
# [2]	validation_0-rmse:5.80548	validation_1-rmse:5.12979
# [3]	validation_0-rmse:5.39406	validation_1-rmse:4.76903
# [4]	validation_0-rmse:5.03552	validation_1-rmse:4.45352
# [5]	validation_0-rmse:4.72329	validation_1-rmse:4.17930
# [6]	validation_0-rmse:4.45432	validation_1-rmse:3.95045
# [7]	validation_0-rmse:4.22029	validation_1-rmse:3.75427
# [8]	validation_0-rmse:4.02061	validation_1-rmse:3.58915
# [9]	validation_0-rmse:3.85082	validation_1-rmse:3.44901
# [10]	validation_0-rmse:3.70591	validation_1-rmse:3.33324
# [11]	validation_0-rmse:3.58310	validation_1-rmse:3.23053
# [12]	validation_0-rmse:3.47565	validation_1-rmse:3.14659
# [13]	validation_0-rmse:3.38843	validation_1-rmse:3.07904
# [14]	validation_0-rmse:3.31518	validation_1-rmse:3.02422
# [15]	validation_0-rmse:3.25092	validation_1-rmse:2.97976
# [16]	validation_0-rmse:3.19783	validation_1-rmse:2.95078
# [17]	validation_0-rmse:3.15448	validation_1-rmse:2.91235
# [18]	validation_0-rmse:3.11381	validation_1-rmse:2.88607
# [19]	validation_0-rmse:3.08266	validation_1-rmse:2.86381
# [20]	validation_0-rmse:3.05225	validation_1-rmse:2.84166
# [21]	validation_0-rmse:3.02741	validation_1-rmse:2.82789
# [22]	validation_0-rmse:3.00915	validation_1-rmse:2.81799
# [23]	validation_0-rmse:2.99064	validation_1-rmse:2.80928
# [24]	validation_0-rmse:2.97640	validation_1-rmse:2.80187
# [25]	validation_0-rmse:2.96172	validation_1-rmse:2.79330
# [26]	validation_0-rmse:2.94973	validation_1-rmse:2.78578
# [27]	validation_0-rmse:2.94017	validation_1-rmse:2.78301
# [28]	validation_0-rmse:2.93014	validation_1-rmse:2.77727
# [29]	validation_0-rmse:2.92279	validation_1-rmse:2.77348
# [30]	validation_0-rmse:2.91606	validation_1-rmse:2.76913
# [31]	validation_0-rmse:2.91096	validation_1-rmse:2.76930
# [32]	validation_0-rmse:2.90455	validation_1-rmse:2.76878
# [33]	validation_0-rmse:2.89829	validation_1-rmse:2.77085
# [34]	validation_0-rmse:2.89321	validation_1-rmse:2.76884
# [35]	validation_0-rmse:2.88754	validation_1-rmse:2.76765
# [36]	validation_0-rmse:2.88278	validation_1-rmse:2.76662
# [37]	validation_0-rmse:2.87779	validation_1-rmse:2.76552
# [38]	validation_0-rmse:2.87287	validation_1-rmse:2.76588
# [39]	validation_0-rmse:2.86906	validation_1-rmse:2.76808
# [40]	validation_0-rmse:2.86586	validation_1-rmse:2.76737
# [41]	validation_0-rmse:2.86267	validation_1-rmse:2.76636
# [42]	validation_0-rmse:2.85737	validation_1-rmse:2.76634
# [0]	validation_0-rmse:6.80321	validation_1-rmse:6.04066
# [1]	validation_0-rmse:6.26493	validation_1-rmse:5.58318
# [2]	validation_0-rmse:5.78835	validation_1-rmse:5.17411
# [3]	validation_0-rmse:5.36510	validation_1-rmse:4.81349
# [4]	validation_0-rmse:4.99396	validation_1-rmse:4.50747
# [5]	validation_0-rmse:4.66462	validation_1-rmse:4.24227
# [6]	validation_0-rmse:4.38251	validation_1-rmse:4.01580
# [7]	validation_0-rmse:4.13773	validation_1-rmse:3.82475
# [8]	validation_0-rmse:3.92075	validation_1-rmse:3.66195
# [9]	validation_0-rmse:3.73499	validation_1-rmse:3.52069
# [10]	validation_0-rmse:3.57531	validation_1-rmse:3.39737
# [11]	validation_0-rmse:3.43666	validation_1-rmse:3.29530
# [12]	validation_0-rmse:3.31909	validation_1-rmse:3.21248
# [13]	validation_0-rmse:3.21881	validation_1-rmse:3.14367
# [14]	validation_0-rmse:3.13178	validation_1-rmse:3.08719
# [15]	validation_0-rmse:3.06077	validation_1-rmse:3.04399
# [16]	validation_0-rmse:2.99971	validation_1-rmse:3.00551
# [17]	validation_0-rmse:2.94791	validation_1-rmse:2.97008
# [18]	validation_0-rmse:2.90372	validation_1-rmse:2.94083
# [19]	validation_0-rmse:2.86403	validation_1-rmse:2.92248
# [20]	validation_0-rmse:2.83174	validation_1-rmse:2.90305
# [21]	validation_0-rmse:2.80420	validation_1-rmse:2.88784
# [22]	validation_0-rmse:2.77956	validation_1-rmse:2.87684
# [23]	validation_0-rmse:2.75776	validation_1-rmse:2.86517
# [24]	validation_0-rmse:2.74096	validation_1-rmse:2.85775
# [25]	validation_0-rmse:2.72363	validation_1-rmse:2.85073
# [26]	validation_0-rmse:2.70483	validation_1-rmse:2.84259
# [27]	validation_0-rmse:2.69078	validation_1-rmse:2.83729
# [28]	validation_0-rmse:2.67904	validation_1-rmse:2.83273
# [29]	validation_0-rmse:2.66771	validation_1-rmse:2.83025
# [30]	validation_0-rmse:2.65760	validation_1-rmse:2.82800
# [31]	validation_0-rmse:2.65013	validation_1-rmse:2.82718
# [32]	validation_0-rmse:2.64964	validation_1-rmse:2.83231
# [33]	validation_0-rmse:2.64410	validation_1-rmse:2.83214
# [34]	validation_0-rmse:2.63713	validation_1-rmse:2.82996
# [35]	validation_0-rmse:2.62979	validation_1-rmse:2.82562
# [36]	validation_0-rmse:2.62263	validation_1-rmse:2.82409
# [37]	validation_0-rmse:2.61479	validation_1-rmse:2.82245
# [38]	validation_0-rmse:2.60807	validation_1-rmse:2.82140
# [39]	validation_0-rmse:2.60253	validation_1-rmse:2.82219
# [40]	validation_0-rmse:2.59770	validation_1-rmse:2.81923
# [41]	validation_0-rmse:2.59377	validation_1-rmse:2.81994
# [42]	validation_0-rmse:2.58835	validation_1-rmse:2.81850
# [43]	validation_0-rmse:2.58431	validation_1-rmse:2.82007
# [44]	validation_0-rmse:2.58608	validation_1-rmse:2.82461
# [45]	validation_0-rmse:2.58087	validation_1-rmse:2.82498
# [46]	validation_0-rmse:2.57746	validation_1-rmse:2.82542
# [47]	validation_0-rmse:2.58247	validation_1-rmse:2.82631
# [0]	validation_0-rmse:6.79799	validation_1-rmse:6.02969
# [1]	validation_0-rmse:6.25218	validation_1-rmse:5.56326
# [2]	validation_0-rmse:5.77061	validation_1-rmse:5.15506
# [3]	validation_0-rmse:5.34472	validation_1-rmse:4.80020
# [4]	validation_0-rmse:4.97066	validation_1-rmse:4.48634
# [5]	validation_0-rmse:4.64338	validation_1-rmse:4.22268
# [6]	validation_0-rmse:4.35813	validation_1-rmse:3.99699
# [7]	validation_0-rmse:4.10941	validation_1-rmse:3.79080
# [8]	validation_0-rmse:3.89413	validation_1-rmse:3.62104
# [9]	validation_0-rmse:3.70794	validation_1-rmse:3.47582
# [10]	validation_0-rmse:3.54751	validation_1-rmse:3.35772
# [11]	validation_0-rmse:3.40827	validation_1-rmse:3.25706
# [12]	validation_0-rmse:3.29097	validation_1-rmse:3.17553
# [13]	validation_0-rmse:3.19108	validation_1-rmse:3.10528
# [14]	validation_0-rmse:3.10693	validation_1-rmse:3.04840
# [15]	validation_0-rmse:3.03434	validation_1-rmse:3.00209
# [16]	validation_0-rmse:2.97087	validation_1-rmse:2.96212
# [17]	validation_0-rmse:2.91947	validation_1-rmse:2.92860
# [18]	validation_0-rmse:2.87157	validation_1-rmse:2.89875
# [19]	validation_0-rmse:2.83377	validation_1-rmse:2.87675
# [20]	validation_0-rmse:2.79910	validation_1-rmse:2.85764
# [21]	validation_0-rmse:2.76897	validation_1-rmse:2.83903
# [22]	validation_0-rmse:2.74171	validation_1-rmse:2.82666
# [23]	validation_0-rmse:2.72190	validation_1-rmse:2.81418
# [24]	validation_0-rmse:2.70146	validation_1-rmse:2.80350
# [25]	validation_0-rmse:2.68336	validation_1-rmse:2.79602
# [26]	validation_0-rmse:2.66638	validation_1-rmse:2.78785
# [27]	validation_0-rmse:2.65246	validation_1-rmse:2.78386
# [28]	validation_0-rmse:2.63818	validation_1-rmse:2.77997
# [29]	validation_0-rmse:2.62603	validation_1-rmse:2.77494
# [30]	validation_0-rmse:2.61484	validation_1-rmse:2.77186
# [31]	validation_0-rmse:2.60428	validation_1-rmse:2.76866
# [32]	validation_0-rmse:2.59574	validation_1-rmse:2.76505
# [33]	validation_0-rmse:2.58860	validation_1-rmse:2.76375
# [34]	validation_0-rmse:2.58073	validation_1-rmse:2.76183
# [35]	validation_0-rmse:2.57288	validation_1-rmse:2.76143
# [36]	validation_0-rmse:2.56329	validation_1-rmse:2.75913
# [37]	validation_0-rmse:2.55935	validation_1-rmse:2.76051
# [38]	validation_0-rmse:2.55341	validation_1-rmse:2.75867
# [39]	validation_0-rmse:2.54653	validation_1-rmse:2.75822
# [40]	validation_0-rmse:2.54080	validation_1-rmse:2.75615
# [41]	validation_0-rmse:2.53731	validation_1-rmse:2.75591
# [42]	validation_0-rmse:2.53006	validation_1-rmse:2.75494
# [43]	validation_0-rmse:2.52299	validation_1-rmse:2.75637
# [44]	validation_0-rmse:2.51855	validation_1-rmse:2.75807
# [45]	validation_0-rmse:2.51343	validation_1-rmse:2.75796
# [46]	validation_0-rmse:2.50808	validation_1-rmse:2.75758
# [47]	validation_0-rmse:2.50184	validation_1-rmse:2.75690
# [0]	validation_0-rmse:6.79601	validation_1-rmse:6.03026
# [1]	validation_0-rmse:6.24644	validation_1-rmse:5.57040
# [2]	validation_0-rmse:5.76082	validation_1-rmse:5.15668
# [3]	validation_0-rmse:5.33196	validation_1-rmse:4.79888
# [4]	validation_0-rmse:4.95667	validation_1-rmse:4.48984
# [5]	validation_0-rmse:4.62711	validation_1-rmse:4.22334
# [6]	validation_0-rmse:4.33908	validation_1-rmse:3.98859
# [7]	validation_0-rmse:4.09012	validation_1-rmse:3.79395
# [8]	validation_0-rmse:3.87436	validation_1-rmse:3.63045
# [9]	validation_0-rmse:3.68714	validation_1-rmse:3.48537
# [10]	validation_0-rmse:3.52568	validation_1-rmse:3.36531
# [11]	validation_0-rmse:3.38478	validation_1-rmse:3.26070
# [12]	validation_0-rmse:3.26506	validation_1-rmse:3.17706
# [13]	validation_0-rmse:3.16469	validation_1-rmse:3.10539
# [14]	validation_0-rmse:3.07818	validation_1-rmse:3.04391
# [15]	validation_0-rmse:3.00542	validation_1-rmse:2.99543
# [16]	validation_0-rmse:2.94241	validation_1-rmse:2.95520
# [17]	validation_0-rmse:2.88771	validation_1-rmse:2.92127
# [18]	validation_0-rmse:2.84100	validation_1-rmse:2.89462
# [19]	validation_0-rmse:2.80111	validation_1-rmse:2.87269
# [20]	validation_0-rmse:2.76878	validation_1-rmse:2.85326
# [21]	validation_0-rmse:2.74060	validation_1-rmse:2.83703
# [22]	validation_0-rmse:2.71499	validation_1-rmse:2.82489
# [23]	validation_0-rmse:2.69345	validation_1-rmse:2.81614
# [24]	validation_0-rmse:2.67331	validation_1-rmse:2.80591
# [25]	validation_0-rmse:2.65736	validation_1-rmse:2.80163
# [26]	validation_0-rmse:2.64338	validation_1-rmse:2.80223
# [27]	validation_0-rmse:2.62942	validation_1-rmse:2.79736
# [28]	validation_0-rmse:2.61712	validation_1-rmse:2.79301
# [29]	validation_0-rmse:2.60313	validation_1-rmse:2.78896
# [30]	validation_0-rmse:2.59271	validation_1-rmse:2.78411
# [31]	validation_0-rmse:2.58420	validation_1-rmse:2.78026
# [32]	validation_0-rmse:2.57493	validation_1-rmse:2.77828
# [33]	validation_0-rmse:2.56317	validation_1-rmse:2.77619
# [34]	validation_0-rmse:2.55537	validation_1-rmse:2.77685
# [35]	validation_0-rmse:2.54953	validation_1-rmse:2.77522
# [36]	validation_0-rmse:2.54094	validation_1-rmse:2.77420
# [37]	validation_0-rmse:2.53386	validation_1-rmse:2.77422
# [38]	validation_0-rmse:2.52719	validation_1-rmse:2.77402
# [39]	validation_0-rmse:2.52083	validation_1-rmse:2.77349
# [40]	validation_0-rmse:2.51439	validation_1-rmse:2.77401
# [41]	validation_0-rmse:2.50862	validation_1-rmse:2.77340
# [42]	validation_0-rmse:2.50325	validation_1-rmse:2.77355
# [43]	validation_0-rmse:2.49959	validation_1-rmse:2.77364
# [44]	validation_0-rmse:2.49420	validation_1-rmse:2.77294
# [45]	validation_0-rmse:2.48957	validation_1-rmse:2.77239
# [46]	validation_0-rmse:2.48450	validation_1-rmse:2.77299
# [47]	validation_0-rmse:2.48237	validation_1-rmse:2.77241
# [48]	validation_0-rmse:2.47849	validation_1-rmse:2.77160
# [49]	validation_0-rmse:2.47581	validation_1-rmse:2.77102
# [50]	validation_0-rmse:2.47291	validation_1-rmse:2.77228
# [51]	validation_0-rmse:2.46908	validation_1-rmse:2.77124
# [52]	validation_0-rmse:2.46469	validation_1-rmse:2.77095
# [53]	validation_0-rmse:2.46219	validation_1-rmse:2.77047
# [54]	validation_0-rmse:2.45891	validation_1-rmse:2.76893
# [55]	validation_0-rmse:2.45718	validation_1-rmse:2.76907
# [56]	validation_0-rmse:2.45612	validation_1-rmse:2.76847
# [57]	validation_0-rmse:2.45293	validation_1-rmse:2.76838
# ...
# [37]	validation_0-rmse:2.88351	validation_1-rmse:2.75746
# [38]	validation_0-rmse:2.87873	validation_1-rmse:2.76018
# [39]	validation_0-rmse:2.87454	validation_1-rmse:2.75878
# [40]	validation_0-rmse:2.86870	validation_1-rmse:2.75713
# [41]	validation_0-rmse:2.86557	validation_1-rmse:2.75629
# [42]	validation_0-rmse:2.86231	validation_1-rmse:2.75758
# [43]	validation_0-rmse:2.85979	validation_1-rmse:2.75698
# [44]	validation_0-rmse:2.85654	validation_1-rmse:2.75671
# [45]	validation_0-rmse:2.85313	validation_1-rmse:2.75586
# [46]	validation_0-rmse:2.85094	validation_1-rmse:2.75518
# [47]	validation_0-rmse:2.84817	validation_1-rmse:2.75597
# [48]	validation_0-rmse:2.84634	validation_1-rmse:2.75567
# [49]	validation_0-rmse:2.84440	validation_1-rmse:2.75526
# [50]	validation_0-rmse:2.84301	validation_1-rmse:2.75515
# [51]	validation_0-rmse:2.84112	validation_1-rmse:2.75466
# [52]	validation_0-rmse:2.83749	validation_1-rmse:2.75359
# [53]	validation_0-rmse:2.83488	validation_1-rmse:2.75231
# [54]	validation_0-rmse:2.83327	validation_1-rmse:2.75054
# [55]	validation_0-rmse:2.83117	validation_1-rmse:2.75036
# [56]	validation_0-rmse:2.82917	validation_1-rmse:2.74995
# [57]	validation_0-rmse:2.82840	validation_1-rmse:2.75004
# [58]	validation_0-rmse:2.82638	validation_1-rmse:2.74724
# [59]	validation_0-rmse:2.82329	validation_1-rmse:2.74712
# [60]	validation_0-rmse:2.82226	validation_1-rmse:2.74696
# [61]	validation_0-rmse:2.82048	validation_1-rmse:2.74713
# [62]	validation_0-rmse:2.81879	validation_1-rmse:2.74719
# [63]	validation_0-rmse:2.81714	validation_1-rmse:2.74636
# [64]	validation_0-rmse:2.81329	validation_1-rmse:2.74574
# [65]	validation_0-rmse:2.81283	validation_1-rmse:2.74571
# [66]	validation_0-rmse:2.81133	validation_1-rmse:2.74545
# [67]	validation_0-rmse:2.80848	validation_1-rmse:2.74599
# [68]	validation_0-rmse:2.80531	validation_1-rmse:2.74552
# [69]	validation_0-rmse:2.80251	validation_1-rmse:2.74528
# [70]	validation_0-rmse:2.80094	validation_1-rmse:2.74544
# [71]	validation_0-rmse:2.80012	validation_1-rmse:2.74629
# [72]	validation_0-rmse:2.79784	validation_1-rmse:2.74803
# [73]	validation_0-rmse:2.79530	validation_1-rmse:2.74736
# [0]	validation_0-rmse:6.80959	validation_1-rmse:6.02456
# [1]	validation_0-rmse:6.27561	validation_1-rmse:5.54759
# [2]	validation_0-rmse:5.80554	validation_1-rmse:5.12984
# [3]	validation_0-rmse:5.39414	validation_1-rmse:4.76908
# [4]	validation_0-rmse:5.03561	validation_1-rmse:4.45358
# [5]	validation_0-rmse:4.72338	validation_1-rmse:4.17937
# [6]	validation_0-rmse:4.45442	validation_1-rmse:3.95051
# [7]	validation_0-rmse:4.22040	validation_1-rmse:3.75434
# [8]	validation_0-rmse:4.02072	validation_1-rmse:3.58922
# [9]	validation_0-rmse:3.85090	validation_1-rmse:3.44939
# [10]	validation_0-rmse:3.70602	validation_1-rmse:3.33360
# [11]	validation_0-rmse:3.58312	validation_1-rmse:3.23110
# [12]	validation_0-rmse:3.47572	validation_1-rmse:3.14715
# [13]	validation_0-rmse:3.38882	validation_1-rmse:3.07901
# [14]	validation_0-rmse:3.31566	validation_1-rmse:3.02233
# [15]	validation_0-rmse:3.25166	validation_1-rmse:2.97490
# [16]	validation_0-rmse:3.19782	validation_1-rmse:2.94085
# [17]	validation_0-rmse:3.15323	validation_1-rmse:2.91030
# [18]	validation_0-rmse:3.11467	validation_1-rmse:2.87729
# [19]	validation_0-rmse:3.08409	validation_1-rmse:2.86427
# [20]	validation_0-rmse:3.05409	validation_1-rmse:2.84469
# [21]	validation_0-rmse:3.03146	validation_1-rmse:2.83368
# [22]	validation_0-rmse:3.01234	validation_1-rmse:2.82098
# [23]	validation_0-rmse:2.99551	validation_1-rmse:2.80934
# [24]	validation_0-rmse:2.97950	validation_1-rmse:2.79953
# [25]	validation_0-rmse:2.96610	validation_1-rmse:2.79231
# [26]	validation_0-rmse:2.95221	validation_1-rmse:2.78812
# [27]	validation_0-rmse:2.94236	validation_1-rmse:2.78390
# [28]	validation_0-rmse:2.93357	validation_1-rmse:2.77921
# [29]	validation_0-rmse:2.92501	validation_1-rmse:2.77460
# [30]	validation_0-rmse:2.91663	validation_1-rmse:2.77244
# [31]	validation_0-rmse:2.90939	validation_1-rmse:2.76957
# [32]	validation_0-rmse:2.90226	validation_1-rmse:2.76796
# [33]	validation_0-rmse:2.89726	validation_1-rmse:2.76767
# [34]	validation_0-rmse:2.89363	validation_1-rmse:2.76688
# [35]	validation_0-rmse:2.88791	validation_1-rmse:2.76444
# [36]	validation_0-rmse:2.88322	validation_1-rmse:2.76359
# [37]	validation_0-rmse:2.87979	validation_1-rmse:2.76525
# [38]	validation_0-rmse:2.87562	validation_1-rmse:2.76391
# [39]	validation_0-rmse:2.87170	validation_1-rmse:2.76392
# [40]	validation_0-rmse:2.86630	validation_1-rmse:2.76214
# [41]	validation_0-rmse:2.86155	validation_1-rmse:2.76265
# [42]	validation_0-rmse:2.85860	validation_1-rmse:2.76264
# [43]	validation_0-rmse:2.85442	validation_1-rmse:2.76656
# [44]	validation_0-rmse:2.85216	validation_1-rmse:2.76503
# [45]	validation_0-rmse:2.85058	validation_1-rmse:2.76486
# [0]	validation_0-rmse:6.80272	validation_1-rmse:6.04030
# [1]	validation_0-rmse:6.27196	validation_1-rmse:5.58675
# [2]	validation_0-rmse:5.79436	validation_1-rmse:5.17886
# [3]	validation_0-rmse:5.37131	validation_1-rmse:4.81950
# [4]	validation_0-rmse:4.99747	validation_1-rmse:4.51011
# [5]	validation_0-rmse:4.67207	validation_1-rmse:4.24983
# [6]	validation_0-rmse:4.38409	validation_1-rmse:4.03237
# [7]	validation_0-rmse:4.13766	validation_1-rmse:3.83574
# [8]	validation_0-rmse:3.92318	validation_1-rmse:3.66645
# [9]	validation_0-rmse:3.73692	validation_1-rmse:3.53048
# [10]	validation_0-rmse:3.57627	validation_1-rmse:3.41239
# [11]	validation_0-rmse:3.43867	validation_1-rmse:3.31551
# [12]	validation_0-rmse:3.32170	validation_1-rmse:3.23399
# [13]	validation_0-rmse:3.22183	validation_1-rmse:3.16649
# [14]	validation_0-rmse:3.13710	validation_1-rmse:3.10490
# [15]	validation_0-rmse:3.06191	validation_1-rmse:3.05843
# [16]	validation_0-rmse:3.00170	validation_1-rmse:3.01921
# [17]	validation_0-rmse:2.94845	validation_1-rmse:2.98313
# [18]	validation_0-rmse:2.90344	validation_1-rmse:2.95407
# [19]	validation_0-rmse:2.86388	validation_1-rmse:2.92757
# [20]	validation_0-rmse:2.83129	validation_1-rmse:2.90771
# [21]	validation_0-rmse:2.80265	validation_1-rmse:2.88956
# [22]	validation_0-rmse:2.77896	validation_1-rmse:2.87503
# [23]	validation_0-rmse:2.75672	validation_1-rmse:2.86756
# [24]	validation_0-rmse:2.73629	validation_1-rmse:2.86110
# [25]	validation_0-rmse:2.71963	validation_1-rmse:2.85013
# [26]	validation_0-rmse:2.70365	validation_1-rmse:2.84363
# [27]	validation_0-rmse:2.69547	validation_1-rmse:2.84199
# [28]	validation_0-rmse:2.68277	validation_1-rmse:2.83669
# [29]	validation_0-rmse:2.67169	validation_1-rmse:2.83275
# [30]	validation_0-rmse:2.66098	validation_1-rmse:2.83129
# [31]	validation_0-rmse:2.65828	validation_1-rmse:2.83236
# [32]	validation_0-rmse:2.65180	validation_1-rmse:2.82615
# [33]	validation_0-rmse:2.64321	validation_1-rmse:2.82564
# [34]	validation_0-rmse:2.63989	validation_1-rmse:2.82279
# [35]	validation_0-rmse:2.63339	validation_1-rmse:2.82219
# [36]	validation_0-rmse:2.62731	validation_1-rmse:2.82143
# [37]	validation_0-rmse:2.62196	validation_1-rmse:2.82060
# [38]	validation_0-rmse:2.61727	validation_1-rmse:2.82132
# [39]	validation_0-rmse:2.61400	validation_1-rmse:2.82156
# [40]	validation_0-rmse:2.60846	validation_1-rmse:2.82030
# [41]	validation_0-rmse:2.60257	validation_1-rmse:2.82084
# [42]	validation_0-rmse:2.59686	validation_1-rmse:2.82042
# [43]	validation_0-rmse:2.59242	validation_1-rmse:2.81949
# [44]	validation_0-rmse:2.59075	validation_1-rmse:2.82036
# [45]	validation_0-rmse:2.59278	validation_1-rmse:2.82345
# [46]	validation_0-rmse:2.58914	validation_1-rmse:2.82312
# [47]	validation_0-rmse:2.58331	validation_1-rmse:2.82414
# [48]	validation_0-rmse:2.59140	validation_1-rmse:2.83014
# [0]	validation_0-rmse:6.79824	validation_1-rmse:6.03007
# [1]	validation_0-rmse:6.25261	validation_1-rmse:5.56331
# [2]	validation_0-rmse:5.77156	validation_1-rmse:5.15586
# [3]	validation_0-rmse:5.34542	validation_1-rmse:4.80186
# [4]	validation_0-rmse:4.97213	validation_1-rmse:4.48992
# [5]	validation_0-rmse:4.64559	validation_1-rmse:4.22591
# [6]	validation_0-rmse:4.36065	validation_1-rmse:3.99664
# [7]	validation_0-rmse:4.11154	validation_1-rmse:3.80004
# [8]	validation_0-rmse:3.89659	validation_1-rmse:3.62917
# [9]	validation_0-rmse:3.71145	validation_1-rmse:3.48226
# [10]	validation_0-rmse:3.54960	validation_1-rmse:3.35801
# [11]	validation_0-rmse:3.41136	validation_1-rmse:3.25072
# [12]	validation_0-rmse:3.29353	validation_1-rmse:3.16293
# [13]	validation_0-rmse:3.19301	validation_1-rmse:3.09645
# [14]	validation_0-rmse:3.10772	validation_1-rmse:3.03995
# [15]	validation_0-rmse:3.03441	validation_1-rmse:2.99007
# [16]	validation_0-rmse:2.97183	validation_1-rmse:2.95100
# [17]	validation_0-rmse:2.91693	validation_1-rmse:2.91517
# [18]	validation_0-rmse:2.87051	validation_1-rmse:2.88942
# [19]	validation_0-rmse:2.83171	validation_1-rmse:2.86535
# [20]	validation_0-rmse:2.79649	validation_1-rmse:2.84453
# [21]	validation_0-rmse:2.76694	validation_1-rmse:2.82513
# [22]	validation_0-rmse:2.74083	validation_1-rmse:2.80931
# [23]	validation_0-rmse:2.72085	validation_1-rmse:2.79907
# [24]	validation_0-rmse:2.70203	validation_1-rmse:2.78997
# [25]	validation_0-rmse:2.68429	validation_1-rmse:2.78343
# [26]	validation_0-rmse:2.66623	validation_1-rmse:2.77678
# [27]	validation_0-rmse:2.65105	validation_1-rmse:2.77040
# [28]	validation_0-rmse:2.63632	validation_1-rmse:2.76515
# [29]	validation_0-rmse:2.62414	validation_1-rmse:2.76426
# [30]	validation_0-rmse:2.61363	validation_1-rmse:2.76160
# [31]	validation_0-rmse:2.60531	validation_1-rmse:2.75848
# [32]	validation_0-rmse:2.59574	validation_1-rmse:2.75706
# [33]	validation_0-rmse:2.58719	validation_1-rmse:2.75502
# [34]	validation_0-rmse:2.57835	validation_1-rmse:2.75274
# [35]	validation_0-rmse:2.56831	validation_1-rmse:2.75168
# [36]	validation_0-rmse:2.55985	validation_1-rmse:2.75034
# [37]	validation_0-rmse:2.55452	validation_1-rmse:2.74835
# [38]	validation_0-rmse:2.54957	validation_1-rmse:2.74789
# [39]	validation_0-rmse:2.54284	validation_1-rmse:2.74765
# [40]	validation_0-rmse:2.53597	validation_1-rmse:2.74963
# [41]	validation_0-rmse:2.53004	validation_1-rmse:2.75063
# [42]	validation_0-rmse:2.52518	validation_1-rmse:2.75100
# [43]	validation_0-rmse:2.52053	validation_1-rmse:2.75409
# [44]	validation_0-rmse:2.51612	validation_1-rmse:2.75381
# [0]	validation_0-rmse:6.79622	validation_1-rmse:6.03033
# [1]	validation_0-rmse:6.24645	validation_1-rmse:5.56988
# [2]	validation_0-rmse:5.76122	validation_1-rmse:5.15740
# [3]	validation_0-rmse:5.33264	validation_1-rmse:4.79777
# [4]	validation_0-rmse:4.95740	validation_1-rmse:4.48634
# [5]	validation_0-rmse:4.62752	validation_1-rmse:4.21801
# [6]	validation_0-rmse:4.33957	validation_1-rmse:3.99401
# [7]	validation_0-rmse:4.09041	validation_1-rmse:3.79863
# [8]	validation_0-rmse:3.87370	validation_1-rmse:3.62924
# [9]	validation_0-rmse:3.68828	validation_1-rmse:3.48422
# [10]	validation_0-rmse:3.52460	validation_1-rmse:3.36078
# [11]	validation_0-rmse:3.38462	validation_1-rmse:3.25981
# [12]	validation_0-rmse:3.26549	validation_1-rmse:3.17289
# [13]	validation_0-rmse:3.16481	validation_1-rmse:3.10249
# [14]	validation_0-rmse:3.07846	validation_1-rmse:3.04192
# [15]	validation_0-rmse:3.00564	validation_1-rmse:2.99475
# [16]	validation_0-rmse:2.94222	validation_1-rmse:2.95306
# [17]	validation_0-rmse:2.88953	validation_1-rmse:2.91924
# [18]	validation_0-rmse:2.84471	validation_1-rmse:2.89399
# [19]	validation_0-rmse:2.80616	validation_1-rmse:2.87027
# [20]	validation_0-rmse:2.77253	validation_1-rmse:2.85253
# [21]	validation_0-rmse:2.74293	validation_1-rmse:2.83738
# [22]	validation_0-rmse:2.71717	validation_1-rmse:2.82342
# [23]	validation_0-rmse:2.69446	validation_1-rmse:2.81534
# [24]	validation_0-rmse:2.67495	validation_1-rmse:2.80664
# [25]	validation_0-rmse:2.65606	validation_1-rmse:2.80001
# [26]	validation_0-rmse:2.64071	validation_1-rmse:2.79543
# [27]	validation_0-rmse:2.62832	validation_1-rmse:2.79103
# [28]	validation_0-rmse:2.61460	validation_1-rmse:2.78866
# [29]	validation_0-rmse:2.60165	validation_1-rmse:2.78403
# [30]	validation_0-rmse:2.58928	validation_1-rmse:2.77954
# [31]	validation_0-rmse:2.57952	validation_1-rmse:2.77559
# [32]	validation_0-rmse:2.57149	validation_1-rmse:2.77192
# [33]	validation_0-rmse:2.56213	validation_1-rmse:2.76992
# [34]	validation_0-rmse:2.55434	validation_1-rmse:2.76905
# [35]	validation_0-rmse:2.54727	validation_1-rmse:2.76643
# [36]	validation_0-rmse:2.53895	validation_1-rmse:2.76434
# [37]	validation_0-rmse:2.53127	validation_1-rmse:2.76263
# [38]	validation_0-rmse:2.52586	validation_1-rmse:2.76072
# [39]	validation_0-rmse:2.52138	validation_1-rmse:2.76026
# [40]	validation_0-rmse:2.51560	validation_1-rmse:2.75911
# [41]	validation_0-rmse:2.51131	validation_1-rmse:2.75827
# [42]	validation_0-rmse:2.50610	validation_1-rmse:2.75764
# [43]	validation_0-rmse:2.50040	validation_1-rmse:2.75855
# [44]	validation_0-rmse:2.49741	validation_1-rmse:2.75701
# [45]	validation_0-rmse:2.49122	validation_1-rmse:2.75707
# [46]	validation_0-rmse:2.48746	validation_1-rmse:2.75626
# [47]	validation_0-rmse:2.48184	validation_1-rmse:2.75535
# [48]	validation_0-rmse:2.47759	validation_1-rmse:2.75526
# [49]	validation_0-rmse:2.47391	validation_1-rmse:2.75596
# [50]	validation_0-rmse:2.47090	validation_1-rmse:2.75740
# [51]	validation_0-rmse:2.46802	validation_1-rmse:2.75690
# [52]	validation_0-rmse:2.46528	validation_1-rmse:2.75644
# [0]	validation_0-rmse:6.79499	validation_1-rmse:6.03665
# [1]	validation_0-rmse:6.24633	validation_1-rmse:5.56741
# [2]	validation_0-rmse:5.75995	validation_1-rmse:5.15244
# [3]	validation_0-rmse:5.33265	validation_1-rmse:4.79089
# [4]	validation_0-rmse:4.95472	validation_1-rmse:4.48448
# [5]	validation_0-rmse:4.62409	validation_1-rmse:4.21535
# [6]	validation_0-rmse:4.33621	validation_1-rmse:3.98854
# [7]	validation_0-rmse:4.08553	validation_1-rmse:3.78994
# [8]	validation_0-rmse:3.86806	validation_1-rmse:3.62417
# [9]	validation_0-rmse:3.68079	validation_1-rmse:3.47681
# [10]	validation_0-rmse:3.51872	validation_1-rmse:3.35609
# [11]	validation_0-rmse:3.37808	validation_1-rmse:3.25844
# [12]	validation_0-rmse:3.25847	validation_1-rmse:3.17644
# [13]	validation_0-rmse:3.15599	validation_1-rmse:3.11255
# [14]	validation_0-rmse:3.06984	validation_1-rmse:3.05490
# [15]	validation_0-rmse:2.99444	validation_1-rmse:3.00277
# [16]	validation_0-rmse:2.92978	validation_1-rmse:2.96386
# [17]	validation_0-rmse:2.87587	validation_1-rmse:2.93044
# [18]	validation_0-rmse:2.82747	validation_1-rmse:2.90205
# [19]	validation_0-rmse:2.78486	validation_1-rmse:2.87803
# [20]	validation_0-rmse:2.75025	validation_1-rmse:2.85799
# [21]	validation_0-rmse:2.72040	validation_1-rmse:2.84028
# [22]	validation_0-rmse:2.69259	validation_1-rmse:2.83064
# [23]	validation_0-rmse:2.66762	validation_1-rmse:2.81934
# [24]	validation_0-rmse:2.64808	validation_1-rmse:2.81140
# [25]	validation_0-rmse:2.62844	validation_1-rmse:2.80550
# [26]	validation_0-rmse:2.61247	validation_1-rmse:2.79773
# [27]	validation_0-rmse:2.59732	validation_1-rmse:2.79579
# [28]	validation_0-rmse:2.58174	validation_1-rmse:2.79103
# [29]	validation_0-rmse:2.56910	validation_1-rmse:2.78437
# [30]	validation_0-rmse:2.55574	validation_1-rmse:2.78128
# [31]	validation_0-rmse:2.54466	validation_1-rmse:2.78010
# [32]	validation_0-rmse:2.53484	validation_1-rmse:2.77649
# [33]	validation_0-rmse:2.52680	validation_1-rmse:2.77526
# [34]	validation_0-rmse:2.51815	validation_1-rmse:2.77510
# [35]	validation_0-rmse:2.51059	validation_1-rmse:2.77192
# [36]	validation_0-rmse:2.50286	validation_1-rmse:2.77029
# [37]	validation_0-rmse:2.49286	validation_1-rmse:2.76910
# [38]	validation_0-rmse:2.48487	validation_1-rmse:2.77225
# [39]	validation_0-rmse:2.47809	validation_1-rmse:2.77204
# [40]	validation_0-rmse:2.47001	validation_1-rmse:2.77016
# [41]	validation_0-rmse:2.46286	validation_1-rmse:2.76960
# [42]	validation_0-rmse:2.45543	validation_1-rmse:2.76752
# [43]	validation_0-rmse:2.44907	validation_1-rmse:2.77002
# [44]	validation_0-rmse:2.44326	validation_1-rmse:2.77194
# [45]	validation_0-rmse:2.43652	validation_1-rmse:2.77096
# [46]	validation_0-rmse:2.43254	validation_1-rmse:2.77045
# [47]	validation_0-rmse:2.42772	validation_1-rmse:2.76946
# Best Hyperparameters:  {'alpha': 0.1, 'gamma': 1, 'learning_rate': 0.1, 'max_depth': 9, 'n_estimators': 300, 'objective': 'reg:squarederror'}
# Best Score:  -7.980874569349928

# %% [markdown]
# ### Create dataframe to save actual values and model predictions

# %%
total_predictions = pd.DataFrame(index=pd.to_datetime(test['Time Column']))
total_predictions['Actual'] = y_test['Traffic Flow 1(t)'].values
total_predictions['Path'] = X_test['Path'].values

# %% [markdown]
# ### Train an XGboost model
# We will fit all the data in this model using the optimum parameters we found above. The optimum parameters for this dataset are:
# - n_estimators = 300
# - learning_rate = 0.1
# - max_depth = 9
# - alpha = 0.1
# - gamma = 1

# %% [markdown]
# ##### Step 0: Create XGBoost model and train it

# %%
# get the best hyperparameters from the grid search
best_params = xgb_grid.best_params_

# initialize the XGBoost model with the best hyperparameters
reg = xgb.XGBRegressor(n_estimators=best_params["n_estimators"],
                      learning_rate=best_params["learning_rate"],
                      max_depth=best_params["max_depth"],
                      objective=best_params["objective"],
                      gamma=best_params["gamma"],
                      alpha=best_params["alpha"])

# %%
# train the XGBoost model with feature weights, use validation set on test data)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test,y_test)],
        verbose=True,
        early_stopping_rounds=10)
# Out:
# [0]	validation_0-rmse:6.79499	validation_1-rmse:6.03665
# [1]	validation_0-rmse:6.24633	validation_1-rmse:5.56741
# [2]	validation_0-rmse:5.75995	validation_1-rmse:5.15244
# [3]	validation_0-rmse:5.33265	validation_1-rmse:4.79089
# [4]	validation_0-rmse:4.95472	validation_1-rmse:4.48448
# [5]	validation_0-rmse:4.62409	validation_1-rmse:4.21535
# [6]	validation_0-rmse:4.33621	validation_1-rmse:3.98854
# [7]	validation_0-rmse:4.08553	validation_1-rmse:3.78994
# [8]	validation_0-rmse:3.86806	validation_1-rmse:3.62417
# [9]	validation_0-rmse:3.68079	validation_1-rmse:3.47681
# [10]	validation_0-rmse:3.51872	validation_1-rmse:3.35609
# [11]	validation_0-rmse:3.37808	validation_1-rmse:3.25844
# [12]	validation_0-rmse:3.25847	validation_1-rmse:3.17644
# [13]	validation_0-rmse:3.15599	validation_1-rmse:3.11255
# [14]	validation_0-rmse:3.06984	validation_1-rmse:3.05490
# [15]	validation_0-rmse:2.99444	validation_1-rmse:3.00277
# [16]	validation_0-rmse:2.92978	validation_1-rmse:2.96386
# [17]	validation_0-rmse:2.87587	validation_1-rmse:2.93044
# [18]	validation_0-rmse:2.82747	validation_1-rmse:2.90205
# [19]	validation_0-rmse:2.78486	validation_1-rmse:2.87803
# [20]	validation_0-rmse:2.75025	validation_1-rmse:2.85799
# [21]	validation_0-rmse:2.72040	validation_1-rmse:2.84028
# [22]	validation_0-rmse:2.69259	validation_1-rmse:2.83064
# [23]	validation_0-rmse:2.66762	validation_1-rmse:2.81934
# [24]	validation_0-rmse:2.64808	validation_1-rmse:2.81140
# [25]	validation_0-rmse:2.62844	validation_1-rmse:2.80550
# [26]	validation_0-rmse:2.61247	validation_1-rmse:2.79773
# [27]	validation_0-rmse:2.59732	validation_1-rmse:2.79579
# [28]	validation_0-rmse:2.58174	validation_1-rmse:2.79103
# [29]	validation_0-rmse:2.56910	validation_1-rmse:2.78437
# [30]	validation_0-rmse:2.55574	validation_1-rmse:2.78128
# [31]	validation_0-rmse:2.54466	validation_1-rmse:2.78010
# [32]	validation_0-rmse:2.53484	validation_1-rmse:2.77649
# [33]	validation_0-rmse:2.52680	validation_1-rmse:2.77526
# [34]	validation_0-rmse:2.51815	validation_1-rmse:2.77510
# [35]	validation_0-rmse:2.51059	validation_1-rmse:2.77192
# [36]	validation_0-rmse:2.50286	validation_1-rmse:2.77029
# [37]	validation_0-rmse:2.49286	validation_1-rmse:2.76910
# [38]	validation_0-rmse:2.48487	validation_1-rmse:2.77225
# [39]	validation_0-rmse:2.47809	validation_1-rmse:2.77204
# [40]	validation_0-rmse:2.47001	validation_1-rmse:2.77016
# [41]	validation_0-rmse:2.46286	validation_1-rmse:2.76960
# [42]	validation_0-rmse:2.45543	validation_1-rmse:2.76752
# [43]	validation_0-rmse:2.44907	validation_1-rmse:2.77002
# [44]	validation_0-rmse:2.44326	validation_1-rmse:2.77194
# [45]	validation_0-rmse:2.43652	validation_1-rmse:2.77096
# [46]	validation_0-rmse:2.43254	validation_1-rmse:2.77045
# [47]	validation_0-rmse:2.42772	validation_1-rmse:2.76946
# [48]	validation_0-rmse:2.42378	validation_1-rmse:2.76911
# [49]	validation_0-rmse:2.41943	validation_1-rmse:2.76879
# [50]	validation_0-rmse:2.41520	validation_1-rmse:2.76868
# [51]	validation_0-rmse:2.41123	validation_1-rmse:2.76747
# [52]	validation_0-rmse:2.40589	validation_1-rmse:2.76668
# [53]	validation_0-rmse:2.40061	validation_1-rmse:2.76739
# [54]	validation_0-rmse:2.39376	validation_1-rmse:2.76614
# [55]	validation_0-rmse:2.39132	validation_1-rmse:2.76665
# [56]	validation_0-rmse:2.38591	validation_1-rmse:2.76606
# [57]	validation_0-rmse:2.38107	validation_1-rmse:2.76601
# [58]	validation_0-rmse:2.37801	validation_1-rmse:2.76545
# [59]	validation_0-rmse:2.37516	validation_1-rmse:2.76543
# [60]	validation_0-rmse:2.37136	validation_1-rmse:2.76568
# [61]	validation_0-rmse:2.37056	validation_1-rmse:2.76549
# [62]	validation_0-rmse:2.36547	validation_1-rmse:2.76669
# [63]	validation_0-rmse:2.36308	validation_1-rmse:2.76609
# [64]	validation_0-rmse:2.36015	validation_1-rmse:2.76476
# [65]	validation_0-rmse:2.35672	validation_1-rmse:2.76453
# [66]	validation_0-rmse:2.35493	validation_1-rmse:2.76435
# [67]	validation_0-rmse:2.35058	validation_1-rmse:2.76337
# [68]	validation_0-rmse:2.34716	validation_1-rmse:2.76157
# [69]	validation_0-rmse:2.34576	validation_1-rmse:2.76157
# [70]	validation_0-rmse:2.34161	validation_1-rmse:2.76105
# [71]	validation_0-rmse:2.33850	validation_1-rmse:2.76015
# [72]	validation_0-rmse:2.33774	validation_1-rmse:2.75995
# [73]	validation_0-rmse:2.33406	validation_1-rmse:2.75991
# [74]	validation_0-rmse:2.33258	validation_1-rmse:2.75989
# [75]	validation_0-rmse:2.32941	validation_1-rmse:2.75934
# [76]	validation_0-rmse:2.32576	validation_1-rmse:2.75926
# [77]	validation_0-rmse:2.32257	validation_1-rmse:2.76104
# [78]	validation_0-rmse:2.31994	validation_1-rmse:2.76074
# [79]	validation_0-rmse:2.31485	validation_1-rmse:2.76228
# [80]	validation_0-rmse:2.31272	validation_1-rmse:2.76166
# [81]	validation_0-rmse:2.31087	validation_1-rmse:2.76099
# [82]	validation_0-rmse:2.30856	validation_1-rmse:2.76076
# [83]	validation_0-rmse:2.30455	validation_1-rmse:2.76010
# [84]	validation_0-rmse:2.29932	validation_1-rmse:2.75880
# [85]	validation_0-rmse:2.29745	validation_1-rmse:2.75878
# [86]	validation_0-rmse:2.29438	validation_1-rmse:2.75865
# [87]	validation_0-rmse:2.29210	validation_1-rmse:2.75819
# [88]	validation_0-rmse:2.28981	validation_1-rmse:2.75734
# [89]	validation_0-rmse:2.28551	validation_1-rmse:2.75664
# [90]	validation_0-rmse:2.28093	validation_1-rmse:2.75780
# [91]	validation_0-rmse:2.27788	validation_1-rmse:2.75731
# [92]	validation_0-rmse:2.27516	validation_1-rmse:2.75697
# [93]	validation_0-rmse:2.27091	validation_1-rmse:2.75867
# [94]	validation_0-rmse:2.26729	validation_1-rmse:2.75889
# [95]	validation_0-rmse:2.26494	validation_1-rmse:2.75886
# [96]	validation_0-rmse:2.25990	validation_1-rmse:2.75889
# [97]	validation_0-rmse:2.25734	validation_1-rmse:2.75878
# [98]	validation_0-rmse:2.25560	validation_1-rmse:2.75863
# [99]	validation_0-rmse:2.25304	validation_1-rmse:2.75862
# XGBRegressor(alpha=0.1, base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=1, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=9, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=300, n_jobs=None, num_parallel_tree=None,
#              predictor=None, ...)

# %% [markdown]
# ##### Feature Importance of XGBoost model
# Show how our model used the feautres, in order to perform splits.

# %%
# Show how much each of the features was used in our regression analysis
plt.figure(figsize=(15,5))
fi = pd.DataFrame(data=reg.feature_importances_,index=reg.feature_names_in_,columns=['importance'])
fi.sort_values('importance').plot(kind='barh', title='Feature Importance')
plt.xlabel('Feature Importance')
plt.ylabel('Feature Name')
plt.show()

# %% [markdown]
# ##### Plot train and validation errors of XGBoost model in the same graph

# %%
# acquire the values of train and validation errors
results = reg.evals_result()
train_errors = results['validation_0']['rmse']
validation_errors = results['validation_1']['rmse']

# plot the validation and training errors
plt.figure(figsize=(10, 6))
plt.plot(train_errors, label='Train Error (Train Set)')
plt.plot(validation_errors, label='Validation Error (Test Set)')
plt.xlabel('Number of Iterations')
plt.ylabel('RMSE score of XGBoost')
plt.title('XGBoost Model Training and Validation Errors')
plt.legend()
plt.show()

# %% [markdown]
# ##### Make predictions on the test set

# %%
y_pred_xgboost = reg.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Calculate the MAE of XGBoost model
mae_xgboost = mean_absolute_error(y_test, y_pred_xgboost)
print("Mae is: ",mae_xgboost)

# Calculate RMSE score of XGBoost model
rmse_xgboost = mean_squared_error(y_test, y_pred_xgboost, squared=False)
print("RMSE score:", rmse_xgboost)
# Out:
# Mae is:  1.7127096896915075
# RMSE score: 2.7566355897783392

# %% [markdown]
# ##### Show example of how well the model learned the trainning data
# Use a random path to visualize the results

# %%
# predict on the trainning set
y_pred_train = reg.predict(X_train)

# add information in the trainning set
train_predictions = pd.DataFrame(index=pd.to_datetime(train['Time Column']))
train_predictions.insert(0,'Train Actual',y_train['Traffic Flow 1(t)'].values)
train_predictions.insert(1,'Train Predicted',y_pred_train)
train_predictions.insert(2,'Path',X_train['Path'].values)

# plot an example of the train-predictions at path 0 of the datase
plt.figure(figsize=(15,5))
plt.plot(train_predictions[train_predictions['Path']==0]['Train Actual'],".-",label='Actual Values')
plt.plot(train_predictions[train_predictions['Path']==0]['Train Predicted'],".-",label='Predictions on train set using XGboost')
plt.xlabel('Time')
plt.ylabel('Traffic Flow in current path')
plt.title('Forecast on train set using XGBoost model')
plt.legend()
plt.show()

# %% [markdown]
# As we can see, the model has learned the trend and (almost) the seasonality of the data. Despite the non-linearity of Traffic Flow, XGBoost performs quite well!

# %% [markdown]
# ##### Show an example of actual values vs predicted on test set

# %%
test_predictions = pd.DataFrame(index=pd.to_datetime(test['Time Column']))
test_predictions.insert(0,'Test Actual',y_test['Traffic Flow 1(t)'].values)
test_predictions.insert(1,'Test Predicted',y_pred_xgboost)
test_predictions.insert(2,'Path',X_test['Path'].values)

# plot an example of the train-predictions
plt.figure(figsize=(15,5))
plt.plot(test_predictions[test_predictions['Path']==0]['Test Actual'],".-",label='Actual Values')
plt.plot(test_predictions[test_predictions['Path']==0]['Test Predicted'],".-",label='Predicted Values from XGBoost')
plt.xlabel('Time information')
plt.ylabel('Traffic Flow in current path')
plt.title('Actual Values vs. Predicted on random Path of test set (XGBoost model)')
plt.legend()
plt.show()

# %% [markdown]
# ### Train LSTM for time series forecasting
# This is the second model that we will train on the same dataset. We use the optimum lookback score that we computed above.

# %% [markdown]
# #### Step 0: Create the train and test sets as before, then scale them
# Use the same train and test sets as in the XGBoost model. In order to create more accurate predictions, we scale those two sets before giving them as input to the LSTM RNN model.

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
# scale the data
scaler = MinMaxScaler()
X_tr = scaler.fit_transform(X_train)
X_te = scaler.fit_transform(X_test)

y_tr = scaler.fit_transform(y_train)
y_te = scaler.fit_transform(y_test)

# %%
# create 3D train set for LSTM
trainX = []
trainY = []

for i in range(len(X_tr)):
    trainX.append(X_tr[i:i+1,:])

for i in range(len(y_tr)):
    trainY.append(y_tr[i:i+1,:])

trainX, trainY = np.array(trainX), np.array(trainY)

# %%
# create 3D test set FOR LSTM
testX = []
testY = []

for i in range(len(X_te)):
    testX.append(X_te[i:i+1,:])

for i in range(len(y_te)):
    testY.append(y_te[i:i+1,:])

testX, testY = np.array(testX), np.array(testY)

# %%
# print shapes of the created tests
trainX.shape, trainY.shape, testX.shape, testY.shape
# Out:
# ((282000, 1, 27), (282000, 1, 1), (42000, 1, 27), (42000, 1, 1))

# %% [markdown]
# #### Step 2: Use the LSTM model for forecasting

# %% [markdown]
# ##### Import libraries and define the LSTM structure

# %%
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dropout
import tensorflow as tf

# %% [markdown]
# In the LSTM model, we include dense layers to capture more complex non linear patterns and dropout layers to prevent overfitting.

# %%
# Define LSTM model
model = Sequential()
model.add(LSTM(1000, activation='relu', return_sequences=True, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dropout(0.2))

model.add(LSTM(500, activation='relu', return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(250, activation='relu', return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(120, activation='relu', return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(60, activation='relu', return_sequences=True))
model.add(Dropout(0.2))

# Additional Dense layers
model.add(Dense(30, activation='relu'))
model.add(Dense(15, activation='relu'))
model.add(Dense(6, activation='relu'))
model.add(Dense(3, activation='relu'))

model.add(Dense(trainY.shape[1]))  # Output layer


# Add early stopping mechanism
early_stopping = EarlyStopping(patience=10, monitor='val_loss', restore_best_weights=True)
# Out:
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %% [markdown]
# ##### Compile the model

# %%
# compile LSTM model
model.compile(optimizer='adam', loss='mse')

# %% [markdown]
# ##### Train the model

# %%
# fit model on training data
history = model.fit(trainX, trainY,
          epochs=50,
          batch_size=len(trainX)//100,
          validation_data=(testX,testY),
          verbose=1,
          callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 100/100 [==============================] - 13s 61ms/step - loss: 0.0086 - val_loss: 0.0124
# Epoch 2/50
# 100/100 [==============================] - 5s 49ms/step - loss: 0.0084 - val_loss: 0.0123
# Epoch 3/50
# 100/100 [==============================] - 5s 49ms/step - loss: 0.0041 - val_loss: 0.0033
# Epoch 4/50
# 100/100 [==============================] - 5s 50ms/step - loss: 0.0021 - val_loss: 0.0032
# Epoch 5/50
# 100/100 [==============================] - 5s 49ms/step - loss: 0.0020 - val_loss: 0.0032
# Epoch 6/50
# 100/100 [==============================] - 5s 50ms/step - loss: 0.0019 - val_loss: 0.0032
# Epoch 7/50
# 100/100 [==============================] - 5s 50ms/step - loss: 0.0019 - val_loss: 0.0032
# Epoch 8/50
# 100/100 [==============================] - 5s 50ms/step - loss: 0.0019 - val_loss: 0.0031
# Epoch 9/50
# 100/100 [==============================] - 5s 50ms/step - loss: 0.0019 - val_loss: 0.0030
# Epoch 10/50
# 100/100 [==============================] - 5s 50ms/step - loss: 0.0019 - val_loss: 0.0032
# Epoch 11/50
# 100/100 [==============================] - 5s 50ms/step - loss: 0.0018 - val_loss: 0.0032
# Epoch 12/50
# 100/100 [==============================] - 5s 51ms/step - loss: 0.0018 - val_loss: 0.0032
# Epoch 13/50
# 100/100 [==============================] - 5s 50ms/step - loss: 0.0018 - val_loss: 0.0033
# Epoch 14/50
# 100/100 [==============================] - 5s 50ms/step - loss: 0.0018 - val_loss: 0.0032
# Epoch 15/50
# 100/100 [==============================] - 5s 52ms/step - loss: 0.0018 - val_loss: 0.0031
# Epoch 16/50
# 100/100 [==============================] - 5s 51ms/step - loss: 0.0018 - val_loss: 0.0033
# Epoch 17/50
# 100/100 [==============================] - 5s 52ms/step - loss: 0.0018 - val_loss: 0.0032
# Epoch 18/50
# 100/100 [==============================] - 5s 52ms/step - loss: 0.0018 - val_loss: 0.0032
# Epoch 19/50
# 100/100 [==============================] - 5s 52ms/step - loss: 0.0017 - val_loss: 0.0033

# %%
# evaluate model on test data
loss_lstm = model.evaluate(testX, testY)
print("Test Loss:", loss_lstm)
# Out:
# 1313/1313 [==============================] - 8s 6ms/step - loss: 0.0030
# Test Loss: 0.003041415009647608

# %%
### PLOT TRAIN VS. VALIDATION LOSS OF LSTM MODEL ###

# extract training and validation losses from the history object
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# plot the losses
plt.figure(figsize=(15,5))
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss Value')
plt.title('Training Loss vs Validation Loss of LSTM model')
plt.legend()

# show the plot
plt.show()

# %% [markdown]
# ##### Make predictions on test set

# %%
# predict on test data
y_pred_lstm = model.predict(testX)
y_pred_lstm = scaler.inverse_transform(y_pred_lstm.reshape(-1,1))
# Out:
# 1313/1313 [==============================] - 7s 5ms/step

# %% [markdown]
# #### Evaluate the LSTM model

# %%
# calculate the MAE score of LSTM model
mae_lstm = mean_absolute_error(scaler.inverse_transform(testY.reshape(-1,1)),y_pred_lstm)
print("Mae LSTM is: ",mae_lstm)

# Calculate the RMSE score of LSTM model
rmse_lstm = mean_squared_error(scaler.inverse_transform(testY.reshape(-1,1)), y_pred_lstm, squared=False)
print("RMSE LSTM score:", rmse_lstm)
# Out:
# Mae LSTM is:  1.8528445574109043
# RMSE LSTM score: 2.8126007327259326

# %% [markdown]
# #### Show example of how well the LSTM captured/learned the train data

# %%
# predict on the trainning set
y_pred_train_LSTM = model.predict(trainX)

# add information in the trainning set
train_predictions = pd.DataFrame(index=pd.to_datetime(train['Time Column']))
train_predictions.insert(0,'Train Actual',y_train['Traffic Flow 1(t)'].values)
train_predictions.insert(1,'Train Predicted',scaler.inverse_transform(y_pred_train_LSTM.reshape(-1,1)))
train_predictions.insert(2,'Path',X_train['Path'].values)

# plot an example of the train-predictions
plt.figure(figsize=(15,5))
plt.plot(train_predictions[train_predictions['Path']==0][['Train Actual','Train Predicted']],".-")
plt.xlabel('Time')
plt.ylabel('Traffic Flow in current path')
plt.title('Forecast on train set using LSTM model')
plt.show()
# Out:
# 8813/8813 [==============================] - 45s 5ms/step

# %% [markdown]
# ### Create Random Forest model
# This is the third model that we train on the same data, in order to forecast the traffic flow prediction. This algorithm is quite the same with the XGBoost, because both of them use decision trees to make forecasts.

# %%
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# #### Step 0: Find optimum parameters for random forest

# %%
# define the parameter grid for the grid search
param_grid = {
    'max_depth': [5, 7, 9],
    'min_samples_split': [5, 10],
    'n_estimators': [100]
}

# create the Random Forest model
rf_model = RandomForestRegressor(n_jobs=-1)

# create the GridSearchCV object
grid_search = GridSearchCV(rf_model, param_grid, cv=3, scoring='neg_mean_squared_error',verbose=1)

# fit the GridSearchCV object on the training data
grid_search.fit(X_train, y_train)

# get the best parameters and the best score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

# print the best parameters and the best score
print("Best Parameters:", best_params)
print("Best Score:", best_score)
# Out:
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# Best Parameters: {'max_depth': 9, 'min_samples_split': 10, 'n_estimators': 100}
# Best Score: -8.733678609124192

# %% [markdown]
# #### Step 1: Create and train best random forest model
# Best parameters are:
# - Max Depth: 9
# - Min samples in each split: 10
# - Number of trees: 100

# %%
# get the best hyperparameters from the grid search
best_params = grid_search.best_params_

# get the best model after Grid Search
best_model = RandomForestRegressor(n_estimators=best_params["n_estimators"],
                                  max_depth=best_params["max_depth"],
                                  min_samples_split=best_params["min_samples_split"],
                                  n_jobs=-1)

# %%
# train the random forest algorithm
best_model.fit(X_train,y_train)
# Out:
# RandomForestRegressor(max_depth=9, min_samples_split=10, n_jobs=-1)

# %% [markdown]
# #### Step 2: Make predictions on train set

# %%
# make predictions on the test set
y_pred_rf = best_model.predict(X_test)

# %%
# predict on the trainning set using random forest
y_pred_train_rf = best_model.predict(X_train)

# add information in the trainning set
train_predictions = pd.DataFrame(index=pd.to_datetime(train['Time Column']))
train_predictions.insert(0,'Train Actual',y_train['Traffic Flow 1(t)'].values)
train_predictions.insert(1,'Train Predicted',y_pred_train_rf)
train_predictions.insert(2,'Path',X_train['Path'].values)

# plot an example of the train-predictions
plt.figure(figsize=(15,5))
plt.plot(train_predictions[train_predictions['Path']==0][['Train Actual','Train Predicted']],".-")
plt.xlabel('Time')
plt.ylabel('Traffic Flow in current path')
plt.title('Forecast on train set using random forest model')
plt.show()

# %% [markdown]
# #### Step 3: Evalueate the random forest regressor

# %%
# calculate the MAE
mae_rf = mean_absolute_error(y_test, y_pred_rf)
print("MAE: ", mae_rf)

# calculate the RMSE
rmse_rf = mean_squared_error(y_test, y_pred_rf, squared=False)
print("RMSE: ", rmse_rf)
# Out:
# MAE:  1.7192047264921388
# RMSE:  2.7595442850328293

# %% [markdown]
# ### Train an Encoder-Decoder model
# This is the fourth model that we are using, in order to forecast the traffic flow.

# %% [markdown]
# #### Step 0: Initialize and compile the Encoder-Decoder model

# %%
# add necessary imports
from keras import layers

# %%
# convert train and test set to infinite datasets for faster training
BATCH_SIZE = 1
BUFFER_SIZE = 1000

train_univariate = tf.data.Dataset.from_tensor_slices((trainX, trainY))
train_univariate = train_univariate.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()
val_univariate = tf.data.Dataset.from_tensor_slices((testX, testY))
val_univariate = val_univariate.batch(BATCH_SIZE).repeat()

# %%
### DEFINE THE MODEL ###

# Encoder part
enco_deco = Sequential()
enco_deco.add(LSTM(100, input_shape=(1, trainX.shape[2]), return_sequences=True))
enco_deco.add(Dropout(0.2))  # Add dropout to the first LSTM layer
enco_deco.add(LSTM(units=50, return_sequences=True))
enco_deco.add(Dropout(0.2))  # Add dropout to the second LSTM layer
enco_deco.add(LSTM(units=15))

# Feature vector
enco_deco.add(layers.RepeatVector(1))

# Decoder part
enco_deco.add(LSTM(units=100, return_sequences=True))
enco_deco.add(LSTM(units=50, return_sequences=True))
enco_deco.add(TimeDistributed(layers.Dense(units=1)))

# %% [markdown]
# Similart to the LSTM model, we include dense layers to capture more complex non linear patterns and dropout layers to prevent overfitting.

# %%
enco_deco.compile(optimizer='adam', loss='mse')

# %% [markdown]
# #### Step 1: Train the model and make predictions

# %%
# train the enco-deco model
history = enco_deco.fit(train_univariate,
                        epochs=50,
                        steps_per_epoch=len(trainX)//100,
                        validation_data=val_univariate,
                        validation_steps=len(testX)//100,
                        verbose=1,
                        callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 2820/2820 [==============================] - 61s 15ms/step - loss: 0.0037 - val_loss: 0.0057
# Epoch 2/50
# 2820/2820 [==============================] - 40s 14ms/step - loss: 0.0017 - val_loss: 0.0052
# Epoch 3/50
# 2820/2820 [==============================] - 37s 13ms/step - loss: 0.0032 - val_loss: 0.0071
# Epoch 4/50
# 2820/2820 [==============================] - 51s 18ms/step - loss: 0.0020 - val_loss: 0.0082
# Epoch 5/50
# 2820/2820 [==============================] - 41s 15ms/step - loss: 0.0026 - val_loss: 0.0074
# Epoch 6/50
# 2820/2820 [==============================] - 32s 11ms/step - loss: 0.0023 - val_loss: 0.0057
# Epoch 7/50
# 2820/2820 [==============================] - 34s 12ms/step - loss: 9.0381e-04 - val_loss: 0.0049
# Epoch 8/50
# 2820/2820 [==============================] - 34s 12ms/step - loss: 0.0022 - val_loss: 0.0067
# Epoch 9/50
# 2820/2820 [==============================] - 32s 11ms/step - loss: 0.0060 - val_loss: 0.0133
# Epoch 10/50
# 2820/2820 [==============================] - 32s 11ms/step - loss: 0.0085 - val_loss: 0.0144
# Epoch 11/50
# 2820/2820 [==============================] - 34s 12ms/step - loss: 0.0019 - val_loss: 0.0085
# Epoch 12/50
# 2820/2820 [==============================] - 33s 12ms/step - loss: 0.0021 - val_loss: 0.0064
# Epoch 13/50
# 2820/2820 [==============================] - 32s 11ms/step - loss: 0.0021 - val_loss: 0.0055
# Epoch 14/50
# 2820/2820 [==============================] - 32s 11ms/step - loss: 0.0015 - val_loss: 0.0054
# Epoch 15/50
# 2820/2820 [==============================] - 32s 12ms/step - loss: 0.0013 - val_loss: 0.0057
# Epoch 16/50
# 2820/2820 [==============================] - 32s 11ms/step - loss: 0.0035 - val_loss: 0.0063
# Epoch 17/50
# 2820/2820 [==============================] - 32s 11ms/step - loss: 0.0023 - val_loss: 0.0059

# %%
# make predictions using Encoder-Decoder model
predicted_enco_deco = enco_deco.predict(testX)
predicted_enco_deco = scaler.inverse_transform(predicted_enco_deco.reshape(-1, 1))
# Out:
# 1313/1313 [==============================] - 8s 5ms/step

# %% [markdown]
# #### Step 2: Evaluate the model

# %%
# Calculate MAE of Encoder - Decoder model
mae_enco_deco = mean_absolute_error(y_test, predicted_enco_deco)

# Calculate RMSE Encoder - Decoder model
rmse_enco_deco = mean_squared_error(y_test, predicted_enco_deco, squared=False)

print("MAE:", mae_enco_deco)
print("RMSE:", rmse_enco_deco)
# Out:
# MAE: 1.9553750852837803
# RMSE: 3.056563840569824

# %% [markdown]
# Plot train loss vs. validation loss

# %%
# Get the loss and validation loss values and pllot them in the same graph
loss = history.history['loss']
val_loss = history.history['val_loss']

# Plot the loss and validation loss
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'b', label='Training Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')
plt.title('Training and Validation Loss of Encoder-Decoder model')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# #### Forecast on train set using Encoder-Decoder model

# %%
# predict on the trainning set
y_pred_train_enco_deco = enco_deco.predict(trainX)
y_pred_train_enco_deco = scaler.inverse_transform(y_pred_train_enco_deco.reshape(-1, 1))

# add information in the trainning set
train_predictions = pd.DataFrame(index=pd.to_datetime(train['Time Column']))
train_predictions.insert(0,'Train Actual',y_train['Traffic Flow 1(t)'].values)
train_predictions.insert(1,'Train Predicted',y_pred_train_enco_deco)
train_predictions.insert(2,'Path',X_train['Path'].values)

# plot an example of the train-predictions
plt.figure(figsize=(15,5))
plt.plot(train_predictions[train_predictions['Path']==0][['Train Actual','Train Predicted']],".-")
plt.xlabel('Time')
plt.ylabel('Traffic Flow in current path')
plt.title('Forecast on train set using Encoder-Decoder model')
plt.show()
# Out:
# 8813/8813 [==============================] - 38s 4ms/step

# %% [markdown]
# ### Add predictions of the four models to the same dataframe

# %%
# store predictions of XGBoost model to a dataframe
total_predictions['Predicted XGBoost'] = y_pred_xgboost

# %%
# store predictions of LSTM model to a dataframe
total_predictions['Predicted LSTM'] = y_pred_lstm

# %%
# add predictions of random forest
total_predictions['Predicted Random Forest'] = y_pred_rf

# %%
# add predictions of encoder decoder model
total_predictions['Predicted Encoder Decoder Model'] = predicted_enco_deco

# %%
# print dataframe with predictions
total_predictions
# Out:
#                      Actual  Path  Predicted XGBoost  Predicted LSTM  \
# Time Column
# 2008-05-24 03:00:00     3.0     0           7.131785        8.414891
# 2008-05-24 03:30:00     5.0     0           5.903675        6.848857
# 2008-05-24 04:00:00     1.0     0           6.282069        6.820249
# 2008-05-24 04:30:00     8.0     0           4.311924        5.416753
# 2008-05-24 05:00:00     6.0     0           5.332633        6.729235
# ...                     ...   ...                ...             ...
# 2008-05-24 21:30:00     3.0   999           3.996164        6.311455
# 2008-05-24 22:00:00     7.0   999           4.547622        5.277493
# 2008-05-24 22:30:00     6.0   999           4.088791        5.845790
# 2008-05-24 23:00:00     3.0   999           4.597534        6.518951
# 2008-05-24 23:30:00     1.0   999           5.195611        5.397912
#
#                      Predicted Random Forest  Predicted Encoder Decoder Model
# Time Column
# 2008-05-24 03:00:00                 7.383214                        11.846033
# 2008-05-24 03:30:00                 5.781280                         9.735999
# 2008-05-24 04:00:00                 5.823358                         8.360398
# 2008-05-24 04:30:00                 4.281614                         6.400306
# 2008-05-24 05:00:00                 5.412766                         7.902155
# ...                                      ...                              ...
# 2008-05-24 21:30:00                 4.398210                         4.310658
# 2008-05-24 22:00:00                 4.612099                         3.201538
# 2008-05-24 22:30:00                 5.300463                         3.917949
# 2008-05-24 23:00:00                 6.337233                         3.685151
# 2008-05-24 23:30:00                 4.971986                         3.345176
#
# [42000 rows x 6 columns]

# %% [markdown]
# ### Add in the same dataframe the scores of each model, in order to compare them

# %%
# create dataframe with scores
scores = pd.DataFrame(columns=['Model','RMSE Score','MAE Score'])

# define rows for dataframe
new_row = {'Model': 'XGBoost', 'RMSE Score': rmse_xgboost, 'MAE Score': mae_xgboost}
new_row1 = {'Model': 'LSTM', 'RMSE Score': rmse_lstm, 'MAE Score': mae_lstm}
new_row2 = {'Model': 'Random Forest', 'RMSE Score': rmse_rf, 'MAE Score': mae_rf}
new_row3 = {'Model': 'Encoder Decoder', 'RMSE Score': rmse_enco_deco, 'MAE Score': mae_enco_deco}

# add rows to dataframe
scores = scores.append(new_row, ignore_index=True)
scores = scores.append(new_row1, ignore_index=True)
scores = scores.append(new_row2, ignore_index=True)
scores = scores.append(new_row3, ignore_index=True)

# %%
# print dataframe with scores
scores
# Out:
#              Model  RMSE Score  MAE Score
# 0          XGBoost    2.756636   1.712710
# 1             LSTM    2.812601   1.852845
# 2    Random Forest    2.759544   1.719205
# 3  Encoder Decoder    3.056564   1.955375

# %% [markdown]
# ### Plot examples of actual vs Predicted for each of the models
# In this part, we select a random path of the dataset and compare (for each model) the actual Traffic Flow values vs. the predicted ones

# %%
# plot results from XGBoost
plt.figure(figsize=(15,5))
plt.plot(total_predictions[total_predictions['Path']==0]['Actual'],label='Actuals')
plt.plot(total_predictions[total_predictions['Path']==0]['Predicted XGBoost'],label='Predicted')
plt.xlabel("Time information")
plt.ylabel('Traffic Flow values')
plt.title('Actual vs Predicted traffic flow values of path 0 using XGBoost model')
plt.legend()
plt.plot()
# Out:
# []

# %%
# plot results from LSTM
plt.figure(figsize=(15,5))
plt.plot(total_predictions[total_predictions['Path']==0]['Actual'],label='Actuals')
plt.plot(total_predictions[total_predictions['Path']==0]['Predicted LSTM'],label='Predicted')
plt.xlabel("Time information")
plt.ylabel('Traffic Flow values')
plt.title('Actual vs Predicted traffic flow values of path 0 using LSTM model')
plt.legend()
plt.plot()
# Out:
# []

# %%
# plot results from Random Forest
plt.figure(figsize=(15,5))
plt.plot(total_predictions[total_predictions['Path']==0]['Actual'],label='Actuals')
plt.plot(total_predictions[total_predictions['Path']==0]['Predicted Random Forest'],label='Predicted')
plt.xlabel("Time information")
plt.ylabel('Traffic Flow values')
plt.title('Actual vs Predicted traffic flow values of path 0 using Random Forest model')
plt.legend()
plt.plot()
# Out:
# []

# %%
# plot results from Encoder Decoder
plt.figure(figsize=(15,5))
plt.plot(total_predictions[total_predictions['Path']==0]['Actual'],label='Actuals')
plt.plot(total_predictions[total_predictions['Path']==0]['Predicted Encoder Decoder Model'],label='Predicted')
plt.xlabel("Time information")
plt.ylabel('Traffic Flow values')
plt.title('Actual vs Predicted traffic flow values of path 0 using Encoder-Decoder model model')
plt.legend()
plt.plot()
# Out:
# []

# %% [markdown]
# ### Make visualizations on actual vs predicted data
# Use best model's predictions from **total_predictions** dataframe and plot the residuals between the actual traffic flow values and predicted. The graph to be created will contain the sum of traffic flow per timestamp, as done before in the visualization step.

# %%
# groupd dataframe by timestamp
grouped = total_predictions.groupby(total_predictions.index).sum()

# add results to dataframe
grouped = pd.DataFrame(grouped,index=grouped.index)

# drop path column, as it is useless
grouped.drop('Path', axis=1, inplace=True)

# %% [markdown]
# ##### Decide which model's predicted values will be used, based on the best RMSE score

# %%
# find the model with the best RMSE score (the lowest)
index = scores[['RMSE Score']].idxmin() # find the model with the minimun RMSE score (best model)

# %%
if (scores.iloc[index]['Model'][0] == 'XGBoost'):
    # create a plot to view the results
    plt.figure(figsize=(15,5))
    sns.lineplot(grouped,x=grouped.index,y='Actual',marker='o',linewidth=2.5,label='Actual')
    sns.lineplot(grouped,x=grouped.index,y='Predicted XGBoost',marker='o',linewidth=2.5, color='orange',label='XGboost')
    plt.xlabel('Time')
    plt.ylabel('Sum of Traffic Flow')
    plt.title('Sum of Traffic Flow in Every Path of the Dataset Over Time vs Predicted')
    plt.show()

elif (scores.iloc[index]['Model'][0] == 'LSTM'):
      # create a plot to view the results
      plt.figure(figsize=(15,5))
      sns.lineplot(grouped,x=grouped.index,y='Actual',marker='o',linewidth=2.5,label='Actual')
      sns.lineplot(grouped,x=grouped.index,y='Predicted XGBoost',marker='o',linewidth=2.5, color='orange',label='XGboost')
      plt.xlabel('Time')
      plt.ylabel('Sum of Traffic Flow')
      plt.title('Sum of Traffic Flow in Every Path of the Dataset Over Time vs Predicted')
      plt.show()

elif (scores.iloc[index]['Model'][0] == 'Random Forest'):
    # create a plot to view the results
      plt.figure(figsize=(15,5))
      sns.lineplot(grouped,x=grouped.index,y='Actual',marker='o',linewidth=2.5,label='Actual')
      sns.lineplot(grouped,x=grouped.index,y='Predicted XGBoost',marker='o',linewidth=2.5, color='orange',label='XGboost')
      plt.xlabel('Time')
      plt.ylabel('Sum of Traffic Flow')
      plt.title('Sum of Traffic Flow in Every Path of the Dataset Over Time vs Predicted')
      plt.show()

elif (scores.iloc[index]['Model'][0] == 'Encoder Decoder'):
    # create a plot to view the results
      plt.figure(figsize=(15,5))
      sns.lineplot(grouped,x=grouped.index,y='Actual',marker='o',linewidth=2.5,label='Actual')
      sns.lineplot(grouped,x=grouped.index,y='Predicted XGBoost',marker='o',linewidth=2.5, color='orange',label='XGboost')
      plt.xlabel('Time')
      plt.ylabel('Sum of Traffic Flow')
      plt.title('Sum of Traffic Flow in Every Path of the Dataset Over Time vs Predicted')
      plt.show()
